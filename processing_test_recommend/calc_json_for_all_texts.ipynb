# %%
import pandas as pd

from text_processing_udpipe_w2v import get_text_map

import json
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
dp = pd.read_csv("3000.csv")
dp.head()
# Out:
#    Unnamed: 0                                         texts_3000  \
# 0           0  Указом президента России Бориса Ельцина внесен...
# 1           1  В Харькове неизвестные изуродовали лицо депута...
# 2           2  Руководитель  следствия по делу  "Аэрофлота"  ...
# 3           3  Постоянный экономический рост позволит Китаю к...
# 4           4  В одном из ночных клубов Хмельницкого группа п...
#
#                                  same_word_list_3000 percent_3000
# 0  {'отмечать', 'изменение', 'иностранный', 'роль...        71,25
# 1  {'регион', 'серьезный', 'агентство', 'являться...  72,22222222
# 2  {'ставить', 'ход', 'фирма', 'отказываться', 'с...           74
# 3  {'внутренний', 'момент', 'сфера', 'слово', 'мн...  72,60273973
# 4  {'отмечать', 'повод', 'смерть', 'свидетель', '...  70,68965517

# %%
dp.iloc[0]['texts_3000']

# %%
text_map = get_text_map(dp.iloc[0]['texts_3000'],raw_text_input = True )

# %%
type(text_map)

# %%
text_map
# Out:
# OrderedDict([('lix', 0.7722),
#              ('ttr', 0.74),
#              ('sent_properties',
#               [0.0,
#                0.0,
#                0.035648662266713274,
#                0.04711291974761567,
#                0.0,
#                0.14117766568625106,
#                0.251912744465936]),
#              ('sentences_map',
#               [OrderedDict([('spec_sentence_features',
#                              OrderedDict([('negation', 0),
#                                           ('coreference', 0),
#                                           ('vozvr_verb', 0),
#                                           ('total_vozvr', 0),
#                                           ('prich', 0.1213849634093679),
#                                           ('total_prich', 0.4984536133171391),
#                                           ('deepr', 0),
#                                           ('total_deepr', 0),
#                                           ('case_complexity',
# ...

# %%
import simplejson
import decimal

# %%
with open('./texts_json/data.json', 'w') as outfile:  
    simplejson.dump(text_map, outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0e3618af3d04> in <module>()
#       1 with open('./texts_json/data.json', 'w') as outfile:
# ----> 2     simplejson.dump(text_map, outfile,parse_float=decimal.Decimal)
#
# ~\Anaconda3\lib\site-packages\simplejson\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, use_decimal, namedtuple_as_object, tuple_as_array, bigint_as_string, sort_keys, item_sort_key, for_json, ignore_nan, int_as_string_bitcount, iterable_as_array, **kw)
#     273             ignore_nan=ignore_nan,
#     274             int_as_string_bitcount=int_as_string_bitcount,
# --> 275             **kw).iterencode(obj)
#     276     # could accelerate with writelines in some versions of Python, at
#     277     # a debuggability cost
#
# ...
