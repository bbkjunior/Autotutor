# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd

import operator
from gensim.models.keyedvectors import FastTextKeyedVectors

from text_processing_udpipe_w2v import get_text_map

from tqdm import tqdm

import statistics

# %%
word_dp = pd.read_csv("word_db.csv", sep = ",", header=None)
word_dp.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.025718 -0.004776  0.031789  0.018760 -0.015405 -0.078441 -0.002449
# 1  0.018746  0.003426  0.020213  0.056091 -0.006876 -0.030144  0.021508
# 2  0.030954  0.012660 -0.013010  0.058922 -0.015895 -0.004156  0.043479
# 3  0.029982  0.046834 -0.016939  0.034865 -0.004499 -0.025411  0.057243
# 4  0.023059  0.052791 -0.031716  0.051026 -0.040494 -0.007667  0.052596
#
#         7         8         9      ...          291       292       293  \
# 0 -0.008062 -0.001146  0.010007    ...     0.017842 -0.041569  0.077341
# 1 -0.038640 -0.008778  0.014135    ...     0.000866 -0.069830  0.107995
# 2 -0.097470  0.013334 -0.000223    ...    -0.012979 -0.054481  0.129445
# 3 -0.126531  0.015994 -0.012146    ...    -0.063004  0.012827  0.101894
# 4 -0.087467 -0.004326  0.018472    ...    -0.052820  0.033877  0.062752
#
#         294       295       296       297       298       299       300
# 0  0.012496  0.049400 -0.037332  0.001658  0.010653 -0.036526 -0.000000
# 1  0.041295  0.074002 -0.027547 -0.023377 -0.026141 -0.028869 -0.062423
# 2  0.047809  0.064443 -0.009311 -0.068905 -0.063734 -0.017192 -0.050362
# 3  0.074595  0.044913 -0.022268 -0.048629 -0.074751  0.018179 -0.035168
# 4  0.100702  0.030436  0.018350 -0.031551 -0.050780  0.061213 -0.059490
#
# [5 rows x 301 columns]

# %%
trigramms =[]
with open ("trigramm_db.txt", "r", encoding = "utf-8") as f:
    for trig in f.readlines():
        trigramms.append(trig[:-1])

# %%
fasttext = FastTextKeyedVectors.load("D:/fasttext_word2vec/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model")

# %%
potential_recommended_text_map = get_text_map("text_8.txt")

# %%
def filter_similar_trigramms(sorted_similarity):
    filtered_sorted_similarity_list = []
    first_similarity = sorted_similarity[0][1][0][0]
    if first_similarity < 0.6:
            return None
    for similar_el in sorted_similarity[:5]:
        similarity_value = similar_el[1][0][0]
        if similarity_value - first_similarity > 0.15 or similarity_value < 0.5:
            break
        filtered_sorted_similarity_list.append(similar_el)
    return filtered_sorted_similarity_list

# %%
def trigramms_recommendation (rec_text_map, marked_trigramms_db, trigrmms_list):
    sentences_map = rec_text_map['sentences_map']
    calc_text_dict = {}
    for sentence_ind in tqdm(range(len(sentences_map))):
        for word in sentences_map[sentence_ind]['sentence_words']:
            text_word_vec = word['lex_vector'].reshape(1, -1)
            text_word_dist_dict = {}
            #print("Now check similarity for [",word['lex_trigram'],"]" )
            for word_db_ind in range(len(marked_trigramms_db)):
                marked_trigramms_db_word_vec = marked_trigramms_db.iloc[word_db_ind][:-1].values.reshape(1, -1)
                similarity = cosine_similarity(text_word_vec,marked_trigramms_db_word_vec)
                text_word_dist_dict[word_db_ind] = similarity
           
            sorted_x = sorted(text_word_dist_dict.items(), key=operator.itemgetter(1), reverse = True)
            filtered_sorted_list = filter_similar_trigramms(sorted_x)
            if not filtered_sorted_list:
                calc_text_dict[word['lex_trigram']] = None
            else:
                similar_trigrams= []
                for similar_el in filtered_sorted_list:
                    similar_trigrams.append((similar_el, trigrmms_list[similar_el[0]],list(marked_trigramms_db.iloc[similar_el[0]])[-1] ))
                calc_text_dict[word['lex_trigram']] = similar_trigrams
    vocab_recommendation_dict = {}
    for key in calc_text_dict:
        print(key , "===>", calc_text_dict[key],'\n')
        understdanding_prob_list = []
        for trgrm in similar_trigrams:
            understdanding_prob = trgrm[2]
            understdanding_prob_list.append(understdanding_prob)
        understdanding_prob_mean = statistics.mean(understdanding_prob_list) 
trigramms_recommendation(potential_recommended_text_map,word_dp,  trigramms)
# Out:
#   0%|                                                                                           | 0/23 [00:00<?, ?it/s]
#   4%|███▌                                                                               | 1/23 [00:04<01:37,  4.41s/it]
#   9%|███████▏                                                                           | 2/23 [00:07<01:16,  3.67s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [01:36<00:00,  4.19s/it]
# [ В классе ===> [((413, array([[0.70004465]])), 'что в в', -0.0), ((101, array([[0.67214563]])), 'ЛРД в Пасадене', 0.0), ((196, array([[0.65397407]])), 'Петровка в одном', -0.0), ((709, array([[0.64807961]])), 'будет в два', 0.0), ((974, array([[0.639251]])), 'летчики в звании', 0.0)]
#
# В классе был ===> None
#
# классе был урок ===> None
#
# был урок русского ===> None
#
# урок русского языка ===> None
#
# русского языка ] ===> None
#
# [ Преподаватель читал ===> None
#
# Преподаватель читал новый ===> [((683, array([[0.52374195]])), 'Ведомости писала что', 0.06047813996587426), ((743, array([[0.4987101]])), 'Как пишет The', 0.09163961321992908), ((742, array([[0.43206459]])), '[ Как пишет', 0.09163961321992908), ((458, array([[0.42807855]])), 'Януковича требуя рассказать', -0.07430377449414131), ((432, array([[0.39092781]])), 'были переданы в', -0.0274701956345495)]
#
# читал новый текст ===> [((834, array([[0.55832197]])), 'с новой инициативой', -0.03440319365690339), ((833, array([[0.42559824]])), 'выступить с новой', -0.0), ((1069, array([[0.39011039]])), 'третьем чтениях ]', 0.06968535772829497), ((1066, array([[0.37966749]])), 'во втором чтениях', 0.06968535772829497), ((1068, array([[0.34575375]])), 'и третьем чтениях', 0.06968535772829497)]
#
# новый текст ] ===> None
#
# [ Студенты внимательно ===> None
#
# Студенты внимательно слушали ===> [((878, array([[0.5118438]])), 'дали понять что', -0.01892048331530674), ((877, array([[0.49434861]])), 'четко дали понять', -0.01892048331530674), ((161, array([[0.46626943]])), 'поставить и понять', -0.0), ((162, array([[0.46004358]])), 'и понять какие', -0.07101898247737588), ((362, array([[0.45256387]])), 'поможет серьезно продвинуться', -0.03692700484474273)]
#
# внимательно слушали ] ===> [((878, array([[0.61959483]])), 'дали понять что', -0.01892048331530674), ((161, array([[0.59472714]])), 'поставить и понять', -0.0), ((877, array([[0.58842684]])), 'четко дали понять', -0.01892048331530674), ((162, array([[0.58196992]])), 'и понять какие', -0.07101898247737588), ((115, array([[0.56013057]])), 'позволяют говорить что', -0.06033119395431034)]
#
# [ Извините можно ===> [((742, array([[0.65916171]])), '[ Как пишет', 0.09163961321992908), ((878, array([[0.64673637]])), 'дали понять что', -0.01892048331530674), ((115, array([[0.64438996]])), 'позволяют говорить что', -0.06033119395431034), ((161, array([[0.63734087]])), 'поставить и понять', -0.0), ((162, array([[0.62306186]])), 'и понять какие', -0.07101898247737588)]
#
# Извините можно войти ===> [((490, array([[0.70629388]])), 'вопросы которые входят', -0.03610414513059808), ((491, array([[0.65841363]])), 'которые входят в', -0.04402867718492656), ((328, array([[0.62454797]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.58112663]])), 'что собирается ликвидировать', 0.04816833691092631), ((161, array([[0.57100819]])), 'поставить и понять', -0.0)]
#
# можно войти ] ===> [((490, array([[0.84391712]])), 'вопросы которые входят', -0.03610414513059808), ((491, array([[0.78789408]])), 'которые входят в', -0.04402867718492656), ((556, array([[0.56925913]])), 'что собирается ликвидировать', 0.04816833691092631), ((328, array([[0.559153]])), 'не собирались уточнил', 0.09327312568958669), ((639, array([[0.55809166]])), 'могут относиться действующим', -0.0498271657485375)]
#
# [ Я опоздал ===> None
#
# Я опоздал сказал ===> [((161, array([[0.69563102]])), 'поставить и понять', -0.0), ((328, array([[0.6938031]])), 'не собирались уточнил', 0.09327312568958669), ((162, array([[0.6709084]])), 'и понять какие', -0.07101898247737588), ((878, array([[0.6704079]])), 'дали понять что', -0.01892048331530674), ((877, array([[0.66366541]])), 'четко дали понять', -0.01892048331530674)]
#
# опоздал сказал Джон ===> [((115, array([[0.63030206]])), 'позволяют говорить что', -0.06033119395431034), ((742, array([[0.60908725]])), '[ Как пишет', 0.09163961321992908), ((826, array([[0.59425748]])), 'ранее Ли сообщил', -0.029057485077713455), ((743, array([[0.58682281]])), 'Как пишет The', 0.09163961321992908), ((161, array([[0.5866779]])), 'поставить и понять', -0.0)]
#
# сказал Джон ] ===> [((826, array([[0.579452]])), 'ранее Ли сообщил', -0.029057485077713455), ((918, array([[0.51734078]])), 'объединения Ли Бон', -0.015980541431139257), ((919, array([[0.47271533]])), 'Ли Бон Чжо', -0.01892048331530674), ((743, array([[0.45578887]])), 'Как пишет The', 0.09163961321992908), ((139, array([[0.38534785]])), 'из них были', 0.04267569574674601)]
#
# [ Что случилось ===> [((351, array([[0.78455482]])), 'надеются что начавшийся', -0.04316593521959937), ((879, array([[0.70023296]])), 'понять что не', -0.03682995808502739), ((878, array([[0.68179141]])), 'дали понять что', -0.01892048331530674), ((555, array([[0.64837752]])), 'том что собирается', 0.09633667382185261), ((824, array([[0.64432581]])), 'Напомним что ранее', -0.04464537750822215)]
#
# Что случилось Джон ===> [((351, array([[0.57811838]])), 'надеются что начавшийся', -0.04316593521959937), ((213, array([[0.51281914]])), 'пока не поступало', -0.20746826392641957), ((327, array([[0.50738596]])), 'давно не собирались', 0.08072910761217851), ((743, array([[0.49199386]])), 'Как пишет The', 0.09163961321992908), ((823, array([[0.49170927]])), '[ Напомним что', -0.03440319365690339)]
#
# случилось Джон ] ===> [((826, array([[0.52649166]])), 'ранее Ли сообщил', -0.029057485077713455), ((918, array([[0.51003867]])), 'объединения Ли Бон', -0.015980541431139257), ((919, array([[0.46646243]])), 'Ли Бон Чжо', -0.01892048331530674), ((743, array([[0.41121724]])), 'Как пишет The', 0.09163961321992908), ((406, array([[0.3785894]])), 'с ними не', -0.023201764571430143)]
#
# [ Вчера вы ===> None
#
# Вчера вы опоздали ===> [((797, array([[0.55483223]])), 'Coca-Cola выходит на', -0.03768735297639999), ((328, array([[0.55127595]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.52660904]])), 'что собирается ликвидировать', 0.04816833691092631), ((810, array([[0.50933407]])), 'США падают от', -0.03768735297639999), ((538, array([[0.5012848]])), 'сумев дозвониться лишь', -0.07907287866315013)]
#
# вы опоздали сегодня ===> [((328, array([[0.59723836]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.54694067]])), 'что собирается ликвидировать', 0.04816833691092631), ((555, array([[0.52254097]])), 'том что собирается', 0.09633667382185261), ((351, array([[0.50322041]])), 'надеются что начавшийся', -0.04316593521959937), ((202, array([[0.49929283]])), 'четверг вечером начался', -0.0700277305992792)]
#
# опоздали сегодня вы ===> None
#
# сегодня вы опоздали ===> [((328, array([[0.59860462]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.56798366]])), 'что собирается ликвидировать', 0.04816833691092631), ((538, array([[0.52641487]])), 'сумев дозвониться лишь', -0.07907287866315013), ((797, array([[0.51524486]])), 'Coca-Cola выходит на', -0.03768735297639999), ((810, array([[0.50161108]])), 'США падают от', -0.03768735297639999)]
#
# вы опоздали ] ===> [((328, array([[0.67074218]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.61755705]])), 'что собирается ликвидировать', 0.04816833691092631), ((161, array([[0.56597589]])), 'поставить и понять', -0.0), ((877, array([[0.54573839]])), 'четко дали понять', -0.01892048331530674), ((162, array([[0.54528097]])), 'и понять какие', -0.07101898247737588)]
#
# [ Нельзя опаздывать ===> [((328, array([[0.6160414]])), 'не собирались уточнил', 0.09327312568958669), ((161, array([[0.56387563]])), 'поставить и понять', -0.0), ((556, array([[0.5522968]])), 'что собирается ликвидировать', 0.04816833691092631), ((878, array([[0.55080634]])), 'дали понять что', -0.01892048331530674), ((351, array([[0.54766856]])), 'надеются что начавшийся', -0.04316593521959937)]
#
# Нельзя опаздывать на ===> [((797, array([[0.62074186]])), 'Coca-Cola выходит на', -0.03768735297639999), ((328, array([[0.54054826]])), 'не собирались уточнил', 0.09327312568958669), ((810, array([[0.53147716]])), 'США падают от', -0.03768735297639999), ((213, array([[0.50526203]])), 'пока не поступало', -0.20746826392641957), ((742, array([[0.49729808]])), '[ Как пишет', 0.09163961321992908)]
# опаздывать на урок ===> [((456, array([[0.56796123]])), 'суд на Януковича', -0.05456640057535233), ((118, array([[0.55742586]])), 'том что на', -0.041565885079915786), ((904, array([[0.54402168]])), 'оружия на Корейском', -0.013894619468405362), ((119, array([[0.49097994]])), 'что на поверхности', -0.031940377620244174), ((522, array([[0.46652237]])), 'работники на 49', -0.03745121228148617)]
#
# на урок ] ===> None
#
# [ Вечером Джон ===> [((201, array([[0.60369859]])), 'в четверг вечером', -0.0700277305992792), ((202, array([[0.60134532]])), 'четверг вечером начался', -0.0700277305992792), ((918, array([[0.52605701]])), 'объединения Ли Бон', -0.015980541431139257), ((826, array([[0.49025216]])), 'ранее Ли сообщил', -0.029057485077713455), ((919, array([[0.48397395]])), 'Ли Бон Чжо', -0.01892048331530674)]
#
# Вечером Джон пришел ===> [((826, array([[0.55825623]])), 'ранее Ли сообщил', -0.029057485077713455), ((202, array([[0.45452433]])), 'четверг вечером начался', -0.0700277305992792), ((743, array([[0.43283511]])), 'Как пишет The', 0.09163961321992908), ((926, array([[0.42152039]])), 'Корея должна вернуться', -0.061921578205223565), ((918, array([[0.39974512]])), 'объединения Ли Бон', -0.015980541431139257)]
#
# Джон пришел домой ===> [((328, array([[0.54468628]])), 'не собирались уточнил', 0.09327312568958669), ((202, array([[0.51127254]])), 'четверг вечером начался', -0.0700277305992792), ((926, array([[0.50609924]])), 'Корея должна вернуться', -0.061921578205223565), ((327, array([[0.47384647]])), 'давно не собирались', 0.08072910761217851), ((725, array([[0.45992537]])), 'времени мы собираемся', -0.06417838030013426)]
#
# пришел домой ] ===> None
#
# [ Дома он ===> [((662, array([[0.63467405]])), 'времени он должен', 0.0838445869857746), ((221, array([[0.62009472]])), 'крыша дома номер', 0.07976748451746778), ((220, array([[0.56118456]])), 'горит крыша дома', 0.09727572313287555), ((330, array([[0.55768506]])), 'уточнил он ]', 0.07182898514734065), ((592, array([[0.54642652]])), '[ По его', -0.043183174375264914)]
#
# Дома он долго ===> [((662, array([[0.71103554]])), 'времени он должен', 0.0838445869857746), ((330, array([[0.61338903]])), 'уточнил он ]', 0.07182898514734065), ((592, array([[0.60571166]])), '[ По его', -0.043183174375264914), ((619, array([[0.60571166]])), '[ По его', -0.029556727998711743), ((663, array([[0.57591727]])), 'он должен быть', 0.10364439162827091)]
#
# он долго думал ===> [((824, array([[0.62744105]])), 'Напомним что ранее', -0.04464537750822215), ((825, array([[0.5970857]])), 'что ранее Ли', -0.03440319365690339), ((879, array([[0.57059643]])), 'понять что не', -0.03682995808502739), ((326, array([[0.56856061]])), 'мы давно не', 0.09327312568958669), ((327, array([[0.53857091]])), 'давно не собирались', 0.08072910761217851)]
#
# долго думал «Вчера ===> [((878, array([[0.66052428]])), 'дали понять что', -0.01892048331530674), ((742, array([[0.64089651]])), '[ Как пишет', 0.09163961321992908), ((879, array([[0.62516226]])), 'понять что не', -0.03682995808502739), ((555, array([[0.62341832]])), 'том что собирается', 0.09633667382185261), ((824, array([[0.62207435]])), 'Напомним что ранее', -0.04464537750822215)]
#
# думал «Вчера я ===> None
#
# «Вчера я опоздал ===> None
#
# я опоздал сегодня ===> [((328, array([[0.57957226]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.52252233]])), 'что собирается ликвидировать', 0.04816833691092631), ((555, array([[0.50017254]])), 'том что собирается', 0.09633667382185261), ((351, array([[0.47740651]])), 'надеются что начавшийся', -0.04316593521959937), ((726, array([[0.47622467]])), 'мы собираемся инвестировать', -0.06417838030013426)]
#
# опоздал сегодня я ===> None
#
# сегодня я тоже ===> None
#
# я тоже опоздал ===> [((328, array([[0.56478762]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.50226492]])), 'что собирается ликвидировать', 0.04816833691092631), ((161, array([[0.48481447]])), 'поставить и понять', -0.0), ((878, array([[0.47747293]])), 'дали понять что', -0.01892048331530674), ((877, array([[0.47510724]])), 'четко дали понять', -0.01892048331530674)]
#
# тоже опоздал ] ===> [((328, array([[0.65908228]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.59482097]])), 'что собирается ликвидировать', 0.04816833691092631), ((161, array([[0.56938858]])), 'поставить и понять', -0.0), ((877, array([[0.54900686]])), 'четко дали понять', -0.01892048331530674), ((162, array([[0.54631833]])), 'и понять какие', -0.07101898247737588)]
#
# [ Это очень ===> [((320, array([[0.5600519]])), 'Тем более что', 0.09327312568958669), ((88, array([[0.52285231]])), 'не менее менее', 0.08870767192003974), ((87, array([[0.51810469]])), 'составить не менее', 0.08870767192003974), ((879, array([[0.51504619]])), 'понять что не', -0.03682995808502739), ((984, array([[0.50759921]])), 'бюджета не менее', -0.03138735963037905)]
#
# Это очень плохо ===> [((879, array([[0.54224987]])), 'понять что не', -0.03682995808502739), ((87, array([[0.5163801]])), 'составить не менее', 0.08870767192003974), ((320, array([[0.50603836]])), 'Тем более что', 0.09327312568958669), ((984, array([[0.49912068]])), 'бюджета не менее', -0.03138735963037905), ((88, array([[0.47018092]])), 'не менее менее', 0.08870767192003974)]
#
# очень плохо ] ===> [((658, array([[0.50933925]])), 'могут ухудшаться ]', -0.09599708988933214), ((657, array([[0.46437261]])), 'не могут ухудшаться', -0.08335730767453015), ((879, array([[0.45978155]])), 'понять что не', -0.03682995808502739), ((129, array([[0.41992994]])), 'порода не однообразна', 0.03680195733856871), ((636, array([[0.41378682]])), 'случае никак не', -0.0498271657485375)]
#
# [ Не буду ===> [((907, array([[0.90803424]])), 'полуострове быть не', -0.015980541431139257), ((908, array([[0.88993421]])), 'быть не должно', -0.03682995808502739), ((740, array([[0.8263922]])), 'деньги не потекут', -0.06417838030013426), ((789, array([[0.8263922]])), 'деньги не потекут', -0.06417838030013426), ((406, array([[0.734459]])), 'с ними не', -0.023201764571430143)]
#
# Не буду больше ===> [((907, array([[0.82836705]])), 'полуострове быть не', -0.015980541431139257), ((908, array([[0.6795689]])), 'быть не должно', -0.03682995808502739), ((740, array([[0.60752781]])), 'деньги не потекут', -0.06417838030013426), ((789, array([[0.60752781]])), 'деньги не потекут', -0.06417838030013426), ((741, array([[0.57250536]])), 'не потекут ]', -0.05420608175162145)]
#
# буду больше опаздывать ===> [((328, array([[0.63566788]])), 'не собирались уточнил', 0.09327312568958669), ((161, array([[0.57866132]])), 'поставить и понять', -0.0), ((162, array([[0.57685517]])), 'и понять какие', -0.07101898247737588), ((556, array([[0.57075386]])), 'что собирается ликвидировать', 0.04816833691092631), ((213, array([[0.55938755]])), 'пока не поступало', -0.20746826392641957)]
#
# больше опаздывать на ===> [((797, array([[0.63040409]])), 'Coca-Cola выходит на', -0.03768735297639999), ((810, array([[0.53171502]])), 'США падают от', -0.03768735297639999), ((328, array([[0.52652559]])), 'не собирались уточнил', 0.09327312568958669), ((213, array([[0.50489516]])), 'пока не поступало', -0.20746826392641957), ((1043, array([[0.49513626]])), 'было принято на', 0.08746715958298083)]
#
# [ Завтра я ===> None
#
# Завтра я встану ===> None
#
# я встану рано ===> [((824, array([[0.59915019]])), 'Напомним что ранее', -0.04464537750822215), ((825, array([[0.57175524]])), 'что ранее Ли', -0.03440319365690339), ((161, array([[0.51610082]])), 'поставить и понять', -0.0), ((328, array([[0.50019325]])), 'не собирались уточнил', 0.09327312568958669), ((555, array([[0.49173973]])), 'том что собирается', 0.09633667382185261)]
#
# встану рано в ===> [((824, array([[0.67098749]])), 'Напомним что ранее', -0.04464537750822215), ((825, array([[0.62630666]])), 'что ранее Ли', -0.03440319365690339), ((1064, array([[0.59200665]])), 'принят сразу во', 0.06968535772829497), ((547, array([[0.58087889]])), 'том что в', 0.09633667382185261), ((548, array([[0.57289872]])), 'что в конце', 0.0)]
# рано в быстро ===> [((413, array([[0.72498417]])), 'что в в', -0.0), ((364, array([[0.69658548]])), 'продвинуться в их', -0.0), ((545, array([[0.68314341]])), 'Дело в том', 0.0), ((540, array([[0.67269871]])), 'лишь в двух', -0.0), ((709, array([[0.67173871]])), 'будет в два', 0.0)]
#
# в 8 часов ===> [((353, array([[0.64088357]])), 'начавшийся в пятницу', -0.0), ((0, array([[0.62516325]])), '[ В пятницу', -0.0), ((967, array([[0.62201279]])), '15 минут ]', -0.08018394577153747), ((200, array([[0.59938439]])), 'домов в четверг', -0.0), ((709, array([[0.57646996]])), 'будет в два', 0.0)]
#
# 8 часов быстро ===> [((967, array([[0.70860007]])), '15 минут ]', -0.08018394577153747), ((966, array([[0.63451354]])), 'около 15 минут', -0.08018394577153747), ((259, array([[0.47016809]])), 'последних месяцев ]', -0.08621415772963854), ((871, array([[0.41228975]])), 'последние 10 месяцев', -0.06963108669351159), ((803, array([[0.37618482]])), 'сложное время когда', -0.02767642980636313)]
#
# часов быстро сделаю ===> None
#
# быстро сделаю зарядку ===> None
#
# сделаю зарядку приготовлю ===> None
#
# зарядку приготовлю завтрак ===> None
#
# приготовлю завтрак позавтракаю ===> None
#
# завтрак позавтракаю повторю ===> [((328, array([[0.63154759]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.56318003]])), 'что собирается ликвидировать', 0.04816833691092631), ((161, array([[0.56179327]])), 'поставить и понять', -0.0), ((726, array([[0.54418365]])), 'мы собираемся инвестировать', -0.06417838030013426), ((775, array([[0.54418365]])), 'мы собираемся инвестировать', -0.06417838030013426)]
#
# позавтракаю повторю домашнее ===> [((161, array([[0.55048926]])), 'поставить и понять', -0.0), ((328, array([[0.54329427]])), 'не собирались уточнил', 0.09327312568958669), ((162, array([[0.53356637]])), 'и понять какие', -0.07101898247737588), ((877, array([[0.52846063]])), 'четко дали понять', -0.01892048331530674), ((531, array([[0.5008723]])), 'проверяющие воспользовались горячей', -0.07907287866315013)]
#
# повторю домашнее задание ===> None
#
# домашнее задание ] ===> None
#
# Завтра я не ===> None
#
# я не опоздаю ===> [((908, array([[0.82683893]])), 'быть не должно', -0.03682995808502739), ((740, array([[0.79127373]])), 'деньги не потекут', -0.06417838030013426), ((789, array([[0.79127373]])), 'деньги не потекут', -0.06417838030013426), ((212, array([[0.74469995]])), 'пострадавших пока не', -0.20746826392641957), ((907, array([[0.72103402]])), 'полуострове быть не', -0.015980541431139257)]
#
# не опоздаю Утром ===> None
#
# опоздаю Утром Джон ===> [((918, array([[0.51743655]])), 'объединения Ли Бон', -0.015980541431139257), ((919, array([[0.48630274]])), 'Ли Бон Чжо', -0.01892048331530674), ((592, array([[0.36850435]])), '[ По его', -0.043183174375264914), ((619, array([[0.36850435]])), '[ По его', -0.029556727998711743), ((507, array([[0.36802714]])), 'из них ]', -0.07220829026119616)]
#
# Утром Джон встал ===> None
#
# Джон встал в ===> [((75, array([[0.67565114]])), 'предпочла оставить в', 0.08278299317053538), ((364, array([[0.64591481]])), 'продвинуться в их', -0.0), ((363, array([[0.62303585]])), 'серьезно продвинуться в', -0.03196080463549311), ((352, array([[0.62293346]])), 'что начавшийся в', -0.03692700484474273), ((55, array([[0.61845015]])), 'корабля говорится в', -0.024804529446421274)]
#
# встал в в ===> [((413, array([[0.97566994]])), 'что в в', -0.0), ((364, array([[0.91755423]])), 'продвинуться в их', -0.0), ((101, array([[0.91337492]])), 'ЛРД в Пасадене', 0.0), ((166, array([[0.90193304]])), 'происходили в этих', -0.0), ((597, array([[0.89923718]])), 'объясняется участившимися в', -0.043183174375264914)]
#
# 8 часов ] ===> [((967, array([[0.78107322]])), '15 минут ]', -0.08018394577153747), ((966, array([[0.71912184]])), 'около 15 минут', -0.08018394577153747), ((259, array([[0.56541313]])), 'последних месяцев ]', -0.08621415772963854), ((871, array([[0.51442611]])), 'последние 10 месяцев', -0.06963108669351159), ((201, array([[0.49568533]])), 'в четверг вечером', -0.0700277305992792)]
#
# [ Он сделал ===> [((330, array([[0.50000121]])), 'уточнил он ]', 0.07182898514734065), ((116, array([[0.45265969]])), 'говорить о том', -0.0), ((6, array([[0.44573282]])), 'признали что их', -0.05036239072468087), ((445, array([[0.44546314]])), 'которыми он владеет', 0.07276013948707317), ((742, array([[0.43205971]])), '[ Как пишет', 0.09163961321992908)]
#
# Он сделал зарядку ===> None
#
# сделал зарядку приготовил ===> None
#
# зарядку приготовил завтрак ===> None
#
# приготовил завтрак позавтракал ===> None
#
# завтрак позавтракал повторил ===> [((328, array([[0.63186669]])), 'не собирались уточнил', 0.09327312568958669), ((556, array([[0.56212858]])), 'что собирается ликвидировать', 0.04816833691092631), ((161, array([[0.56193653]])), 'поставить и понять', -0.0), ((877, array([[0.54191584]])), 'четко дали понять', -0.01892048331530674), ((726, array([[0.54158023]])), 'мы собираемся инвестировать', -0.06417838030013426)]
#
# позавтракал повторил домашнее ===> [((161, array([[0.55137713]])), 'поставить и понять', -0.0), ((328, array([[0.54447543]])), 'не собирались уточнил', 0.09327312568958669), ((162, array([[0.53428293]])), 'и понять какие', -0.07101898247737588), ((877, array([[0.52931886]])), 'четко дали понять', -0.01892048331530674), ((531, array([[0.49912272]])), 'проверяющие воспользовались горячей', -0.07907287866315013)]
#
# повторил домашнее задание ===> None
#
# домашнее задание в ===> [((413, array([[0.62238763]])), 'что в в', -0.0), ((633, array([[0.61672863]])), 'недропользования в любом', -0.0), ((416, array([[0.60775095]])), 'году в соответствии', -0.0), ((623, array([[0.60637753]])), 'обсуждаемые в средствах', -0.0), ((801, array([[0.58934962]])), 'рынок в сложное', -0.0)]
#
# задание и пошел ===> [((363, array([[0.55250329]])), 'серьезно продвинуться в', -0.03196080463549311), ((352, array([[0.55151766]])), 'что начавшийся в', -0.03692700484474273), ((313, array([[0.53068983]])), 'речь идет пенсионном', -0.05054611667884718), ((853, array([[0.50714316]])), 'инициативе идет речь', -0.03440319365690339), ((751, array([[0.47648109]])), 'США начнутся в', 0.09163961321992908)]
#
# и пошел в ===> [((363, array([[0.70347971]])), 'серьезно продвинуться в', -0.03196080463549311), ((352, array([[0.69904967]])), 'что начавшийся в', -0.03692700484474273), ((364, array([[0.67235779]])), 'продвинуться в их', -0.0), ((751, array([[0.6467163]])), 'США начнутся в', 0.09163961321992908), ((597, array([[0.62832315]])), 'объясняется участившимися в', -0.043183174375264914)]
#
# пошел в институт ===> [((413, array([[0.77261797]])), 'что в в', -0.0), ((101, array([[0.73772395]])), 'ЛРД в Пасадене', 0.0), ((597, array([[0.73310731]])), 'объясняется участившимися в', -0.043183174375264914), ((364, array([[0.71895483]])), 'продвинуться в их', -0.0), ((166, array([[0.71554052]])), 'происходили в этих', -0.0)]
#
# в институт ] ===> [((96, array([[0.50778612]])), 'представители американской Лаборатории', 0.084999980015061), ((97, array([[0.48149831]])), 'американской Лаборатории реактивного', 0.084999980015061), ((517, array([[0.43847557]])), '47 центров помощи', -0.054095825911506044), ((1058, array([[0.431567]])), 'административного центра Приморского', 0.05784483144401916), ((509, array([[0.42439525]])), 'Проверяющие министерства финансов', -0.04435935109895217)]
#
# [ В минут ===> [((540, array([[0.68918303]])), 'лишь в двух', -0.0), ((709, array([[0.68589986]])), 'будет в два', 0.0), ((413, array([[0.67026603]])), 'что в в', -0.0), ((967, array([[0.65447238]])), '15 минут ]', -0.08018394577153747), ((196, array([[0.63797692]])), 'Петровка в одном', -0.0)]
#
# В 9 часов ===> [((967, array([[0.84835036]])), '15 минут ]', -0.08018394577153747), ((966, array([[0.76140754]])), 'около 15 минут', -0.08018394577153747), ((259, array([[0.54014879]])), 'последних месяцев ]', -0.08621415772963854), ((871, array([[0.48556473]])), 'последние 10 месяцев', -0.06963108669351159), ((201, array([[0.45194857]])), 'в четверг вечером', -0.0700277305992792)]
# 9 часов Джон ===> [((967, array([[0.743636]])), '15 минут ]', -0.08018394577153747), ((966, array([[0.67568123]])), 'около 15 минут', -0.08018394577153747), ((259, array([[0.52221793]])), 'последних месяцев ]', -0.08621415772963854), ((871, array([[0.47308757]])), 'последние 10 месяцев', -0.06963108669351159), ((201, array([[0.47189214]])), 'в четверг вечером', -0.0700277305992792)]
#
# часов 30 минут ===> [((967, array([[0.94158232]])), '15 минут ]', -0.08018394577153747), ((966, array([[0.83154505]])), 'около 15 минут', -0.08018394577153747), ((259, array([[0.55611244]])), 'последних месяцев ]', -0.08621415772963854), ((871, array([[0.49926105]])), 'последние 10 месяцев', -0.06963108669351159), ((872, array([[0.43228853]])), '10 месяцев сообщает', -0.06963108669351159)]
#
# 30 минут Джон ===> [((967, array([[0.81100142]])), '15 минут ]', -0.08018394577153747), ((966, array([[0.70567305]])), 'около 15 минут', -0.08018394577153747), ((259, array([[0.45098589]])), 'последних месяцев ]', -0.08621415772963854), ((919, array([[0.40688768]])), 'Ли Бон Чжо', -0.01892048331530674), ((871, array([[0.40509596]])), 'последние 10 месяцев', -0.06963108669351159)]
#
# минут Джон пришел ===> [((826, array([[0.52702192]])), 'ранее Ли сообщил', -0.029057485077713455), ((743, array([[0.4132306]])), 'Как пишет The', 0.09163961321992908), ((926, array([[0.41098576]])), 'Корея должна вернуться', -0.061921578205223565), ((328, array([[0.36979457]])), 'не собирались уточнил', 0.09327312568958669), ((202, array([[0.36452121]])), 'четверг вечером начался', -0.0700277305992792)]
#
# Джон пришел в ===> [((352, array([[0.66495353]])), 'что начавшийся в', -0.03692700484474273), ((453, array([[0.64412073]])), 'правда подала в', -0.07430377449414131), ((75, array([[0.63641398]])), 'предпочла оставить в', 0.08278299317053538), ((364, array([[0.63058463]])), 'продвинуться в их', -0.0), ((751, array([[0.62637493]])), 'США начнутся в', 0.09163961321992908)]
#
# пришел в институт ===> [((413, array([[0.76352471]])), 'что в в', -0.0), ((101, array([[0.73889572]])), 'ЛРД в Пасадене', 0.0), ((597, array([[0.73634906]])), 'объясняется участившимися в', -0.043183174375264914), ((364, array([[0.71092306]])), 'продвинуться в их', -0.0), ((166, array([[0.71070575]])), 'происходили в этих', -0.0)]
#
# Что случилось молодой ===> [((351, array([[0.64212316]])), 'надеются что начавшийся', -0.04316593521959937), ((327, array([[0.53909296]])), 'давно не собирались', 0.08072910761217851), ((213, array([[0.51381046]])), 'пока не поступало', -0.20746826392641957), ((350, array([[0.5093662]])), 'и надеются что', -0.03196080463549311), ((823, array([[0.5037735]])), '[ Напомним что', -0.03440319365690339)]
#
# случилось молодой человек ===> [((90, array([[0.64898968]])), '30 человек ]', 0.08870767192003974), ((89, array([[0.55855191]])), 'менее 30 человек', 0.08870767192003974), ((327, array([[0.43697616]])), 'давно не собирались', 0.08072910761217851), ((879, array([[0.37822824]])), 'понять что не', -0.03682995808502739), ((740, array([[0.34226913]])), 'деньги не потекут', -0.06417838030013426)]
#
# молодой человек ] ===> [((90, array([[0.90675733]])), '30 человек ]', 0.08870767192003974), ((89, array([[0.75578142]])), 'менее 30 человек', 0.08870767192003974), ((938, array([[0.37927149]])), 'нашего народа ]', -0.0733132974460097), ((879, array([[0.36235625]])), 'понять что не', -0.03682995808502739), ((326, array([[0.3553075]])), 'мы давно не', 0.09327312568958669)]
#
# [ Куда вы ===> None
#
# Куда вы идете ===> None
#
# вы идете спросил ===> [((328, array([[0.67637134]])), 'не собирались уточнил', 0.09327312568958669), ((742, array([[0.66230645]])), '[ Как пишет', 0.09163961321992908), ((161, array([[0.60331463]])), 'поставить и понять', -0.0), ((329, array([[0.59561091]])), 'собирались уточнил он', 0.08072910761217851), ((878, array([[0.58943142]])), 'дали понять что', -0.01892048331530674)]
#
# идете спросил дежурный ===> [((328, array([[0.60714732]])), 'не собирались уточнил', 0.09327312568958669), ((847, array([[0.55206581]])), 'не уточнив впрочем', -0.03440319365690339), ((466, array([[0.53571906]])), '[ Как сообщает', -0.059700725838095714), ((1024, array([[0.53571906]])), '[ Как сообщает', 0.06710637837013368), ((329, array([[0.53548331]])), 'собирались уточнил он', 0.08072910761217851)]
#
# спросил дежурный ] ===> None
#
# [ Я иду ===> [((313, array([[0.51965539]])), 'речь идет пенсионном', -0.05054611667884718), ((853, array([[0.47327515]])), 'инициативе идет речь', -0.03440319365690339), ((797, array([[0.37766358]])), 'Coca-Cola выходит на', -0.03768735297639999), ((312, array([[0.3695503]])), 'что речь идет', -0.05054611667884718), ((153, array([[0.35729398]])), 'выше поднимется Curiosity', -0.07101898247737588)]
#
# Я иду на ===> [((797, array([[0.6028019]])), 'Coca-Cola выходит на', -0.03768735297639999), ((313, array([[0.57434475]])), 'речь идет пенсионном', -0.05054611667884718), ((853, array([[0.55096984]])), 'инициативе идет речь', -0.03440319365690339), ((312, array([[0.43654887]])), 'что речь идет', -0.05054611667884718), ((798, array([[0.42071758]])), 'выходит на молочный', -0.02767642980636313)]
#
# иду на урок ===> [((904, array([[0.5764139]])), 'оружия на Корейском', -0.013894619468405362), ((456, array([[0.56389339]])), 'суд на Януковича', -0.05456640057535233), ((118, array([[0.54000665]])), 'том что на', -0.041565885079915786), ((119, array([[0.52495444]])), 'что на поверхности', -0.031940377620244174), ((522, array([[0.46992869]])), 'работники на 49', -0.03745121228148617)]
#
# [ Сегодня я ===> None
#
# Сегодня я не ===> None
#
# я не опоздал ===> [((327, array([[0.75053802]])), 'давно не собирались', 0.08072910761217851), ((213, array([[0.72221922]])), 'пока не поступало', -0.20746826392641957), ((879, array([[0.70145137]])), 'понять что не', -0.03682995808502739), ((740, array([[0.69091385]])), 'деньги не потекут', -0.06417838030013426), ((789, array([[0.69091385]])), 'деньги не потекут', -0.06417838030013426)]
#
# не опоздал ответил ===> [((328, array([[0.70875367]])), 'не собирались уточнил', 0.09327312568958669), ((161, array([[0.70047002]])), 'поставить и понять', -0.0), ((162, array([[0.67804364]])), 'и понять какие', -0.07101898247737588), ((877, array([[0.65716489]])), 'четко дали понять', -0.01892048331530674), ((878, array([[0.64422699]])), 'дали понять что', -0.01892048331530674)]
#
# опоздал ответил Джон ===> [((496, array([[0.61565371]])), 'часто задаваемых они', -0.08805735436985311), ((161, array([[0.56584379]])), 'поставить и понять', -0.0), ((596, array([[0.56427134]])), 'это объясняется участившимися', -0.043183174375264914), ((743, array([[0.5601302]])), 'Как пишет The', 0.09163961321992908), ((328, array([[0.55653499]])), 'не собирались уточнил', 0.09327312568958669)]
#
# ответил Джон ] ===> [((826, array([[0.55259801]])), 'ранее Ли сообщил', -0.029057485077713455), ((918, array([[0.50318433]])), 'объединения Ли Бон', -0.015980541431139257), ((919, array([[0.4458936]])), 'Ли Бон Чжо', -0.01892048331530674), ((743, array([[0.44431259]])), 'Как пишет The', 0.09163961321992908), ((744, array([[0.38248661]])), 'пишет The Daily', 0.07740027627147918)]
#
# [ Идите домой ===> None
#
# Идите домой молодой ===> None
#
# домой молодой человек ===> [((90, array([[0.59052576]])), '30 человек ]', 0.08870767192003974), ((89, array([[0.47529632]])), 'менее 30 человек', 0.08870767192003974), ((327, array([[0.38095276]])), 'давно не собирались', 0.08072910761217851), ((326, array([[0.32280962]])), 'мы давно не', 0.09327312568958669), ((740, array([[0.30030134]])), 'деньги не потекут', -0.06417838030013426)]
#
# [ Сегодня нет ===> None
#
# Сегодня нет урока ===> None
#
# нет урока ] ===> None
#
# [ Сегодня воскресенье ===> [((201, array([[0.50000226]])), 'в четверг вечером', -0.0700277305992792), ((1, array([[0.44979428]])), 'В пятницу представители', -0.062422885189795885), ((950, array([[0.41627341]])), 'в четверг ]', 0.12009507553616627), ((202, array([[0.41142519]])), 'четверг вечером начался', -0.0700277305992792), ((977, array([[0.39362396]])), '[ Отныне город', -0.03138735963037905)]
# Сегодня воскресенье ] ===> [((201, array([[0.60281849]])), 'в четверг вечером', -0.0700277305992792), ((202, array([[0.53038461]])), 'четверг вечером начался', -0.0700277305992792), ((1, array([[0.51007205]])), 'В пятницу представители', -0.062422885189795885), ((950, array([[0.47641478]])), 'в четверг ]', 0.12009507553616627), ((550, array([[0.44657272]])), 'конце февраля Пентагон', 0.04816833691092631)]
