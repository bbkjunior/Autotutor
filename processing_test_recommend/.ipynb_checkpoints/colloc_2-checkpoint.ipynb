# %%
import nltk
import pandas as pd
from pymystem3 import Mystem

# %%
text = "Красивая мама красиво мыла раму"
m = Mystem()
lemmas = m.lemmatize(text)
print(''.join(lemmas))
# Out:
# красивый мама красиво мыть рама

# %%
text_content_ru = """
В классе был урок русского языка. Преподаватель читал новый текст.
Студенты внимательно слушали.
– Извините, можно войти? Я опоздал, – сказал Джон.
– Что случилось, Джон? Вчера вы опоздали, сегодня вы опоздали. Нельзя
опаздывать на урок.
Вечером Джон пришел домой. Дома он долго думал: «Вчера я опоздал,
сегодня я тоже опоздал. Это очень плохо. Не буду больше опаздывать на
урок. Завтра я встану рано, в 8 часов, быстро сделаю зарядку, приготовлю
завтрак, позавтракаю, повторю домашнее задание. Завтра я не опоздаю!»
Утром Джон встал в 8 часов. Он сделал зарядку, приготовил завтрак,
позавтракал, повторил домашнее задание и пошел в институт.
В 9 часов 30 минут Джон пришел в институт.
– Что случилось, молодой человек? Куда вы идете? – спросил дежурный.
– Я иду на урок. Сегодня я не опоздал, – ответил Джон.
– Идите домой, молодой человек! Сегодня нет урока. Сегодня воскресенье.
"""
lemmas_ru = m.lemmatize(text_content_ru)
lemmas_ru = ''.join(lemmas_ru)
print(lemmas_ru)
# Out:
# в класс быть урок русский язык. преподаватель читать новый текст.
# студент внимательно слушать.
# – извинять, можно входить? я опаздывать, – сказать джон.
# – что случаться, джон? вчера вы опаздывать, сегодня вы опаздывать. нельзя
# опаздывать на урок.
# вечер джон приходить домой. дома он долго думать: «вчера я опаздывать,
# сегодня я тоже опаздывать. это очень плохой. не быть больше опаздывать на
# урок. завтра я вставать рано, в 8 час, быстро сделать зарядка, приготавливать
# завтрак, позавтракать, повторять домашний задание. завтра я не опаздывать!»
# утро джон вставать в 8 час. он сделать зарядка, приготавливать завтрак,
# позавтракать, повторять домашний задание и пойти в институт.
# в 9 час 30 минута джон приходить в институт.
# – что случаться, молодой человек? куда вы идти? – спрашивать дежурный.
# – я идти на урок. сегодня я не опаздывать, – отвечать джон.
# – идти домой, молодой человек! сегодня нет урок. сегодня воскресение.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/lilyakhoang/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = "Ай да А.С. Пушкин! Ай да сукин сын!"
print("Before:", nltk.sent_tokenize(text))
print("After:", nltk.sent_tokenize(text, language="russian"))
# Out:
# Before: ['Ай да А.С.', 'Пушкин!', 'Ай да сукин сын!']
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-59-b439bd3437ac> in <module>()
#       1 text = "Ай да А.С. Пушкин! Ай да сукин сын!"
#       2 print("Before:", nltk.sent_tokenize(text))
# ----> 3 print("After:", nltk.sent_tokenize(text, language="russian"))
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     102     :param language: the model name in the Punkt corpus
#     103     """
# --> 104     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#     105     return tokenizer.tokenize(text)
#     106
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     866
#     867     # Load the resource.
# --> 868     opened_resource = _open(resource_url)
#     869
#     870     if format == 'raw':
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in _open(resource_url)
#     991
#     992     if protocol is None or protocol.lower() == 'nltk':
# --> 993         return find(path_, path + ['']).open()
#     994     elif protocol.lower() == 'file':
#     995         # urllib might not use mode='rb', so handle this one ourselves:
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     697     sep = '*' * 70
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#     701
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   Attempted to load tokenizers/punkt/PY3/russian.pickle
#
#   Searched in:
#     - '/Users/lilyakhoang/nltk_data'
#     - '/Users/lilyakhoang/anaconda3/nltk_data'
#     - '/Users/lilyakhoang/anaconda3/share/nltk_data'
#     - '/Users/lilyakhoang/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
mystemmed_line = m.analyze(line)

# %%
text_content_en = """
	Sources tell us that Google is acquiring Kaggle, a platform that hosts data science and machine learning
	competitions. Details about the transaction remain somewhat vague , but given that Google is hosting
	its Cloud Next conference in San Francisco this week, the official announcement could come as early
	as tomorrow.  Reached by phone, Kaggle co-founder CEO Anthony Goldbloom declined to deny that the
	acquisition is happening. Google itself declined 'to comment on rumors'.
"""

# %%
text_content =  nltk.sent_tokenize(lemmas_ru)
tok_sent = [ sent.split() for sent in text_content]
text_split = []
for sentence in tok_sent:
    for word in sentence:
        text_split.append(word)

# %%
bigrams = nltk.collocations.BigramAssocMeasures()
trigrams = nltk.collocations.TrigramAssocMeasures()
bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(text_split)
trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(text_split)

# %%
bigram_freq = bigramFinder.ngram_fd.items()
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)
#trigrams
trigram_freq = trigramFinder.ngram_fd.items()
trigramFreqTable = pd.DataFrame(list(trigram_freq), columns=['trigram','freq']).sort_values(by='freq', ascending=False)

# %%
bigramFreqTable
# Out:
#                          bigram  freq
# 34                  (на, урок.)     3
# 33             (опаздывать, на)     2
# 18             (опаздывать,, –)     2
# 22                     (–, что)     2
# 23            (что, случаться,)     2
# 28       (опаздывать,, сегодня)     2
# 66   (приготавливать, завтрак,)     2
# 37            (джон, приходить)     2
# 85               (в, институт.)     2
# 45                 (сегодня, я)     2
# 56                  (завтра, я)     2
# 72                      (я, не)     2
# 60                       (в, 8)     2
# 69        (повторять, домашний)     2
# 68   (позавтракать,, повторять)     2
# 67    (завтрак,, позавтракать,)     2
# 64          (сделать, зарядка,)     2
# 21                   (джон., –)     2
# 65   (зарядка,, приготавливать)     2
# 17             (я, опаздывать,)     2
# 106            (урок., сегодня)     2
# 101     (спрашивать, дежурный.)     1
# 74         (опаздывать!», утро)     1
# 82                 (задание, и)     1
# 81          (домашний, задание)     1
# 80                (он, сделать)     1
# 79                   (час., он)     1
# 78                    (8, час.)     1
# 77                (вставать, в)     1
# 76             (джон, вставать)     1
# ..                          ...   ...
# 4              (русский, язык.)     1
# 3               (урок, русский)     1
# 2                  (быть, урок)     1
# 30            (вы, опаздывать.)     1
# 32         (нельзя, опаздывать)     1
# 62               (час,, быстро)     1
# 49                 (это, очень)     1
# 61                    (8, час,)     1
# 1                 (класс, быть)     1
# 58            (вставать, рано,)     1
# 57                (я, вставать)     1
# 55              (урок., завтра)     1
# 54         (больше, опаздывать)     1
# 53               (быть, больше)     1
# 52                   (не, быть)     1
# 51                (плохой., не)     1
# 50             (очень, плохой.)     1
# 48           (опаздывать., это)     1
# 35               (урок., вечер)     1
# 47          (тоже, опаздывать.)     1
# 46                    (я, тоже)     1
# 44                  («вчера, я)     1
# 43            (думать:, «вчера)     1
# 42             (долго, думать:)     1
# 41                  (он, долго)     1
# 40                   (дома, он)     1
# 39               (домой., дома)     1
# 38          (приходить, домой.)     1
# 36                (вечер, джон)     1
# 117     (сегодня, воскресение.)     1
#
# [118 rows x 2 columns]

# %%
#get english stopwords
en_stopwords = set(nltk.corpus.stopwords.words('russian'))
#function to filter for ADJ/NN bigrams
def rightTypes(ngram):
    print(ngram)
    if '-pron-' in ngram or 't' in ngram:
        print("pron found")
        return False
    for word in ngram:
        if word in en_stopwords or word.isspace():
            print("stopword found")
            return False
    acceptable_types = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    second_type = ('NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(ngram, lang='rus')
    
    print(tags)
    if tags[0][1] in acceptable_types and tags[1][1] in second_type:
        print("fltr ok")
        return True
    else:
        print("pos not ok")
        return False
#filter bigrams
filtered_bi = bigramFreqTable[bigramFreqTable.bigram.map(lambda x: rightTypes(x))]
# Out:
# ('на', 'урок.')
# stopword found
# ('опаздывать', 'на')
# stopword found
# ('опаздывать,', '–')
# [('опаздывать,', 'V'), ('–', 'NONLEX')]
# pos not ok
# ('–', 'что')
# stopword found
# ('что', 'случаться,')
# stopword found
# ('опаздывать,', 'сегодня')
# [('опаздывать,', 'V'), ('сегодня', 'ADV')]
# pos not ok
# ('приготавливать', 'завтрак,')
# [('приготавливать', 'V'), ('завтрак,', 'S')]
# pos not ok
# ('джон', 'приходить')
# [('джон', 'V'), ('приходить', 'V')]
# pos not ok
# ('в', 'институт.')
# stopword found
# ('сегодня', 'я')
# stopword found
# ('завтра', 'я')
# stopword found
# ('я', 'не')
# stopword found
# ('в', '8')
# stopword found
# ('повторять', 'домашний')
# [('повторять', 'V'), ('домашний', 'S')]
# pos not ok
# ('позавтракать,', 'повторять')
# [('позавтракать,', 'V'), ('повторять', 'V')]
# pos not ok
# ('завтрак,', 'позавтракать,')
# [('завтрак,', 'V'), ('позавтракать,', 'S')]
# pos not ok
# ('сделать', 'зарядка,')
# [('сделать', 'V'), ('зарядка,', 'S')]
# pos not ok
# ('джон.', '–')
# [('джон.', 'V'), ('–', 'NONLEX')]
# pos not ok
# ('зарядка,', 'приготавливать')
# [('зарядка,', 'V'), ('приготавливать', 'V')]
# pos not ok
# ('я', 'опаздывать,')
# stopword found
# ('урок.', 'сегодня')
# [('урок.', 'V'), ('сегодня', 'ADV')]
# pos not ok
# ('спрашивать', 'дежурный.')
# [('спрашивать', 'V'), ('дежурный.', 'S')]
# pos not ok
# ('опаздывать!»', 'утро')
# [('опаздывать!»', 'V'), ('утро', 'S')]
# pos not ok
# ('задание', 'и')
# stopword found
# ('домашний', 'задание')
# [('домашний', 'A=m'), ('задание', 'S')]
# pos not ok
# ('он', 'сделать')
# stopword found
# ('час.', 'он')
# stopword found
# ('8', 'час.')
# [('8', 'NUM=ciph'), ('час.', 'S')]
# pos not ok
# ('вставать', 'в')
# stopword found
# ('джон', 'вставать')
# [('джон', 'V'), ('вставать', 'V')]
# pos not ok
# ('утро', 'джон')
# [('утро', 'S'), ('джон', 'S')]
# pos not ok
# ('не', 'опаздывать!»')
# stopword found
# ('и', 'пойти')
# stopword found
# ('–', 'идти')
# [('–', 'NONLEX'), ('идти', 'V')]
# pos not ok
# ('идти', 'домой,')
# [('идти', 'V'), ('домой,', 'S')]
# pos not ok
# ('задание.', 'завтра')
# [('задание.', 'V'), ('завтра', 'ADV')]
# pos not ok
# ('домашний', 'задание.')
# [('домашний', 'A=m'), ('задание.', 'S')]
# pos not ok
# ('домой,', 'молодой')
# [('домой,', 'V'), ('молодой', 'A=m')]
# pos not ok
# ('молодой', 'человек!')
# [('молодой', 'A=m'), ('человек!', 'S')]
# pos not ok
# ('человек!', 'сегодня')
# [('человек!', 'S-PRO'), ('сегодня', 'ADV')]
# pos not ok
# ('сегодня', 'нет')
# stopword found
# ('нет', 'урок.')
# stopword found
# ('отвечать', 'джон.')
# [('отвечать', 'V'), ('джон.', 'S')]
# pos not ok
# ('–', 'отвечать')
# [('–', 'V'), ('отвечать', 'V')]
# pos not ok
# ('пойти', 'в')
# stopword found
# ('–', 'спрашивать')
# [('–', 'V'), ('спрашивать', 'V')]
# pos not ok
# ('дежурный.', '–')
# [('дежурный.', 'V'), ('–', 'NONLEX')]
# pos not ok
# ('–', 'я')
# stopword found
# ('идти?', '–')
# [('идти?', 'V'), ('–', 'NONLEX')]
# pos not ok
# ('вы', 'идти?')
# stopword found
# ('куда', 'вы')
# stopword found
# ('человек?', 'куда')
# stopword found
# ('я', 'идти')
# stopword found
# ('молодой', 'человек?')
# [('молодой', 'A=m'), ('человек?', 'S')]
# pos not ok
# ('случаться,', 'молодой')
# [('случаться,', 'V'), ('молодой', 'A=m')]
# pos not ok
# ('институт.', '–')
# [('институт.', 'V'), ('–', 'NONLEX')]
# pos not ok
# ('приходить', 'в')
# stopword found
# ('идти', 'на')
# stopword found
# ('минута', 'джон')
# [('минута', 'S'), ('джон', 'S')]
# pos not ok
# ('30', 'минута')
# [('30', 'NUM=ciph'), ('минута', 'S')]
# pos not ok
# ('не', 'опаздывать,')
# stopword found
# ('час', '30')
# [('час', 'S'), ('30', 'NUM=ciph')]
# pos not ok
# ('9', 'час')
# [('9', 'NUM=ciph'), ('час', 'S')]
# pos not ok
# ('в', '9')
# stopword found
# ('институт.', 'в')
# stopword found
# ('в', 'класс')
# stopword found
# ('рано,', 'в')
# stopword found
# ('быстро', 'сделать')
# [('быстро', 'ADV'), ('сделать', 'V')]
# pos not ok
# ('–', 'извинять,')
# [('–', 'NONLEX'), ('извинять,', 'V')]
# pos not ok
# ('сегодня', 'вы')
# stopword found
# ('вы', 'опаздывать,')
# stopword found
# ('вчера', 'вы')
# stopword found
# ('джон?', 'вчера')
# [('джон?', 'S'), ('вчера', 'ADV')]
# pos not ok
# ('случаться,', 'джон?')
# [('случаться,', 'V'), ('джон?', 'S')]
# pos not ok
# ('сказать', 'джон.')
# [('сказать', 'V'), ('джон.', 'S')]
# pos not ok
# ('–', 'сказать')
# [('–', 'PRAEDIC'), ('сказать', 'V')]
# pos not ok
# ('входить?', 'я')
# stopword found
# ('можно', 'входить?')
# stopword found
# ('извинять,', 'можно')
# stopword found
# ('слушать.', '–')
# [('слушать.', 'V'), ('–', 'NONLEX')]
# pos not ok
# ('опаздывать.', 'нельзя')
# stopword found
# ('внимательно', 'слушать.')
# [('внимательно', 'ADV'), ('слушать.', 'V')]
# pos not ok
# ('студент', 'внимательно')
# [('студент', 'S'), ('внимательно', 'ADV')]
# pos not ok
# ('текст.', 'студент')
# [('текст.', 'V'), ('студент', 'S')]
# pos not ok
# ('новый', 'текст.')
# [('новый', 'A=m'), ('текст.', 'S')]
# pos not ok
# ('читать', 'новый')
# [('читать', 'V'), ('новый', 'A=m')]
# pos not ok
# ('преподаватель', 'читать')
# [('преподаватель', 'S'), ('читать', 'V')]
# pos not ok
# ('язык.', 'преподаватель')
# [('язык.', 'A=m'), ('преподаватель', 'S')]
# pos not ok
# ('русский', 'язык.')
# [('русский', 'A=m'), ('язык.', 'S')]
# pos not ok
# ('урок', 'русский')
# [('урок', 'S'), ('русский', 'A=m')]
# pos not ok
# ('быть', 'урок')
# stopword found
# ('вы', 'опаздывать.')
# stopword found
# ('нельзя', 'опаздывать')
# stopword found
# ('час,', 'быстро')
# [('час,', 'S-PRO'), ('быстро', 'ADV')]
# pos not ok
# ('это', 'очень')
# [('это', 'S-PRO'), ('очень', 'ADV')]
# pos not ok
# ('8', 'час,')
# [('8', 'NUM=ciph'), ('час,', 'S')]
# pos not ok
# ('класс', 'быть')
# stopword found
# ('вставать', 'рано,')
# [('вставать', 'V'), ('рано,', 'S')]
# pos not ok
# ('я', 'вставать')
# stopword found
# ('урок.', 'завтра')
# [('урок.', 'V'), ('завтра', 'ADV')]
# pos not ok
# ('больше', 'опаздывать')
# stopword found
# ('быть', 'больше')
# stopword found
# ('не', 'быть')
# stopword found
# ('плохой.', 'не')
# stopword found
# ('очень', 'плохой.')
# [('очень', 'ADV'), ('плохой.', 'ADV')]
# pos not ok
# ('опаздывать.', 'это')
# [('опаздывать.', 'V'), ('это', 'S-PRO')]
# pos not ok
# ('урок.', 'вечер')
# [('урок.', 'V'), ('вечер', 'S')]
# pos not ok
# ('тоже', 'опаздывать.')
# stopword found
# ('я', 'тоже')
# stopword found
# ('«вчера', 'я')
# stopword found
# ('думать:', '«вчера')
# [('думать:', 'S'), ('«вчера', 'S')]
# pos not ok
# ('долго', 'думать:')
# [('долго', 'ADV'), ('думать:', 'S')]
# pos not ok
# ('он', 'долго')
# stopword found
# ('дома', 'он')
# stopword found
# ('домой.', 'дома')
# [('домой.', 'V'), ('дома', 'ADV')]
# pos not ok
# ('приходить', 'домой.')
# [('приходить', 'V'), ('домой.', 'S')]
# pos not ok
# ('вечер', 'джон')
# [('вечер', 'S'), ('джон', 'S')]
# pos not ok
# ('сегодня', 'воскресение.')
# [('сегодня', 'ADV'), ('воскресение.', 'S')]
# pos not ok

# %%
filtered_bi
# Out:
# Empty DataFrame
# Columns: [bigram, freq]
# Index: []

# %%
#function to filter for trigrams
def rightTypesTri(ngram):
    if '-pron-' in ngram or 't' in ngram:
        return False
    for word in ngram:
        if word in en_stopwords or word.isspace():
            return False
    first_type = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    third_type = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in first_type and tags[2][1] in third_type:
        return True
    else:
        return False
#filter trigrams
filtered_tri = trigramFreqTable[trigramFreqTable.trigram.map(lambda x: rightTypesTri(x))]
