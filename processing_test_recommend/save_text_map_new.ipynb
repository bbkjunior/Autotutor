# %%
import json
from text_proc_colloc import get_text_map
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
ma = get_text_map("text_8.txt")

# %%
ma
# Out:
# OrderedDict([('lix', 0.4112),
#              ('ttr', 0.56),
#              ('sent_properties',
#               [0.13043478260869565,
#                0.043478260869565216,
#                0.0,
#                0.0,
#                0.0,
#                0.0,
#                0.15444444444444444]),
#              ('sentences_map',
#               [OrderedDict([('spec_sentence_features',
#                              OrderedDict([('negation', 0),
#                                           ('coreference', 0),
#                                           ('vozvr_verb', 0),
#                                           ('total_vozvr', 0),
#                                           ('prich', 0),
#                                           ('total_prich', 0),
#                                           ('deepr', 0),
#                                           ('total_deepr', 0),
#                                           ('case_complexity', 0),
# ...

# %% [raw]
# with open('text_map.json',  'w', encoding = "utf-8") as outfile:
#     json.dump(ma, outfile, ensure_ascii=False)
