# %% [markdown]
# # ДЛЯ БОЛЬШИХ ОБЪЕМОВ ДАННЫХ СЧИТАЕМ МЕТРИКИ ДЛЯ ОТРЫВКОВ ТЕКСТОВ А ПОТОМ УСРЕДНЯЕМ МЕТРКИ МЕЖДУ СОХРАНЕННЫМИ ФАЙЛАМИ

# %%
https://medium.com/@nicharuch/collocations-identifying-phrases-that-act-like-individual-words-in-nlp-f58a93a2f84a
    
    https://github.com/nicharuc/Collocations/blob/master/Collocations.ipynb
        
        
https://www.nltk.org/_modules/nltk/tag.html
    
https://www.nltk.org/_modules/nltk/collocations.html
    
https://www.nltk.org/api/nltk.metrics.html

# %%
from colloc_lib import get_pos_filtered_colloc_from_corpus_list, get_colloc_from_corpus_list
import pandas as pd
from ud_class import Model 
import nltk
from pymystem3 import Mystem

# %%
texts_lenta.iloc[0]['texts_3000']
# Out:
# 'Указом президента России Бориса Ельцина внесены изменения в  существующую структуру Федеральной службы безопасности РФ, утвержденную в июле прошлого года. Как говорится в поступившем сегодня сообщении Центра общественных связей ФСБ, в соответствии с Основами (Концепцией) государственной политики Российской Федерации по военномустроительству на период до 2005 года, на базе Департамента по борьбе с терроризмом и Управления конституционной безопасности ФСБ создан Департамент по защите конституционного строя и борьбе с терроризмом. В составе департамента организуются три управления с четко определенной компетенцией. В ФСБ отмечают, что "в современных условиях для российскойгосударственности имеют приоритетное значение вопросы защитыконституционного строя, сохранения целостности страны, борьбыс терроризмом и всеми формами экстремизма, а также разведывательно-подрывной деятельностью спецслужб и организаций иностранных государств". Как подчеркивается в сообщении, "органам безопасности в решении данных проблем отведена особая роль".'

# %% [markdown]
# # FREQ POS FILTER

# %%
stopwords = set(nltk.corpus.stopwords.words('russian'))
model = Model('./udpipe parsers/russian-syntagrus-ud-2.0-170801.udpipe')
texts_lenta = pd.read_csv("3000.csv")

bigramFreqTable, trigramFreqTable, filtered_bi, filtered_tri =get_pos_filtered_colloc_from_corpus_list(list(texts_lenta['texts_3000']), stopwords, model)
# Out:
# 100%|██████████| 898/898 [01:53<00:00,  7.88it/s]

# %%
filtered_bi
# Out:
#                                            bigram  freq
# 2629               (глава_NOUN, государство_NOUN)    72
# 2548                  (настоящий_ADJ, время_NOUN)    65
# 510                   (ближайший_ADJ, время_NOUN)    37
# 21525                    (русский_ADJ, язык_NOUN)    36
# 5429                   (право_NOUN, человек_NOUN)    35
# 17                        (прошлый_ADJ, год_NOUN)    34
# 2207                 (миллиард_NOUN, доллар_NOUN)    33
# 6684                 (министр_NOUN, оборона_NOUN)    32
# 1984                  (миллион_NOUN, доллар_NOUN)    31
# 3250                    (точка_NOUN, зрение_NOUN)    29
# 242          (правоохранительный_ADJ, орган_NOUN)    27
# 4142                 (кабинет_NOUN, министр_NOUN)    27
# 2639         (администрация_NOUN, президент_NOUN)    26
# 8205                  (внутренний_ADJ, дело_NOUN)    26
# 1070            (министерство_NOUN, оборона_NOUN)    25
# 4997                      (текущий_ADJ, год_NOUN)    24
# 1335                  (тысяча_NOUN, человек_NOUN)    24
# 2190                   (первый_ADJ, очередь_NOUN)    23
# 5713                  (последний_ADJ, время_NOUN)    23
# 906                  (главный_ADJ, редактор_NOUN)    23
# 7437        (национальный_ADJ, безопасность_NOUN)    23
# 19339             (конституционный_ADJ, суд_NOUN)    23
# 4389         (общественный_ADJ, организация_NOUN)    23
# 682                   (молодой_ADJ, человек_NOUN)    22
# 13415                 (миллиард_NOUN, рубль_NOUN)    22
# 5590             (заместитель_NOUN, министр_NOUN)    21
# 7994                    (последний_ADJ, год_NOUN)    21
# 2946                   (уголовный_ADJ, дело_NOUN)    21
# 3398             (глава_NOUN, правительство_NOUN)    21
# 3388             (глава_NOUN, администрация_NOUN)    21
# ...                                           ...   ...
# 36565        (руководство_NOUN, государство_NOUN)     1
# 36596             (добьется»_ADJ, Пятилетний_ADJ)     1
# 36588               (политика_NOUN, рвущийся_ADJ)     1
# 36577             (хороший_ADJ, специалисты»_ADJ)     1
# 36751                (министр_NOUN, реформа_NOUN)     1
# 36728                (четкий_ADJ, понимание_NOUN)     1
# 36702            (болезненный_ADJ, ситуация_NOUN)     1
# 36697            (сегодняшний_ADJ, ситуация_NOUN)     1
# 36696          (сохранение_NOUN, сегодняшний_ADJ)     1
# 36694               (социальный_ADJ, группа_NOUN)     1
# 36749          (бизнес_NOUN, проектирование_NOUN)     1
# 36746                   (реформа_NOUN, греф_NOUN)     1
# 36745         (технологизация_NOUN, реформа_NOUN)     1
# 36741                  (дорожный_ADJ, карта_NOUN)     1
# 36740                (понятный_ADJ, дорожный_ADJ)     1
# 36736          (министр_NOUN, правительство_NOUN)     1
# 36695              (группа_NOUN, сохранение_NOUN)     1
# 36693               (количество_NOUN, разный_ADJ)     1
# 36652           (консервация_NOUN, ситуация_NOUN)     1
# 36669                 (привычный_ADJ, образ_NOUN)     1
# 36664              (популярный_ADJ, реформа_NOUN)     1
# 36661                     (день_NOUN, легкий_ADJ)     1
# 36659            (технологический_ADJ, план_NOUN)     1
# 36653              (социальный_ADJ, область_NOUN)     1
# 36674  (фундаментальный_ADJ, преобразование_NOUN)     1
# 36690                  (слово_NOUN, реформа_NOUN)     1
# 36689              (прослойка_NOUN, человек_NOUN)     1
# 36688               (большой_ADJ, прослойка_NOUN)     1
# 36687                 (интерес_NOUN, большой_ADJ)     1
# 36679    (образование_NOUN, здравоохранение_NOUN)     1
#
# [21904 rows x 2 columns]

# %% [markdown]
# # FREQ PMI ETC

# %%
stopwords = set(nltk.corpus.stopwords.words('russian'))
model_lemm = Mystem()
texts_lenta = pd.read_csv("3000.csv")
corpus_list = list(texts_lenta['texts_3000'])

# %%
bigramFreqTable, trigramFreqTable,quadgram_freq,  bigramPMITable, trigramPMITable, quadragramPMITable = get_colloc_from_corpus_list(corpus_list, model_lemm, "rus")
# Out:
# 100%|██████████| 898/898 [00:12<00:00, 74.00it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-7f8216a53d68> in <module>()
# ----> 1 bigramFreqTable, trigramFreqTable,quadgram_freq,  bigramPMITable, trigramPMITable, quadragramPMITable = get_colloc_from_corpus_list(corpus_list, model_lemm, "rus")
#
# ~/Autotutor/processing_test_recommend/colloc_lib.py in get_colloc_from_corpus_list(corpus_list, lemm_model, lang)
#     198         return 0
#     199     bigramFreqTable, trigramFreqTable, quadgram_freq = get_freq_colloc(corpus_split_line)
# --> 200     bigramPMITable, trigramPMITable , quadragramPMITable= get_pmi_colloc(corpus_split_line)
#     201
#     202     return bigramFreqTable, trigramFreqTable,quadgram_freq,  bigramPMITable, trigramPMITable, quadragramPMITable
#
# ~/Autotutor/processing_test_recommend/colloc_lib.py in get_pmi_colloc(text_split)
#     167     bigrams = nltk.collocations.BigramAssocMeasures()
#     168     trigrams = nltk.collocations.TrigramAssocMeasures()
# --> 169     quadragram = nltk.metrics.QuadgramAssocMeasures
#     170     #quadragram = nltk.collocations.QuadgramAssocMeasures()
#     171
#
# AttributeError: module 'nltk.translate.metrics' has no attribute 'QuadgramAssocMeasures'

# %%
type(trigramFreqTable), type(quadgram_freq)

# %%
quadgram_freq

# %%
from nltk.metrics import ContingencyMeasures, BigramAssocMeasures, TrigramAssocMeasures

# %%
QuadgramAssocMeasures??????
