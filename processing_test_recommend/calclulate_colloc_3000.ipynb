# %%
import pandas as pd

# %%
from colloc_lib import get_colloc_from_corpus_list

# %%
texts_db = pd.read_csv("3000.csv")
texts_db.head()
# Out:
#    Unnamed: 0                                         texts_3000  \
# 0           0  Указом президента России Бориса Ельцина внесен...
# 1           1  В Харькове неизвестные изуродовали лицо депута...
# 2           2  Руководитель  следствия по делу  "Аэрофлота"  ...
# 3           3  Постоянный экономический рост позволит Китаю к...
# 4           4  В одном из ночных клубов Хмельницкого группа п...
#
#                                  same_word_list_3000 percent_3000
# 0  {'отмечать', 'изменение', 'иностранный', 'роль...        71,25
# 1  {'регион', 'серьезный', 'агентство', 'являться...  72,22222222
# 2  {'ставить', 'ход', 'фирма', 'отказываться', 'с...           74
# 3  {'внутренний', 'момент', 'сфера', 'слово', 'мн...  72,60273973
# 4  {'отмечать', 'повод', 'смерть', 'свидетель', '...  70,68965517

# %%
texts_list = list(texts_db['texts_3000'])

# %%
bigramFreqTable, trigramFreqTable,quadgram_freq,  bigramPMITable, trigramPMITable, quadragramPMITable, bigramChiTable, trigramChiTable = get_colloc_from_corpus_list(texts_list, "rus")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 898/898 [26:54<00:00,  1.80s/it]

# %%
quadragramPMITable
# Out:
#                                             quadragram        PMI
# 0           (искусствознание, вгик, союз, театральный)  42.027999
# 1                              (The, New, York, Times)  40.714245
# 2                   (вгик, союз, театральный, деятель)  40.706071
# 3            (замминистра, культура, григорий, ивлиев)  37.678621
# 4              (институт, искусствознание, вгик, союз)  37.504437
# 5    (государственный, институт, искусствознание, в...  35.541590
# 6                 (она, краткий, изложение, приводить)  33.571992
# 7             (глава, минэкономразвития, герман, греф)  32.060015
# 8          (начальник, генеральный, штаб, вооруженный)  31.882040
# 9                 (достоинство, и, деловой, репутация)  31.770851
# 10                         (мэр, москва, юрий, лужков)  31.600636
# 11              (объединять, комитет, начальник, штаб)  31.442937
# 12               (президент, украина, петр, порошенко)  31.368728
# ...
