# %%
from gensim.models.keyedvectors import FastTextKeyedVectors
#fasttext = FastTextKeyedVectors.load("D:/fasttext_word2vec/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model")
fasttext = FastTextKeyedVectors.load("/Users/nigula/input/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model")

# %%
from text_processing import get_text_map
from os import listdir
from os.path import join
import random
import json
from collections import OrderedDict
import numpy as np
import pandas as pd
from collections import OrderedDict

# %%
texts_lenta = pd.read_csv("./articles/music_lenta.csv")

# %%
texts_index = [0,
17,
26,
32,
98,
121,
130,133,
200,
231,240,316,331,334,336,366,371]

# %%
len(texts_index)
# Out:
# 17

# %%
text_maps_json_dict = {}
for tex_ind in texts_index:
    text_map = get_text_map(texts_lenta.iloc[tex_ind]['text'],unigramm_db_path ='./colloc/music_unigr_freq.json' , 
                            colloc_db_path = "/Users/nigula/Desktop/long_term_storage/colloc/music_smart_colloc_freq.json", raw_text_input=True)
    text_maps_json_dict[tex_ind] = text_map
    
#"/Users/nigula/Desktop/long_term_storage/colloc/music_smart_colloc_freq.json"
#"D:\input\music_smart_colloc_freq.json"

# %%
text_maps_json_dict[0]
# Out:
# OrderedDict([('lix', 0.6118),
#              ('ttr', 0.75),
#              ('overall_colloc_text',
#               [{0: [(0, 'расход'),
#                  (1, 'на проведение музыкальный конкурс'),
#                  (5, 'евровидение 2017 в киев'),
#                  (9, 'оказываться'),
#                  (10, 'предельно'),
#                  (11, 'высокий')]},
#                {1: [(0, 'о это в четверг'),
#                  (4, '11'),
#                  (5, 'май писать украинский'),
#                  (8, 'издание вести')]},
#                {2: [(0, 'украинец возмущать запредельный'),
#                  (3, 'гонорар артист'),
#                  (5, 'и ведущий'),
#                  (7, 'шоу'),
#                  (8, 'то что'),
#                  (10, 'почти весь'),
#                  (12, 'тендер'),
#                  (13, 'проводить в'),
#                  (15, 'сжимать'),
#                  (16, 'срок'),
#                  (17, 'по'),
#                  (18, 'сокращенный процедура'),
#                  (20, 'а также'),
#                  (22, 'явно'),
#                  (23, 'лишний неоправданный трата'),
#                  (26, 'в страна'),
#                  (28, 'где'),
#                  (29, 'идти'),
#                  (30, 'война'),
#                  (31, 'речь идти о'),
#                  (34, 'вооружать конфликт в донбасс'),
#                  (38, 'примечание лентыру а'),
#                  (41, 'большой часть население'),
#                  (44, 'не хватать'),
#                  (46, 'деньги'),
#                  (47, 'даже на'),
#                  (49, 'оплата коммуналки'),
#                  (51, 'говорить в'),
#                  (53, 'заметка')]},
#                {3: [(0, 'по'),
#                  (1, 'подсчет газета'),
#                  (3, 'на соревнование'),
#                  (5, 'быть тратить'),
#                  (7, '870'),
#                  (8, 'миллион'),
#                  (9, 'гривна 33 миллион'),
#                  (12, 'доллар')]},
#                {4: [(0, 'ровно'),
#                  (1, 'столько'),
#                  (2, 'закладывать в'),
#                  (4, 'проект госбюджет'),
#                  (6, 'украина'),
#                  (7, '2017 год на'),
#                  (10, 'дотация государственный угольный'),
#                  (13, 'шахта частичный покрытие'),
#                  (16, 'разница'),
#                  (17, 'в'),
#                  (18, 'себестоимость писать издание')]},
#                {5: [(0, 'по мнение'),
#                  (2, 'автор пять миллион'),
#                  (5, 'гривна 190 тысяча'),
#                  (8, 'доллар'),
#                  (9, 'тратить на'),
#                  (11, 'белый полотно'),
#                  (13, 'который'),
#                  (14, 'задрапировать'),
#                  (15, 'недостра'),
#                  (16, 'рядом с'),
#                  (18, 'место проведение конкурса'),
#                  (21, 'явно'),
#                  (22, 'можно быть бы'),
#                  (25, 'тратить'),
#                  (26, 'с'),
#                  (27, 'больший пользой')]},
#                {6: [(0, 'отмечать что'),
#                  (2, 'ткань оказываться непригодный'),
#                  (5, 'после первый'),
#                  (7, 'дождь')]},
#                {7: [(0, 'евровидение 2017 проходить в'), (4, 'киев')]},
#                {8: [(0, 'первый'),
#                  (1, 'полуфинал состояться 9'),
#                  (4, 'май второй'),
#                  (6, 'проводить'),
#                  (7, '11 май')]},
#                {9: [(0, 'финал намечать на 13'), (4, 'май')]}]),
#              ('sent_properties',
#               [0.2,
#                0.2,
#                0.024266827607358696,
#                0.03000229547540447,
#                0.0,
#                0.07131167644959036,
#                0.191510992676087]),
#              ('sentences_map',
#               [OrderedDict([('spec_sentence_features',
#                              OrderedDict([('negation', 0),
#                                           ('coreference', 0),
#                                           ('vozvr_verb', 0),
#                                           ('total_vozvr', 0),
#                                           ('prich', 0),
#                                           ('total_prich', 0),
#                                           ('deepr', 0),
#                                           ('total_deepr', 0),
#                                           ('case_complexity', 0),
#                                           ('total_case', 0),
#                                           ('mean_depend_length',
#                                            0.2090909090909091)])),
#                             ('syntax_prop',
#                              OrderedDict([('distances_list',
#                                            [9, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2]),
#                                           ('sent_vocab_imp',
#                                            3.2761321890194637)])),
#                             ('sentence_words',
#                              [OrderedDict([('word', 'Расходы'),
#                                            ('lemma', 'расход'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.338411134635427),
#                                                          ('nominal_index',
#                                                           '1')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'NOUN'),
#                                                          ('case', 'Nom')]))]),
#                               OrderedDict([('word', 'на'),
#                                            ('lemma', 'на'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.1816686495166347),
#                                                          ('nominal_index',
#                                                           '2')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'ADP')]))]),
#                               OrderedDict([('word', 'проведение'),
#                                            ('lemma', 'проведение'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.2876803816741029),
#                                                          ('nominal_index',
#                                                           '3')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'NOUN'),
#                                                          ('case', 'Acc')]))]),
#                               OrderedDict([('word', 'музыкального'),
#                                            ('lemma', 'музыкальный'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.338411134635427),
#                                                          ('nominal_index',
#                                                           '4')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'ADJ')]))]),
#                               OrderedDict([('word', 'конкурса'),
#                                            ('lemma', 'конкурс'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.338411134635427),
#                                                          ('nominal_index',
#                                                           '5')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'NOUN'),
#                                                          ('case', 'Gen')]))]),
#                               OrderedDict([('word', '«Евровидение'),
#                                            ('lemma', 'евровидение'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.2876803816741029),
#                                                          ('nominal_index',
#                                                           '6')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'PROPN')]))]),
#                               OrderedDict([('word', '2017»'),
#                                            ('lemma', '2017'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.25168633962928233),
#                                                          ('nominal_index',
#                                                           '8')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'ADJ')]))]),
#                               OrderedDict([('word', 'в'),
#                                            ('lemma', 'в'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf', 0),
#                                                          ('nominal_index',
#                                                           '9')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'ADP')]))]),
#                               OrderedDict([('word', 'Киеве'),
#                                            ('lemma', 'киев'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.2876803816741029),
#                                                          ('nominal_index',
#                                                           '10')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'PROPN')]))]),
#                               OrderedDict([('word', 'оказались'),
#                                            ('lemma', 'оказываться'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.2876803816741029),
#                                                          ('nominal_index',
#                                                           '11')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'VERB')]))]),
#                               OrderedDict([('word', 'предельно'),
#                                            ('lemma', 'предельно'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.338411134635427),
#                                                          ('nominal_index',
#                                                           '12')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'ADV')]))]),
#                               OrderedDict([('word', 'высокими'),
#                                            ('lemma', 'высокий'),
#                                            ('vocabulary_prop',
#                                             OrderedDict([('tf_idf',
#                                                           0.338411134635427),
#                                                          ('nominal_index',
#                                                           '13')])),
#                                            ('grammar_prop',
#                                             OrderedDict([('pos', 'ADJ')]))])]),
#                             ('collocation_index_list',
#                              [(0, ('расход', 36, 90.2)),
#                               (1,
#                                ('на проведение музыкальный конкурс',
#                                 6301.75,
#                                 66.325)),
#                               (5,
#                                ('евровидение 2017 в киев',
#                                 14419.25,
#                                 7853.150000000001)),
#                               (9, ('оказываться', 632, 155.1)),
#                               (10, ('предельно', 11, 17.1)),
#                               (11, ('высокий', 186, 483.3))]),
#                             ('collocation_vectors_list',
#                              [(0,
#                                ('расход', 36, 90.2),
#                                [[0.06441634893417358,
#                                  -0.06682262569665909,
#                                  -0.04025978222489357,
#                                  0.0301998071372509,
#                                  -0.0432300791144371,
#                                  -0.19613288342952728,
#                                  0.045779965817928314,
#                                  -0.04417695477604866,
#                                  0.18085253238677979,
#                                  -0.003155086189508438,
#                                  0.13258464634418488,
#                                  -0.03593701869249344,
#                                  -0.005347901955246925,
#                                  0.016542932018637657,
#                                  -0.018451210111379623,
#                                  0.0005701915943063796,
#                                  -0.11392262578010559,
#                                  0.047232840210199356,
#                                  0.016622010618448257,
#                                  -0.09928876161575317,
#                                  -0.012583010829985142,
#                                  0.03338193520903587,
#                                  0.060854244977235794,
#                                  -0.00348075688816607,
#                                  -0.00015174358850345016,
#                                  0.04268819838762283,
#                                  0.015010533854365349,
#                                  -0.04557902738451958,
#                                  -0.015568318776786327,
#                                  -0.09460889548063278,
#                                  -0.07870976626873016,
#                                  -0.010821729898452759,
#                                  -0.08491771668195724,
#                                  0.060842327773571014,
#                                  -0.001032268046401441,
#                                  -0.004294074606150389,
#                                  -0.031073225662112236,
#                                  -0.005221463739871979,
#                                  0.04687438905239105,
#                                  0.1072370857000351,
#                                  -0.013254311867058277,
#                                  -0.04653908684849739,
#                                  0.04041355475783348,
#                                  0.102894127368927,
#                                  0.053349778056144714,
#                                  -0.0022754112724214792,
#                                  -0.041855596005916595,
#                                  -0.024424584582448006,
#                                  -0.012904565781354904,
#                                  -0.030705101788043976,
#                                  0.06253837794065475,
#                                  0.04435429722070694,
#                                  -0.06854758411645889,
#                                  0.08352508395910263,
#                                  -0.012217625975608826,
#                                  -0.007753419224172831,
#                                  0.06574603915214539,
#                                  -0.012282097712159157,
#                                  0.05015173926949501,
#                                  -0.060630302876234055,
#                                  0.0859946459531784,
#                                  0.018871452659368515,
#                                  -0.05179864168167114,
#                                  -0.016830645501613617,
#                                  -0.08841139078140259,
#                                  -0.0830017700791359,
#                                  -0.10258735716342926,
#                                  0.026303431019186974,
#                                  -0.016796303912997246,
#                                  -0.05696843937039375,
#                                  -0.11518097668886185,
#                                  0.008637954480946064,
#                                  0.02742023579776287,
#                                  0.024393856525421143,
#                                  0.05256018415093422,
#                                  0.01930646412074566,
#                                  0.03941724821925163,
#                                  -0.03296837955713272,
#                                  0.046125441789627075,
#                                  -0.019566858187317848,
#                                  0.12748469412326813,
#                                  -0.07460178434848785,
#                                  0.045790914446115494,
#                                  -0.06047707796096802,
#                                  -0.07425804436206818,
#                                  0.03096303530037403,
#                                  -0.014172722585499287,
#                                  0.03350002318620682,
#                                  0.013809154741466045,
#                                  -0.07957623898983002,
#                                  -0.07218228280544281,
#                                  -0.09328857809305191,
#                                  -0.03531539812684059,
#                                  -0.019300445914268494,
#                                  -0.025772783905267715,
#                                  0.0026729959063231945,
#                                  0.008522349409759045,
#                                  -0.045392390340566635,
#                                  0.0948028489947319,
#                                  0.020462367683649063,
#                                  0.0008773283916525543,
#                                  -0.005118242930620909,
#                                  -0.07485688477754593,
#                                  -0.06452499330043793,
#                                  -0.05964779481291771,
#                                  0.11131126433610916,
#                                  -0.06846220046281815,
#                                  0.04918575659394264,
#                                  0.022185783833265305,
#                                  0.03613855317234993,
#                                  -0.04160292074084282,
#                                  0.046320315450429916,
#                                  -0.06192207708954811,
#                                  0.019113972783088684,
#                                  0.00330992229282856,
#                                  0.010313687846064568,
#                                  -0.06375472247600555,
#                                  0.023522071540355682,
#                                  -0.07863510400056839,
#                                  0.08156087249517441,
#                                  -0.06767337024211884,
#                                  0.03493773937225342,
#                                  -0.09032724797725677,
#                                  0.09813303500413895,
#                                  0.002819680143147707,
#                                  -0.03174132853746414,
#                                  0.07229267060756683,
#                                  -0.001477863872423768,
#                                  -0.017975296825170517,
#                                  -0.013388381339609623,
#                                  -0.02469198778271675,
#                                  -0.04846381023526192,
#                                  0.014852353371679783,
#                                  0.047873396426439285,
#                                  0.015555075369775295,
#                                  -0.08601146191358566,
#                                  0.038203392177820206,
#                                  -0.06378979235887527,
#                                  -0.07796836644411087,
#                                  -0.036850571632385254,
#                                  0.019898882135748863,
#                                  0.006769544444978237,
#                                  -0.065180703997612,
#                                  0.04219687730073929,
#                                  -0.030886569991707802,
#                                  -0.014310603961348534,
#                                  -0.04289771616458893,
#                                  0.08099919557571411,
#                                  0.016376402229070663,
#                                  -0.01726214773952961,
#                                  0.03699464350938797,
#                                  -0.12682338058948517,
#                                  -0.04197482764720917,
#                                  0.0010758424177765846,
#                                  0.12522940337657928,
#                                  0.08311554789543152,
#                                  -0.09816433489322662,
#                                  0.04089847207069397,
#                                  -0.010283936746418476,
#                                  0.05919245257973671,
#                                  0.04976758360862732,
#                                  0.002809408586472273,
#                                  -0.015785101801156998,
#                                  -0.028145872056484222,
#                                  -0.08768422901630402,
#                                  0.03502868488430977,
#                                  0.05826113745570183,
#                                  0.043979231268167496,
#                                  0.05781122297048569,
#                                  0.007260332349687815,
#                                  -0.06061634421348572,
#                                  -0.0844758078455925,
#                                  0.016685698181390762,
#                                  0.011715329252183437,
#                                  0.038495469838380814,
#                                  0.07092899829149246,
#                                  -0.02418394759297371,
#                                  0.016411732882261276,
#                                  0.013041330501437187,
#                                  -0.008817602880299091,
#                                  -0.18266817927360535,
#                                  -0.000902536790817976,
#                                  -0.09284590929746628,
#                                  0.11731941998004913,
#                                  -0.010177072137594223,
#                                  -0.04654748737812042,
#                                  0.1635960191488266,
#                                  -0.015928780660033226,
#                                  0.0509645901620388,
#                                  0.05706162750720978,
#                                  0.056668102741241455,
#                                  0.07051366567611694,
#                                  -0.0008071820484474301,
#                                  -0.04396447911858559,
#                                  0.0787387266755104,
#                                  0.043771836906671524,
#                                  -0.06943546235561371,
#                                  -0.023374268785119057,
#                                  0.008751565590500832,
#                                  0.026482699438929558,
#                                  0.08802294731140137,
#                                  0.031808264553546906,
#                                  0.08337146043777466,
#                                  0.014721967279911041,
#                                  0.07232814282178879,
#                                  -0.005762137472629547,
#                                  -6.040627704351209e-05,
#                                  -0.006097391713410616,
#                                  -0.029751094058156013,
#                                  -0.030482057482004166,
#                                  0.10771877318620682,
#                                  -0.03591705486178398,
#                                  -0.051658451557159424,
#                                  -0.04667419195175171,
#                                  -0.012181783095002174,
#                                  0.10592567920684814,
#                                  -0.008972394280135632,
#                                  -0.004212389700114727,
#                                  -0.025936607271432877,
#                                  0.04689577966928482,
#                                  0.01554807461798191,
#                                  -0.05316406115889549,
#                                  -0.04475189745426178,
#                                  -0.0207517109811306,
#                                  0.026664435863494873,
#                                  0.09839722514152527,
#                                  -0.04330572485923767,
#                                  0.053906165063381195,
#                                  -0.05167701095342636,
#                                  0.06444621831178665,
#                                  0.034213483333587646,
#                                  0.0018390279728919268,
#                                  0.06444092839956284,
#                                  0.07593275606632233,
#                                  0.11310553550720215,
#                                  0.09527567028999329,
#                                  -0.13179709017276764,
#                                  -0.0470731221139431,
#                                  0.04202479496598244,
#                                  -0.06748460233211517,
#                                  0.05677312985062599,
#                                  0.02359514869749546,
#                                  -0.0323931910097599,
#                                  0.040264859795570374,
#                                  -0.06537094712257385,
#                                  0.019766908138990402,
#                                  0.055368728935718536,
#                                  -0.07265635579824448,
#                                  -0.02244771644473076,
#                                  0.0881214365363121,
#                                  -0.006347703281790018,
#                                  0.0036178904119879007,
#                                  0.004396411124616861,
#                                  -0.002912461059167981,
#                                  0.047157444059848785,
#                                  -0.09456023573875427,
#                                  0.014316028915345669,
#                                  -0.022858692333102226,
#                                  0.021138565614819527,
#                                  -0.012448707595467567,
#                                  0.06423062086105347,
#                                  -0.0008258646121248603,
#                                  -0.03678460791707039,
#                                  -0.04816463217139244,
#                                  0.09481421113014221,
#                                  -0.02989307977259159,
#                                  0.0856044590473175,
#                                  -0.0038113559130579233,
#                                  -0.02668066881597042,
#                                  0.019914638251066208,
#                                  0.02781689539551735,
#                                  0.07506585121154785,
#                                  0.02452872134745121,
#                                  -0.050331104546785355,
#                                  0.00395785691216588,
#                                  0.06535857915878296,
#                                  0.011411056853830814,
#                                  -0.011407708749175072,
#                                  0.0773329809308052,
#                                  0.00813873391598463,
#                                  -0.05124351754784584,
#                                  0.023676155135035515,
#                                  0.14182880520820618,
#                                  -0.015193942934274673,
#                                  0.024253197014331818,
#                                  -0.1208314448595047,
#                                  0.07586658746004105,
#                                  -0.03730864077806473,
#                                  0.03364118933677673,
#                                  -0.02821282297372818,
#                                  -0.007369206286966801,
#                                  0.0666208416223526,
#                                  -0.02712089568376541,
#                                  -0.0087001733481884,
#                                  -0.01201635506004095,
#                                  0.0049228668212890625,
#                                  0.03791535273194313,
#                                  -0.003446024376899004,
#                                  -0.07907542586326599,
#                                  0.01526574231684208]]),
#                               (1,
#                                ('на проведение музыкальный конкурс',
#                                 6301.75,
#                                 66.325),
#                                [[0.009193502133712173,
#                                  -0.0036910964408889413,
#                                  -0.04098232957767323,
#                                  0.027354208286851645,
#                                  -0.02349625714123249,
#                                  -0.02197554975282401,
#                                  0.03571407694835216,
#                                  0.0007854613941162825,
#                                  0.013841204810887575,
#                                  0.021937734447419643,
#                                  -0.007078422233462334,
#                                  0.025680480641312897,
#                                  -0.048583883326500654,
#                                  -0.0006990313995629549,
#                                  -0.029286104952916503,
#                                  0.030925295897759497,
#                                  -0.01642171898856759,
#                                  0.016702255757991225,
#                                  -0.006444886326789856,
#                                  0.00764555879868567,
#                                  0.04618078382918611,
#                                  -0.020564299542456865,
#                                  -0.005412373226135969,
#                                  0.06176686938852072,
#                                  0.026130274403840303,
#                                  -0.005340126983355731,
#                                  -0.025987084489315748,
#                                  0.021141954697668552,
#                                  -0.0004794615088030696,
#                                  -0.0061593116843141615,
#                                  -0.05541347770486027,
#                                  -0.011832961579784751,
#                                  -0.02110724928206764,
#                                  -0.03119611641159281,
#                                  -0.006301620043814182,
#                                  0.014376227743923664,
#                                  -0.027435667347162962,
#                                  0.037464340683072805,
#                                  -0.03665044717490673,
#                                  0.0068099560448899865,
#                                  0.03876866539940238,
#                                  -0.04172151512466371,
#                                  0.0019035665318369865,
#                                  0.028829612536355853,
#                                  0.00937015749514103,
#                                  -0.0338990595046198,
#                                  0.004244792740792036,
#                                  0.007708972814725712,
#                                  0.0159706580452621,
#                                  0.012787918443791568,
#                                  -0.03516595857217908,
#                                  0.007651433814316988,
#                                  0.02723882207646966,
#                                  -0.028226462192833424,
#                                  0.01718940236605704,
#                                  -0.00020779750775545835,
#                                  -0.0020648451754823327,
#                                  0.026390901766717434,
#                                  0.0046649223659187555,
#                                  -0.029019806999713182,
#                                  0.016333401203155518,
#                                  0.019495706539601088,
#                                  0.05348422494716942,
#                                  0.012388780014589429,
#                                  -0.05650091916322708,
#                                  0.008384780492633581,
#                                  -0.06379123218357563,
#                                  -0.021146372659131885,
#                                  0.00991495733615011,
#                                  -0.02596553531475365,
#                                  0.012984788743779063,
#                                  0.0011208972427994013,
#                                  0.018542574252933264,
#                                  0.030997976660728455,
#                                  0.03347807674435899,
#                                  0.00019197908113710582,
#                                  0.049913179653231055,
#                                  -0.025497438036836684,
#                                  0.029506178107112646,
#                                  0.0529393854085356,
#                                  0.028839569306001067,
#                                  -0.01353907585144043,
#                                  0.011792551726102829,
#                                  0.012555722147226334,
#                                  0.042540334892692044,
#                                  -0.05988424317911267,
#                                  0.021184843382798135,
#                                  0.026633681263774633,
#                                  0.03484547510743141,
#                                  -0.004769491613842547,
#                                  -0.019256660249084234,
#                                  0.02338454034179449,
#                                  0.006461160257458687,
#                                  0.04279654868878424,
#                                  -0.05075848335400224,
#                                  -0.040644001943292096,
#                                  -0.025238761329092085,
#                                  0.020595974288880825,
#                                  -0.06121895252726972,
#                                  0.016042527626268566,
#                                  0.03290860168635845,
#                                  -0.006055160891264677,
#                                  0.023693091701716185,
#                                  0.06354197929613292,
#                                  0.015437222173204646,
#                                  0.010449043475091457,
#                                  -0.03405172692146152,
#                                  0.01682510973296303,
#                                  0.009160211309790611,
#                                  0.06199821108020842,
#                                  0.00015116343274712563,
#                                  0.0036175937857478857,
#                                  0.012086893140804023,
#                                  0.0092273986665532,
#                                  0.005598414572887123,
#                                  0.030608645640313625,
#                                  0.010474118636921048,
#                                  0.0034568302799016237,
#                                  -0.02155645447783172,
#                                  -0.017257755058381008,
#                                  0.01879189832834527,
#                                  -0.01887665968388319,
#                                  0.030266493908129632,
#                                  -0.032492624362930655,
#                                  0.029065160546451807,
#                                  -0.04239438474178314,
#                                  -0.05383608606643975,
#                                  0.028479300322942436,
#                                  -0.05627359822392464,
#                                  -0.015154698165133595,
#                                  0.005263684790406842,
#                                  0.024767583701759577,
#                                  0.05353845312492922,
#                                  0.05613802280277014,
#                                  -0.019381058169528842,
#                                  -0.04882586537860334,
#                                  0.014338835200760514,
#                                  -0.012967119459062815,
#                                  -0.03503283113241196,
#                                  0.011293686744465958,
#                                  0.03727380000054836,
#                                  -0.016320833936333656,
#                                  -0.005890423897653818,
#                                  -0.04809213522821665,
#                                  0.048899183981120586,
#                                  0.020139122381806374,
#                                  -0.024243324412964284,
#                                  0.004874671692959964,
#                                  0.06404872820712626,
#                                  -0.015388379455544055,
#                                  -0.0054150334326550364,
#                                  -0.022470387280918658,
#                                  0.054369412537198514,
#                                  0.008006559917703271,
#                                  0.03021507919766009,
#                                  -0.010798926232382655,
#                                  -0.007486606398742879,
#                                  0.016437171027064323,
#                                  0.018410547636449337,
#                                  0.030624442268162966,
#                                  -0.008994035888463259,
#                                  1.2617558240890503e-05,
#                                  -0.020966765994671732,
#                                  -0.04352079750970006,
#                                  -0.006206009711604565,
#                                  -0.04274493781849742,
#                                  0.03131489991210401,
#                                  -0.012304729549214244,
#                                  0.03446710994467139,
#                                  0.014995418954640627,
#                                  -0.05340866860933602,
#                                  -0.0012344876304268837,
#                                  0.011890910798683763,
#                                  0.04338485316839069,
#                                  -0.03276143508264795,
#                                  0.023057296872138977,
#                                  -0.017116769682615995,
#                                  0.02039231255184859,
#                                  0.04412661725655198,
#                                  -0.012951262353453785,
#                                  0.013104010839015245,
#                                  0.015882516046985984,
#                                  0.04276957054389641,
#                                  -0.019745651865378022,
#                                  0.0048547491896897554,
#                                  -0.023683644190896302,
#                                  0.011597486212849617,
#                                  -0.03644228633493185,
#                                  0.020995265746023506,
#                                  -0.019690905697643757,
#                                  0.02026748948264867,
#                                  0.016876100562512875,
#                                  -0.03593274997547269,
#                                  0.008262082934379578,
#                                  0.028578220400959253,
#                                  0.025117042940109968,
#                                  -0.041329929255880415,
#                                  0.03271337249316275,
#                                  0.009440533525776118,
#                                  0.002999783493578434,
#                                  0.028623158112168312,
#                                  -0.032205577939748764,
#                                  -0.024051907181274146,
#                                  0.006038947380147874,
#                                  0.000579342246055603,
#                                  0.01826662836538162,
#                                  0.00523142539896071,
#                                  0.060903960606083274,
#                                  -0.01834585430333391,
#                                  -0.017439582850784063,
#                                  -0.016747728921473026,
#                                  0.01612421660684049,
#                                  -0.04650251101702452,
#                                  0.016845949925482273,
#                                  0.02362856175750494,
#                                  -0.039946830831468105,
#                                  0.05377723602578044,
#                                  -0.01547730527818203,
#                                  0.01278918289244757,
#                                  -0.00889291032217443,
#                                  0.004508106037974358,
#                                  -0.038869307725690305,
#                                  0.001553625101223588,
#                                  0.04081284598214552,
#                                  0.0035340161994099617,
#                                  0.030598734272643924,
#                                  -0.013980693591292948,
#                                  0.043494795565493405,
#                                  -0.004923171363770962,
#                                  0.006290753837674856,
#                                  -0.024459336418658495,
#                                  -0.02653056720737368,
#                                  -0.002603605855256319,
#                                  -0.01262964925263077,
#                                  0.01732703414745629,
#                                  -0.033868011785671115,
#                                  0.02830788167193532,
#                                  0.015029524452984333,
#                                  0.01077482633991167,
#                                  0.038034260272979736,
#                                  -0.03782240767031908,
#                                  -0.051774101331830025,
#                                  0.015008318237960339,
#                                  0.005099689122289419,
#                                  0.038791444851085544,
#                                  0.04631099896505475,
#                                  0.007353659486398101,
#                                  -0.018762283958494663,
#                                  -0.00753920606803149,
#                                  0.016986237140372396,
#                                  -0.036821731831878424,
#                                  -0.015262673143297434,
#                                  -0.014504311606287956,
#                                  0.01176455314271152,
#                                  -0.037830061512067914,
#                                  0.021487477933987975,
#                                  -0.011204108479432762,
#                                  0.008447106287349015,
#                                  -0.04570215509738773,
#                                  0.015882632636930794,
#                                  -0.01040480681695044,
#                                  0.028394719236530364,
#                                  0.009304369799792767,
#                                  0.015292268712073565,
#                                  -0.021573456935584545,
#                                  -0.03026795224286616,
#                                  -0.0030520748114213347,
#                                  -0.04019793355837464,
#                                  0.00030816951766610146,
#                                  0.03710853197844699,
#                                  -0.021320103434845805,
#                                  -0.053499278612434864,
#                                  -0.06405002810060978,
#                                  0.04595550429075956,
#                                  0.03650885820388794,
#                                  0.025151520501822233,
#                                  -0.020010497886687517,
#                                  -0.02181438682600856,
#                                  0.040864600809072726,
#                                  0.06675959844142199,
#                                  -0.021621448824589606,
#                                  0.06294624553993344,
#                                  0.009268494555726647,
#                                  0.06429677363485098,
#                                  -0.022018908290192485,
#                                  -0.02393155958270654,
#                                  -0.03992335469229147,
#                                  -0.008232608903199434,
#                                  0.03186958143487573,
#                                  0.06568038556724787,
#                                  0.018748003290966153,
#                                  0.0167992333881557,
#                                  -0.01872959197498858,
#                                  0.0370444874279201,
#                                  -0.030650343280285597,
#                                  0.03793319978285581,
#                                  -0.001328140962868929,
#                                  -0.0388287587556988,
#                                  -0.07376539544202387,
#                                  0.005879233358427882]]),
#                               (5,
#                                ('евровидение 2017 в киев',
#                                 14419.25,
#                                 7853.150000000001),
#                                [[0.01610186163452454,
#                                  -0.001012407839880325,
#                                  -0.03645709328338853,
#                                  0.02764251171174692,
#                                  -0.032468501609400846,
#                                  -0.035863670738763176,
#                                  0.00044154279748909175,
#                                  -0.028807268856326118,
#                                  -0.002637883328134194,
#                                  0.00161072565606446,
#                                  0.018232863454613835,
#                                  -0.014173585514072329,
#                                  -0.013045106585195754,
#                                  0.037293890898581594,
#                                  -0.005371606230255566,
#                                  -0.002008102987019811,
#                                  0.025203013647114858,
#                                  -0.019637884630355984,
#                                  0.00093193152861204,
#                                  -0.030690701511048246,
#                                  -0.004342004809586797,
#                                  -0.02662288592910045,
#                                  0.03594826837070286,
#                                  0.03832208410312887,
# ...
#                                  0.09787339717149734,
#                                  -0.013250879012048244,
#                                  0.0034630305599421263,
#                                  0.04162653908133507,
#                                  -0.0900377482175827,
#                                  -0.021775608882308006,
#                                  -0.021015768870711327,
#                                  -0.10928729921579361,
#                                  0.040442872792482376,
#                                  -0.007657029200345278,
#                                  -0.0634969100356102,
#                                  0.11471578478813171,
#                                  -0.07875978946685791,
#                                  0.08112376183271408,
#                                  0.009284601546823978,
#                                  -0.025762926787137985,
#                                  -0.0903019905090332,
#                                  -0.01595899648964405,
#                                  0.027031581848859787,
#                                  -0.04223508760333061,
#                                  -0.029710745438933372,
#                                  0.031327348202466965,
#                                  0.021017875522375107,
#                                  -0.08537720143795013,
#                                  0.10241107642650604,
#                                  -0.005544679705053568,
#                                  -0.014438350684940815,
#                                  0.06964250653982162,
#                                  -0.08947575092315674,
#                                  0.05255943909287453,
#                                  -0.08202467858791351,
#                                  -0.028755009174346924,
#                                  0.0440942719578743,
#                                  0.04065006971359253,
#                                  -0.06832658499479294,
#                                  0.010283065028488636,
#                                  -0.013711581937968731,
#                                  -0.0864654928445816,
#                                  0.07959526032209396,
#                                  0.024564411491155624,
#                                  -0.023089883849024773,
#                                  0.04963931813836098,
#                                  -0.08936195075511932,
#                                  -0.0556638240814209,
#                                  0.05805978178977966,
#                                  0.05982987955212593,
#                                  -0.00817535538226366,
#                                  0.1338168829679489,
#                                  0.02824295125901699,
#                                  0.06481288373470306,
#                                  0.11067315191030502,
#                                  -0.011624922975897789,
#                                  0.007355404086410999,
#                                  -0.08804605901241302,
#                                  0.01355335209518671,
#                                  -0.006269155070185661,
#                                  -0.06338803470134735,
#                                  0.011600309051573277,
#                                  -0.09939999878406525,
#                                  0.07752212136983871,
#                                  0.0030500588472932577,
#                                  0.13130581378936768,
#                                  -0.08492909371852875,
#                                  -0.07715900987386703,
#                                  0.03660964593291283,
#                                  -0.09889405220746994,
#                                  -0.054038047790527344,
#                                  0.0696454718708992,
#                                  0.012043403461575508,
#                                  0.013423703610897064,
#                                  -0.042697008699178696,
#                                  0.030467113479971886,
#                                  -0.06812260299921036,
#                                  -0.006137649994343519,
#                                  -0.010347667150199413,
#                                  -0.0889454111456871,
#                                  0.01591353490948677,
#                                  0.0005408914294093847,
#                                  -0.03552136942744255,
#                                  -0.11581001430749893,
#                                  0.009664448909461498,
#                                  -0.023774651810526848,
#                                  0.07306833565235138,
#                                  -0.05145753547549248,
#                                  -0.08619891852140427,
#                                  -0.08900199830532074,
#                                  0.0826401337981224,
#                                  -0.02861110493540764,
#                                  0.021537207067012787,
#                                  0.023531362414360046,
#                                  0.04661652073264122,
#                                  -0.00684257410466671,
#                                  0.0871119350194931,
#                                  0.07597390562295914,
#                                  -0.040364108979701996,
#                                  0.08410350233316422,
#                                  -0.02995566464960575,
#                                  0.03070487082004547,
#                                  -0.041066478937864304,
#                                  0.14387314021587372,
#                                  0.05168112739920616,
#                                  0.03600839152932167,
#                                  0.11284913867712021,
#                                  0.053119875490665436,
#                                  -0.0007287237094715238,
#                                  -0.042557042092084885,
#                                  0.005012082401663065,
#                                  -0.024624962359666824,
#                                  -0.03488601744174957,
#                                  0.06734120100736618,
#                                  0.0006587280659005046,
#                                  -0.07841207087039948,
#                                  -0.08176795393228531,
#                                  0.06386533379554749,
#                                  -0.012261408381164074,
#                                  0.009723827242851257,
#                                  0.046038445085287094,
#                                  0.042767483741045,
#                                  0.019086001440882683,
#                                  0.04783831164240837,
#                                  0.04433589056134224,
#                                  0.07216151803731918,
#                                  0.012277444824576378,
#                                  -0.0014088260941207409,
#                                  0.0019344516331329942,
#                                  -0.012040702626109123,
#                                  -0.007358004804700613,
#                                  -0.046397335827350616,
#                                  0.02181803248822689,
#                                  0.020235970616340637,
#                                  0.00979157816618681,
#                                  0.03715080767869949,
#                                  0.015628186985850334,
#                                  0.045141495764255524,
#                                  -0.03829525038599968,
#                                  0.10783848166465759,
#                                  -0.04186160862445831,
#                                  0.09825693815946579,
#                                  0.05762062221765518,
#                                  0.05663848668336868,
#                                  -0.10311754792928696,
#                                  -0.1360408365726471,
#                                  0.04045799747109413,
#                                  0.015066669322550297,
#                                  0.08423852175474167,
#                                  -0.016552142798900604,
#                                  -0.022534558549523354,
#                                  0.08078838884830475,
#                                  -0.0725303590297699,
#                                  -0.12791365385055542,
#                                  0.012684949673712254,
#                                  0.04880012944340706,
#                                  -0.00996834971010685,
#                                  0.03494694456458092,
#                                  -0.029948143288493156,
#                                  0.0015849975170567632,
#                                  0.0615776926279068,
#                                  0.15887446701526642,
#                                  0.003567334497347474,
#                                  0.01619805209338665,
#                                  -0.03137648478150368,
#                                  0.06617550551891327,
#                                  0.022639157250523567,
#                                  -0.01773134618997574,
#                                  0.010852478444576263,
#                                  -0.04422038793563843,
#                                  -0.06647080928087234,
#                                  -0.012400624342262745,
#                                  0.026765765622258186,
#                                  -0.012319756671786308,
#                                  -0.01663651131093502,
#                                  0.03612838685512543,
#                                  -0.08258675783872604,
#                                  0.08160277456045151,
#                                  -0.06986889243125916,
#                                  0.004133764188736677,
#                                  -0.05841929465532303,
#                                  0.01393012423068285,
#                                  -0.033520981669425964,
#                                  -0.024074500426650047,
#                                  -0.02653549239039421,
#                                  -0.04805523157119751,
#                                  0.00488115381449461,
#                                  -0.07235933840274811,
#                                  -0.012601643800735474,
#                                  0.09068236500024796,
#                                  0.04199869930744171,
#                                  0.04066919535398483,
#                                  -0.07274184376001358,
#                                  0.01813795417547226,
#                                  -0.059230174869298935,
#                                  -0.03952644392848015,
#                                  0.13210268318653107,
#                                  -0.07373719662427902,
#                                  0.06619463860988617,
#                                  -0.09736672788858414,
#                                  -0.0194795373827219,
#                                  0.02813303843140602,
#                                  0.06517501920461655,
#                                  0.025996627286076546,
#                                  -0.07825244218111038,
#                                  -0.02294206991791725,
#                                  -0.036497630178928375,
#                                  0.02902866154909134,
#                                  -0.013000664301216602,
#                                  0.0010267442557960749,
#                                  -0.01030132919549942,
#                                  0.023384790867567062,
#                                  -0.006257060915231705,
#                                  0.03519342467188835,
#                                  -0.04825982451438904,
#                                  -0.05469369888305664,
#                                  -0.004170640371739864,
#                                  -0.043089359998703,
#                                  -0.07191197574138641,
#                                  0.017113342881202698,
#                                  0.05436761677265167,
#                                  -0.020116088911890984,
#                                  -0.035581909120082855,
#                                  -0.043774768710136414,
#                                  0.04962360858917236,
#                                  -0.04702006280422211,
#                                  -0.05509871989488602,
#                                  0.030980432406067848,
#                                  0.07419346272945404,
#                                  0.06761862337589264,
#                                  0.026372620835900307,
#                                  -0.029665181413292885,
#                                  0.036095552146434784,
#                                  0.004216733388602734,
#                                  0.03557487204670906,
#                                  0.03448447957634926,
#                                  -0.09847454726696014,
#                                  0.012393354438245296,
#                                  0.09798196703195572,
#                                  0.08041504770517349,
#                                  -0.08278181403875351,
#                                  0.022539328783750534,
#                                  -0.04888857901096344,
#                                  -0.041250403970479965,
#                                  -0.03273862600326538,
#                                  -0.13943703472614288,
#                                  0.0821681022644043,
#                                  0.002607117174193263,
#                                  0.04106024652719498,
#                                  0.06823518127202988,
#                                  0.04577130824327469,
#                                  -0.06972771137952805,
#                                  0.08304215222597122,
#                                  0.010723045095801353,
#                                  -0.15066291391849518,
#                                  0.028066257014870644,
#                                  0.033082399517297745,
#                                  0.037428244948387146,
#                                  0.016584981232881546,
#                                  0.092325858771801,
#                                  0.03623113036155701,
#                                  0.020801058039069176,
#                                  0.00993097759783268,
#                                  -0.008082869462668896,
#                                  -0.038005221635103226,
#                                  -0.0017842395463958383,
#                                  -0.032201096415519714,
#                                  -0.04326999932527542,
#                                  -0.0008471535984426737,
#                                  0.012588739395141602,
#                                  0.037403181195259094,
#                                  0.033910300582647324,
#                                  0.00633570272475481,
#                                  0.12764710187911987,
#                                  0.004379123914986849,
#                                  -0.003444559406489134,
#                                  -0.0034075623843818903,
#                                  -0.036341775208711624,
#                                  0.07587309181690216,
#                                  -0.07964321970939636,
#                                  0.07838106155395508,
#                                  0.010130183771252632,
#                                  0.04047713428735733,
#                                  0.008810073137283325,
#                                  -0.007377828471362591,
#                                  -0.016465822234749794,
#                                  0.1292351484298706,
#                                  -0.0032116000074893236,
#                                  0.12241852283477783,
#                                  -0.08937728404998779,
#                                  -0.049144744873046875,
#                                  0.01140077505260706,
#                                  -0.049922067672014236]])])])]),
#              ('sentences_count', 0.1),
#              ('average_sentence_length', 0.166)])

# %%
question_text_sent_collocind_dict = {"0":{'0':[9,11],'2':[26,35],'5':[13,27]},
                                     "17":{'0':[7,18],'2':[8,19],'4':[2,16],'8':[7,25],'10':[14,24],'12':[9,24]},
                                     "26":{'0':[6,19],'5':[5,11],'7':[0,6],'13':[13,27]},
                                     "32":{'3':[9,20],'5':[5,17],'14':[6,17],'18':[3,19]},
                                    "98":{'0':[11,16],'4':[3,6],'5':[1,12],'8':[7,12]},
                                    "121":{'1':[2,7],'3':[5,19],'4':[0,15],'4':[0,15],'6':[13,17],'11':[0,5]},#'0':[11,16],
                                    "130":{'0':[17,28],'1':[0,7],'4':[1,8],'5':[6,10],'8':[15,19],'9':[12,28],'16':[0,12]},#,'3':[2,9]
                                    "133":{'2':[19,35],'6':[8,13],'8':[3,12],'9':[7,16],'18':[8,19],'20':[0,8],'20':[0,8],'40':[11,20],'49':[0,15]},
                                     "200":{'0':[11,14],'2':[11,17],'4':[0,15],'10':[0,10],'12':[5,12]},
                                      "231":{'2':[0,7],'4':[0,19],'7':[0,12],'12':[13,30]},
                                    "240":{'1':[0,13],'11':[0,8],'15':[5,20]},
                                     "316":{'0':[12,20],'5':[8,13],'7':[9,20],'11':[20,27]},
                                     "331":{'2':[14,23],'4':[4,12],'10':[4,14]},"334":{'1':[4,10],'2':[0,3],'5':[4,12],'8':[1,9]},
                                     "336":{'1':[0,10],'7':[0,9],'10':[1,7],'13':[3,5]},"366":{'0':[0,4],'1':[0,12],'5':[15,24],'8':[8,20],'10':[0,15],'11':[0,18],'15':[2,11]},
                                     "371":{'0':[9,21],'2':[13,20],'3':[11,25],'6':[2,7],'12':[0,16],'21':[0,30]}}

# %%
list(question_text_sent_collocind_dict.keys())
# Out:
# ['0',
#  '17',
#  '26',
#  '32',
#  '98',
#  '121',
#  '130',
#  '133',
#  '200',
#  '231',
#  '240',
#  '316',
#  '331',
#  '334',
#  '336',
#  '366',
#  '371']

# %% [raw]
# answers_dict = {}
# text_ind_keys = list(question_text_sent_collocind_dict.keys())
# text_ind_keys = [int(numb) for numb in text_ind_keys]
# text_ind_keys.sort()
# for key in text_ind_keys:
#     answers_dict[key] = OrderedDict()
#     key_list = list(question_text_sent_collocind_dict[str(key)].keys())
#     key_list = [int(numb) for numb in key_list]
#     print("orig", key_list)
#     key_list.sort()
#     print("sorted",key_list)
#     for setn_keys in key_list:
#         answers_dict[key][setn_keys] = True
# answers_dict

# %%
len(list(ans_dict_enze.keys())), len(list(question_text_sent_collocind_dict.keys()))
# Out:
# (17, 17)

# %%
texts_lenta.iloc[371]['text']
# Out:
# 'Вокалист американской рок-группы Limp Bizkit Фред Дерст откликнулся на призыв главы Крыма Сергея Аксенова к мировым знаменитостям, изъявив желание обосноваться на полуострове. Об этом сообщают в четверг, 8 октября, «Известия». В письме музыканта в адрес администрации Крыма говорится, что он «был бы счастлив», получив российский паспорт, купить «симпатичный домик в Крыму». Дерст, по его словам, намерен жить на полуострове по полгода, снимая там фильмы и сериалы, которые бы позволили вывести Россию «на высокий уровень в этом бизнесе». Таким образом вокалист Limp Bizkit хочет стать «частью великого будущего Крыма и России». Дерст отмечает, что не может отказаться от гражданства США, поскольку в Лос-Анджелесе живет его сын. Однако он обещает «привлечь в Россию больше американцев». «Я могу помочь американцам понять, как прекрасна Россия. Я буду создавать фильмы, сериалы, музыку, новые бренды в Крыму, но при этом мне необходимо иметь два паспорта — это важно. Я думаю, проблем с этим не будет», — приводят «Известия» цитату из письма. Для реализации своих замыслов Дерст рассчитывает на поддержку правительства. В его планах, помимо прочего, организация кинофестиваля в Крыму и создание киностудии, что позволило бы привлечь к полуострову «невероятное внимание мирового сообщества». В будущем музыкант не исключает, что займется в России политикой, чтобы «помочь многим людям и вдохновить их». Он также надеется на встречу с президентом России Владимиром Путиным. «Я думаю, что я мог бы стать другом президента Путина. Уверен в этом... Я думаю, что президент Путин узнает, что я за человек, посмотрев мне в глаза, и поймет, что у него есть союзник, который поможет во многих вещах. Я уверен, что мы можем сделать много важных дел вместе, и это поможет России и поможет людям по всему миру понять, что Путин — "отличный парень" с четкими моральными принципами и хороший человек», — говорится в письме. 1 сентября Фред Дерст заявил о желании получить российское гражданство и приобрести недвижимость в России. В середине сентября глава Крыма Сергей Аксенов пригласил представителей мирового шоу-бизнеса и большого спорта обосноваться на полуострове и таким образом создать «аналог американского Беверли-Хиллс». «Если уважаемые представители шоу-бизнеса, спорта, другие знаменитости захотят обосноваться в Крыму — милости просим. Мы можем предоставить помощь в поиске подходящего места у моря, среди гор, лесов или степей, в любом случае — среди великолепной природы и в чудесном климате Крыма», — отмечалось в обращении главы Крыма. Американский боксер Рой Джонс 20 августа написал официальное прошение о получении российского паспорта, а 12 сентября президент Владимир Путин подписал указ, предоставляющий спортсмену гражданство РФ. 10 сентября французский актер Сами Насери, известный по кинофраншизе «Такси», заявил о готовности оформить российский паспорт, если ему кто-нибудь предложит. В 2013 российский паспорт получил актер Жерар Депардье.'

# %%
tex_map = get_text_map(texts_lenta.iloc[371]['text'],unigramm_db_path = "C:\Autotutor\improved_approach\colloc\music_unigr_freq.json",
                            colloc_db_path = "D:\input\music_smart_colloc_freq.json",raw_text_input=True)

# %%
tex_map['overall_colloc_text'][15]
# Out:
# {15: [(0, 'за'),
#   (1, '21летний певица'),
#   (3, 'из'),
#   (4, 'зеленодольск'),
#   (5, 'татарстан'),
#   (6, 'быть'),
#   (7, 'отдавать'),
#   (8, 'более'),
#   (9, 'половина'),
#   (10, 'голос телезритель')]}

# %%
shan = {0: OrderedDict([(0, True), (2, False), (5, False)]),
    17: OrderedDict([(0, False),
                 (2, False),
                 (4, False),
                 (8, True),
                 (10, False),
                 (12, False)]),
    26: OrderedDict([(0, False), (5, True), (7, True), (13, False)]),
    32: OrderedDict([(3, True), (5, True), (14, False), (18, False)]),
    98: OrderedDict([(0, True), (4, True), (5, True), (8, False)]),
    121: OrderedDict([#(0, True),вопрос проебан просто не вставлен в тест!!!!
                 (1, True),
                 (3, False),
                 (4, True),
                 (6, False),
                 (11, True)]),
    130: OrderedDict([(0, True),
                 (1, False),
                # (3, True),вопрос проебан просто не вставлен в тест!!!!
                 (4, False),
                 (5, False),
                 (8, False),
                 (9, True),
                 (16, True)]),
    133: OrderedDict([(2, False),
                 (6, False),
                 (8, False),
                 (9, False),
                 (18, False),
                 (20, False),
                 (40, True),
                 (49, False)]),
    200: OrderedDict([(0, False),(2, False), (4, False), (10, True), (12, True)]),
    231: OrderedDict([(2, False), (4, True), (7, False), (12, False)]),
    240: OrderedDict([(1, True), (11, False), (15, False)]),
    316: OrderedDict([(0, True), (5, False), (7, False), (11, True)]),
    331: OrderedDict([(2, False), (4, False), (10, False)]),
    334: OrderedDict([(1, False), (2, False), (5, True), (8, False)]),
    336: OrderedDict([(1, True), (7, True), (10, True), (13, True)]),
    366: OrderedDict([(0, True),
                 (1, False),
                 (5, False),
                 (8, False),
                 (10, True),
                 (11, True),
                 (15, False)]),
    371: OrderedDict([(0, False),
                 (2, False),
                 (3, False),
                 (6, False),
                 (12, False),
                 (21, False)])}#!

# %%
effected_collocations_start_indexes_list = [i for i in range(effected_collocations_start_indexes_list[0],effected_collocations_start_indexes_list[1]+1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f096c255b3ae> in <module>
# ----> 1 effected_collocations_start_indexes_list = [i for i in range(effected_collocations_start_indexes_list[0],effected_collocations_start_indexes_list[1]+1)]
#
# NameError: name 'effected_collocations_start_indexes_list' is not defined

# %%
class user_vector:
    def __init__(self,debug = False):
        self.debug = debug
        self.vocab_features =[]
        self.sentence_features =[]
        #coreference_items, negation_items, sent_special_pos, dependencies_length, Y (answer)                   
        self.text_fearues = [] #OrderedDict([("lix",[]),("ttr",[])])
        self.answers_count = OrderedDict([("correct_answers",0),("incorrect_answers",0)])
        self.collocations_list = []
        
    def start_new_text(self):
        self.answers_count['correct_answers'] = 0
        self.answers_count['incorrect_answers'] = 0
        if self.debug:print("answers count has been reset", self.answers_count['correct_answers'], self.answers_count['incorrect_answers'])
    
    def end_text(self, text_map):
        if self.debug:
            print("\n========")
            print("SUM UP TEXT VALUES")
            print("========\n")
        correct_answers_rate = round(self.answers_count['correct_answers'] / (self.answers_count['correct_answers'] 
                                                                              + self.answers_count['incorrect_answers']),2)
        current_text_features = []
        if self.debug: 
            print("answers_count", self.answers_count)
        current_text_features.append(text_map['lix'])
        current_text_features.append(text_map['ttr'])
        current_text_features.append(text_map['sentences_count'])
        current_text_features.append(text_map['average_sentence_length'])
        #current_text_features.extend(text_map['vocab_properties'])
        current_text_features.extend(text_map['sent_properties'])
        current_text_features.append(correct_answers_rate)
        self.text_fearues.append(current_text_features)
        if self.debug: print("TEXT FEATURES",self.text_fearues)
    
    def update_vector_with_answer_sentence(self, sentence_map, effected_collocations_start_indexes_list, correct_answer):
        #update setnence and text features
        if self.debug:
            print("\n===NEW REPLY CALCULATION====")
            print("\n========")
            print("ADDING SENTENCE RESULTS")
            print("========\n")
            
        #update setnence and text features
        if correct_answer == True:
            answer_value = 1
            self.answers_count['correct_answers'] += 1
            if self.debug: print("Answer for this question is correct")
        else:
            answer_value = 0
            self.answers_count['incorrect_answers'] += 1
            if self.debug: print("Answer for this question is incorrect")
        if self.debug:print("check answers count", self.answers_count['correct_answers'], self.answers_count['incorrect_answers'])
        current_sentence_features = []
        current_sentence_features.append(sentence_map['spec_sentence_features']['negation'])
        current_sentence_features.append(sentence_map['spec_sentence_features']['coreference'])
        current_sentence_features.append(sentence_map['spec_sentence_features']['vozvr_verb'])
        current_sentence_features.append(sentence_map['spec_sentence_features']['prich'])
        current_sentence_features.append(sentence_map['spec_sentence_features']['deepr'])
        current_sentence_features.append(sentence_map['spec_sentence_features']['case_complexity'])
        current_sentence_features.append(sentence_map['spec_sentence_features']['mean_depend_length'])
        
        #current_sentence_features.extend(sentence_map['average_vocabulary'])
        current_sentence_features.append(answer_value)#target variable
        self.sentence_features.append(current_sentence_features)
        
        if self.debug: print("SENTENCE FEATURES", current_sentence_features)
        
        if self.debug:
            print("\n========")
            print("ADDING VOCABULARY RESULTS")
            print("========\n") 
        effected_collocations_start_indexes_list_ranged = [i for i in range(effected_collocations_start_indexes_list[0],effected_collocations_start_indexes_list[1]+1)]    
        for word_w in sentence_map['collocation_vectors_list']:
            
            if word_w[0] in effected_collocations_start_indexes_list_ranged:
                if self.debug:print(word_w[1][0])
                current_word_features = []
                #current_word_features.append(str("local_freq_") + str(word_w[1][1]))
                current_word_features.append(word_w[1][1])
                #print("11", word_w[1][1])
                #current_word_features.append(str("global_freq_mpi_ln_") + glob_freq_log)
                current_word_features.append(word_w[1][2])
                #print("12",word_w[1][2])
                current_word_features.extend(word_w[2][0])
                #print("20",word_w[2][0])
                current_word_features.append(answer_value)
                
                self.collocations_list.append(word_w[1][0])
                #print(current_word_features)
                self.vocab_features.append(current_word_features)
    def export_user_db(self, learner_id):
                
        words_db = np.array([np.array(word) for word in self.vocab_features])
        word_db_path = learner_id + '_word_db.csv'
        np.savetxt(word_db_path, words_db, delimiter=',') #, fmt='%s'
        
        sentence_db = np.array([np.array(sent) for sent in self.sentence_features])
        sentence_db_path = learner_id + '_sentence_db.csv'
        np.savetxt(sentence_db_path, sentence_db, delimiter=',') 
        
        text_db = np.array([np.array(text) for text in self.text_fearues])
        text_db_path = learner_id + '_text_db.csv'
        np.savetxt(text_db_path, text_db, delimiter=',') 
        
        with open(learner_id + "_colloc_lit.txt", "w", encoding = "utf-8") as f:
            for colloc in self.collocations_list:
                f.write(colloc + '\n')

# %%
text_maps_json_dict.keys(),len(list(text_maps_json_dict.keys()))
# Out:
# (dict_keys([0, 17, 26, 32, 98, 121, 130, 133, 200, 231, 240, 316, 331, 334, 336, 366, 371]),
#  17)

# %%
question_text_sent_collocind_dict['0']['0']
# Out:
# [9, 11]

# %%
text_maps_json_dict.keys()
# Out:
# dict_keys([0, 17, 26, 32, 98, 121, 130, 133, 200, 231, 240, 316, 331, 334, 336, 366, 371])

# %%
def get_user_db(ans_dict, ans_dict_name):
    DEBUG = False
    user = user_vector(debug = DEBUG)
    for text in text_maps_json_dict.keys():
        print("text_index", text)
        text_map = text_maps_json_dict[text]
        user.start_new_text()
        for question_sentence_index in question_text_sent_collocind_dict[str(text)].keys():

            user.update_vector_with_answer_sentence(text_map['sentences_map'][int(question_sentence_index)], 
                                            effected_collocations_start_indexes_list = question_text_sent_collocind_dict[str(text)][str(question_sentence_index)],
                                            correct_answer = ans_dict[int(text)][int(question_sentence_index)])

            user.end_text(text_map)
    user.export_user_db(ans_dict_name)

# %%
get_user_db(shan, "shan_big_musician")
# Out:
# text_index 0
# text_index 17
# text_index 26
# text_index 32
# text_index 98
# text_index 121
# text_index 130
# text_index 133
# text_index 200
# text_index 231
# text_index 240
# text_index 316
# text_index 331
# text_index 334
# text_index 336
# text_index 366
# text_index 371

# %% [raw]
# DEBUG = False
# user = user_vector(debug = DEBUG)
# for text in text_maps_json_dict.keys():
#     print("text_index", text)
#     text_map = text_maps_json_dict[text]
#     user.start_new_text()
#     for question_sentence_index in question_text_sent_collocind_dict[str(text)].keys():
#
#         user.update_vector_with_answer_sentence(text_map['sentences_map'][int(question_sentence_index)],
#                                         effected_collocations_start_indexes_list = question_text_sent_collocind_dict[str(text)][str(question_sentence_index)],
#                                         correct_answer = ans_dict_enze[int(text)][int(question_sentence_index)])
#
#         user.end_text(text_map)

# %%
user.export_user_db("enze_big_musician")

# %% [markdown]
# # ANSWER DICTS

# %%
lynn3849 = {0: OrderedDict([(0, False), (2, False), (5, False)]),
    17: OrderedDict([(0, True),
                 (2, False),
                 (4, True),
                 (8, True),
                 (10, True),
                 (12, False)]),
    26: OrderedDict([(0, True), (5, False), (7, False), (13, False)]),
    32: OrderedDict([(3, False), (5, True), (14, True), (18, True)]),
    98: OrderedDict([(0, False), (4, False), (5, True), (8, True)]),
    121: OrderedDict([#(0, True),вопрос проебан просто не вставлен в тест!!!!
                 (1, False),
                 (3, True),
                 (4, False),
                 (6, False),
                 (11, False)]),
    130: OrderedDict([(0, False),
                 (1, True),
                # (3, True),вопрос проебан просто не вставлен в тест!!!!
                 (4, True),
                 (5, True),
                 (8, False),
                 (9, False),
                 (16, False)]),
    133: OrderedDict([(2, False),
                 (6, False),
                 (8, False),
                 (9, True),
                 (18, True),
                 (20, True),
                 (40, True),
                 (49, False)]),
    200: OrderedDict([(0, False),(2, True), (4, True), (10, True), (12, False)]),
    231: OrderedDict([(2, False), (4, True), (7, False), (12, True)]),
    240: OrderedDict([(1, True), (11, False), (15, True)]),
    316: OrderedDict([(0, False), (5, False), (7, False), (11, False)]),
    331: OrderedDict([(2, False), (4, True), (10, False)]),
    334: OrderedDict([(1, False), (2, True), (5, True), (8, False)]),
    336: OrderedDict([(1, False), (7, True), (10, True), (13, True)]),
    366: OrderedDict([(0, True),
                 (1, False),
                 (5, True),
                 (8, False),
                 (10, False),
                 (11, False),
                 (15, False)]),
    371: OrderedDict([(0, True),
                 (2, True),
                 (3, True),
                 (6, True),
                 (12, False),
                 (21, False)])}#!

# %%
sendaeremail = {0: OrderedDict([(0, True), (2, True), (5, False)]),
    17: OrderedDict([(0, True),
                 (2, True),
                 (4, True),
                 (8, True),
                 (10, True),
                 (12, True)]),
    26: OrderedDict([(0, True), (5, True), (7, True), (13, True)]),
    32: OrderedDict([(3, True), (5, True), (14, True), (18, True)]),
    98: OrderedDict([(0, True), (4, False), (5, True), (8, True)]),
    121: OrderedDict([#(0, True),вопрос проебан просто не вставлен в тест!!!!
                 (1, True),
                 (3, False),
                 (4, True),
                 (6, False),
                 (11, True)]),
    130: OrderedDict([(0, True),
                 (1, True),
                # (3, True),вопрос проебан просто не вставлен в тест!!!!
                 (4, True),
                 (5, True),
                 (8, True),
                 (9, True),
                 (16, True)]),
    133: OrderedDict([(2, True),
                 (6, True),
                 (8, False),
                 (9, False),
                 (18, True),
                 (20, True),
                 (40, True),
                 (49, True)]),
    200: OrderedDict([(0, True),(2, True), (4, True), (10, True), (12, True)]),
    231: OrderedDict([(2, True), (4, True), (7, True), (12, True)]),
    240: OrderedDict([(1, True), (11, True), (15, True)]),
    316: OrderedDict([(0, True), (5, True), (7, True), (11, True)]),
    331: OrderedDict([(2, False), (4, True), (10, True)]),
    334: OrderedDict([(1, True), (2, True), (5, True), (8, True)]),
    336: OrderedDict([(1, True), (7, True), (10, False), (13, True)]),
    366: OrderedDict([(0, True),
                 (1, True),
                 (5, True),
                 (8, True),
                 (10, True),
                 (11, True),
                 (15, False)]),
    371: OrderedDict([(0, True),
                 (2, True),
                 (3, True),
                 (6, True),
                 (12, True),
                 (21, True)])}#!

# %%
aijingchen18 = {0: OrderedDict([(0, True), (2, False), (5, False)]),
    17: OrderedDict([(0, True),
                 (2, True),
                 (4, True),
                 (8, True),
                 (10, True),
                 (12, True)]),
    26: OrderedDict([(0, True), (5, True), (7, True), (13, True)]),
    32: OrderedDict([(3, True), (5, True), (14, True), (18, True)]),
    98: OrderedDict([(0, True), (4, True), (5, True), (8, True)]),
    121: OrderedDict([#(0, True),вопрос проебан просто не вставлен в тест!!!!
                 (1, True),
                 (3, False),
                 (4, True),
                 (6, True),
                 (11, True)]),
    130: OrderedDict([(0, True),
                 (1, True),
                # (3, True),вопрос проебан просто не вставлен в тест!!!!
                 (4, True),
                 (5, True),
                 (8, True),
                 (9, True),
                 (16, True)]),
    133: OrderedDict([(2, True),
                 (6, True),
                 (8, False),
                 (9, True),
                 (18, True),
                 (20, True),
                 (40, True),
                 (49, True)]),
    200: OrderedDict([(0, True),(2, True), (4, True), (10, True), (12, True)]),
    231: OrderedDict([(2, True), (4, True), (7, True), (12, False)]),
    240: OrderedDict([(1, True), (11, True), (15, True)]),
    316: OrderedDict([(0, False), (5, True), (7, True), (11, True)]),
    331: OrderedDict([(2, False), (4, True), (10, False)]),
    334: OrderedDict([(1, True), (2, True), (5, True), (8, False)]),
    336: OrderedDict([(1, True), (7, True), (10, True), (13, True)]),
    366: OrderedDict([(0, True),
                 (1, True),
                 (5, True),
                 (8, False),
                 (10, False),
                 (11, True),
                 (15, True)]),
    371: OrderedDict([(0, True),
                 (2, True),
                 (3, True),
                 (6, True),
                 (12, True),
                 (21, False)])}#!

# %%
three_nine_eight_rec_dict = {0: OrderedDict([(0, True), (2, True), (5, True)]),
    17: OrderedDict([(0, True),
                 (2, True),
                 (4, True),
                 (8, True),
                 (10, False),
                 (12, True)]),
    26: OrderedDict([(0, True), (5, True), (7, False), (13, True)]),
    32: OrderedDict([(3, True), (5, True), (14, True), (18, True)]),
    98: OrderedDict([(0, True), (4, True), (5, True), (8, False)]),
    121: OrderedDict([#(0, True),вопрос проебан просто не вставлен в тест!!!!
                 (1, True),
                 (3, False),
                 (4, True),
                 (6, False),
                 (11, True)]),
    130: OrderedDict([(0, True),
                 (1, True),
                # (3, True),вопрос проебан просто не вставлен в тест!!!!
                 (4, True),
                 (5, True),
                 (8, True),
                 (9, True),
                 (16, False)]),
    133: OrderedDict([(2, False),
                 (6, True),
                 (8, False),
                 (9, True),
                 (18, True),
                 (20, True),
                 (40, False),
                 (49, False)]),
    200: OrderedDict([(0, True),(2, True), (4, True), (10, True), (12, True)]),
    231: OrderedDict([(2, True), (4, True), (7, True), (12, True)]),
    240: OrderedDict([(1, True), (11, True), (15, False)]),
    316: OrderedDict([(0, False), (5, True), (7, False), (11, False)]),
    331: OrderedDict([(2, False), (4, True), (10, False)]),
    334: OrderedDict([(1, True), (2, True), (5, True), (8, False)]),
    336: OrderedDict([(1, True), (7, True), (10, True), (13, True)]),
    366: OrderedDict([(0, False),
                 (1, False),
                 (5, True),
                 (8, True),
                 (10, True),
                 (11, True),
                 (15, True)]),
    371: OrderedDict([(0, True),
                 (2, True),
                 (3, True),
                 (6, True),
                 (12, False),
                 (21, True)])}#!

# %%
chsun_answer_dict ={0: OrderedDict([(0, True), (2, True), (5, True)]),
 17: OrderedDict([(0, True),
              (2, True),
              (4, True),
              (8, True),
              (10, True),
              (12, True)]),
 26: OrderedDict([(0, True), (5, True), (7, True), (13, True)]),
 32: OrderedDict([(3, True), (5, True), (14, True), (18, True)]),
 98: OrderedDict([(0, True), (4, True), (5, True), (8, True)]),
 121: OrderedDict([#(0, True),вопрос проебан просто не вставлен в тест!!!!
              (1, True),
              (3, False),
              (4, True),
              (6, True),
              (11, True)]),
 130: OrderedDict([(0, True),
              (1, True),
             # (3, True),вопрос проебан просто не вставлен в тест!!!!
              (4, True),
              (5, True),
              (8, True),
              (9, True),
              (16, True)]),
 133: OrderedDict([(2, False),
              (6, True),
              (8, True),
              (9, True),
              (18, True),
              (20, True),
              (40, True),
              (49, True)]),
 200: OrderedDict([(0, True),(2, True), (4, False), (10, True), (12, True)]),
 231: OrderedDict([(2, False), (4, True), (7, True), (12, True)]),
 240: OrderedDict([(1, True), (11, True), (15, True)]),
 316: OrderedDict([(0, True), (5, True), (7, True), (11, False)]),
 331: OrderedDict([(2, False), (4, True), (10, True)]),
 334: OrderedDict([(1, True), (2, True), (5, True), (8, True)]),
 336: OrderedDict([(1, True), (7, True), (10, True), (13, True)]),
 366: OrderedDict([(0, False),
              (1, False),
              (5, True),
              (8, True),
              (10, True),
              (11, True),
              (15, False)]),
 371: OrderedDict([(0, True),
              (2, True),
              (3, True),
              (6, True),
              (12, True),
              (21, True)])}

# %%
ans_dict_enze ={0: OrderedDict([(0, True), (2, True), (5, True)]),
 17: OrderedDict([(0, True),
              (2, False),
              (4, True),
              (8, True),
              (10, True),
              (12, True)]),
 26: OrderedDict([(0, True), (5, True), (7, True), (13, True)]),
 32: OrderedDict([(3, True), (5, True), (14, True), (18, False)]),
 98: OrderedDict([(0, True), (4, False), (5, True), (8, True)]),
 121: OrderedDict([#(0, True),вопрос проебан просто не вставлен в тест!!!!
              (1, True),
              (3, True),
              (4, True),
              (6, True),
              (11, True)]),
 130: OrderedDict([(0, True),
              (1, True),
             # (3, True),вопрос проебан просто не вставлен в тест!!!!
              (4, True),
              (5, False),
              (8, True),
              (9, True),
              (16, True)]),
 133: OrderedDict([(2, False),
              (6, True),
              (8, True),
              (9, True),
              (18, True),
              (20, True),
              (40, True),
              (49, True)]),
 200: OrderedDict([(0, True),(2, True), (4, True), (10, True), (12, True)]),
 231: OrderedDict([(2, False), (4, False), (7, True), (12, True)]),
 240: OrderedDict([(1, False), (11, True), (15, True)]),
 316: OrderedDict([(0, True), (5, True), (7, True), (11, True)]),
 331: OrderedDict([(2, False), (4, True), (10, True)]),
 334: OrderedDict([(1, True), (2, True), (5, True), (8, True)]),
 336: OrderedDict([(1, False), (7, True), (10, True), (13, True)]),
 366: OrderedDict([(0, True),
              (1, True),
              (5, False),
              (8, True),
              (10, True),
              (11, True),
              (15, False)]),
 371: OrderedDict([(0, True),
              (2, True),
              (3, True),
              (6, True),
              (12, True),
              (21, True)])}#!
