# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading https://files.pythonhosted.org/packages/6f/ed/9c755d357d33bc1931e157f537721efb5b88d2c583fe593cc09603076cc3/nltk-3.4.zip (1.4MB)
#     100% |████████████████████████████████| 1.4MB 2.8MB/s ta 0:00:011
# Requirement already satisfied: six in /Users/lilyakhoang/anaconda3/lib/python3.7/site-packages (from nltk) (1.11.0)
# Requirement already satisfied: singledispatch in /Users/lilyakhoang/anaconda3/lib/python3.7/site-packages (from nltk) (3.4.0.3)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Stored in directory: /Users/lilyakhoang/Library/Caches/pip/wheels/4b/c8/24/b2343664bcceb7147efeb21c0b23703a05b23fcfeaceaa2a1e
# Successfully built nltk
# Installing collected packages: nltk
# Successfully installed nltk-3.4

# %%
import copy 

import pandas as pd
import copy

import re

import os

import operator

import pymorphy2
from pymystem3 import Mystem

import nltk

import itertools 

import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer

from collections import OrderedDict

import progressbar
import time

from collections import OrderedDict
from string import punctuation
full_punctuation = punctuation + "–" + "," + "»" + "«"
full_punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~–,»«'

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
russian_stopwords = stopwords.words("russian")
russian_stopwords.remove("бы")
russian_stopwords.remove("не")
russian_stopwords.remove("ни")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
tokenizer = nltk.data.load('russian.pickle')
text = "Ай да А.С. Пушкин! Ай да сукин сын!"
print("Before:", nltk.sent_tokenize(text))
print("After:", tokenizer.tokenize(text))
# Out:
# Before: ['Ай да А.С.', 'Пушкин!', 'Ай да сукин сын!']
# After: ['Ай да А.С. Пушкин!', 'Ай да сукин сын!']

# %%
end_line_punctuation = "!.?»"
def delete_empty_newlines(file):
    new_lines = []
    collected_line = ''
    empty_endline = False
    with open (file, "r", encoding = "utf-8") as f:
        for line in f.readlines():
            cl_line = line.strip()
            #print(cl_line, "||",cl_line[-1])
            if(cl_line[-1] not in end_line_punctuation):
                #print("go to the next")
                collected_line += ' ' + cl_line
                empty_endline = True
            else:
                if(collected_line):
                    collected_line += ' ' + cl_line
                empty_endline = False
            
            if not (empty_endline):
                if(collected_line):
                    #print(collected_line)
                    new_lines.append(collected_line)
                    collected_line = ''
                    
                else:
                    #print(cl_line)
                    new_lines.append(cl_line)
                
    return new_lines
list_sentences_lines = delete_empty_newlines("text_8.txt")

# %%
list_sentences_lines
# Out:
# ['В классе был урок русского языка. Преподаватель читал новый текст.',
#  'Студенты внимательно слушали.',
#  '– Извините, можно войти? Я опоздал, – сказал Джон.',
#  ' – Что случилось, Джон? Вчера вы опоздали, сегодня вы опоздали. Нельзя опаздывать на урок.',
#  ' Вечером Джон пришел домой. Дома он долго думал: «Вчера я опоздал, сегодня я тоже опоздал. Это очень плохо. Не буду больше опаздывать на урок. Завтра я встану рано, в 8 часов, быстро сделаю зарядку, приготовлю завтрак, позавтракаю, повторю домашнее задание. Завтра я не опоздаю!»',
#  ' Утром Джон встал в 8 часов. Он сделал зарядку, приготовил завтрак, позавтракал, повторил домашнее задание и пошел в институт.',
#  'В 9 часов 30 минут Джон пришел в институт.',
#  '– Что случилось, молодой человек? Куда вы идете? – спросил дежурный.',
#  '– Я иду на урок. Сегодня я не опоздал, – ответил Джон.',
#  '– Идите домой, молодой человек! Сегодня нет урока. Сегодня воскресенье.']

# %%
def preprocess_text(text):
    sentences = nltk.sent_tokenize(text)
    clean_sentence = []
    #print(sentences)
    for sentence in sentences:
        words = sentence.split()
        clean_text= ''
        for word in words:
            clean_word = ''
            for char in word:
                if char != " " and char not in full_punctuation:
                    clean_word += char.lower()
            clean_text += clean_word + ' '
        clean_text = re.sub(' +', ' ', clean_text)
        clean_text = clean_text.strip()
        clean_sentence.append(clean_text)
    return clean_sentence   

def clean_file(file_lines_list):
    preprocessed_text = []
    for line in file_lines_list:
        t = preprocess_text(line)
        #print(t)
        preprocessed_text.extend(t)

    return preprocessed_text
sentences_list = clean_file(list_sentences_lines)

# %%
def calculate_lix_from_list_of_sentences(processed_text_sentences):
        sentences_count = len(processed_text_sentences)
        words_count = sum([len(line.split(' ')) for line in processed_text_sentences])
        long_words_count = 0 #more than 6
        for line in processed_text_sentences:
            for word in line.split():
                if len(word) > 6:
                    long_words_count += 1
        lix = words_count/ sentences_count + (long_words_count * 100) / words_count
        
        return round(lix,2)
text_lix = calculate_lix_from_list_of_sentences(sentences_list)

# %%
m = Mystem()
al = m.analyze('в классе был урок русского языка')

# %%
al[2]
# Out:
# {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'класс', 'wt': 1}],
#  'text': 'классе'}

# %%
sentences_list
# Out:
# ['в классе был урок русского языка',
#  'преподаватель читал новый текст',
#  'студенты внимательно слушали',
#  'извините можно войти',
#  'я опоздал сказал джон',
#  'что случилось джон',
#  'вчера вы опоздали сегодня вы опоздали',
#  'нельзя опаздывать на урок',
#  'вечером джон пришел домой',
#  'дома он долго думал вчера я опоздал сегодня я тоже опоздал',
#  'это очень плохо',
#  'не буду больше опаздывать на урок',
#  'завтра я встану рано в 8 часов быстро сделаю зарядку приготовлю завтрак позавтракаю повторю домашнее задание',
#  'завтра я не опоздаю',
#  'утром джон встал в 8 часов',
#  'он сделал зарядку приготовил завтрак позавтракал повторил домашнее задание и пошел в институт',
#  'в 9 часов 30 минут джон пришел в институт',
#  'что случилось молодой человек',
#  'куда вы идете',
#  'спросил дежурный',
#  'я иду на урок',
#  'сегодня я не опоздал ответил джон',
#  'идите домой молодой человек',
#  'сегодня нет урока',
#  'сегодня воскресенье']

# %%
def get_sent_gramm_features_map(clean_text):
    text_grammar_map = []
    m = Mystem()
    
    bar = progressbar.ProgressBar(maxval=len(clean_text),
                                      widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
    line_number = 0
    bar.start()
        
    for sentence in clean_text:
        parsed_sentence_clean = []
        parsed_sentence =  m.analyze(sentence)
        for word in parsed_sentence:
            if word['text'].isalpha():
                parsed_sentence_clean.append(word)
        text_grammar_map.append(parsed_sentence_clean)
        
        line_number += 1
        bar.update(line_number)
        time.sleep(0.1)
        
    return text_grammar_map
text_grammar_map_ex =  get_sent_gramm_features_map(sentences_list)
# Out:
# [========================================================================] 100%

# %%
text_grammar_map_ex[0]
# Out:
# [{'analysis': [{'gr': 'PR=', 'lex': 'в', 'wt': 0.9999917878}], 'text': 'в'},
#  {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'класс', 'wt': 1}],
#   'text': 'классе'},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,муж,несов', 'lex': 'быть', 'wt': 1}],
#   'text': 'был'},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)',
#     'lex': 'урок',
#     'wt': 0.9992735223}],
#   'text': 'урок'},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#     'lex': 'русский',
#     'wt': 0.9496245492}],
#   'text': 'русского'},
#  {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'язык', 'wt': 0.9963354032}],
#   'text': 'языка'}]

# %%
def lemmatize_text_from_grammar_map(text_gr_map):
    lemm_text = []
    for sentence_gr_map in text_gr_map:
        sentence = ''
        for word_grammar_features in sentence_gr_map:
            keys = list(word_grammar_features.keys())
            values = list(word_grammar_features.values())
            word  = word_grammar_features['text']
            if ('analysis' not in keys):
                pass
            elif(word_grammar_features['analysis'] ==[]):
                pass
            else:
                lemma = word_grammar_features['analysis'][0]['lex']
                sentence += lemma + ' '
        sentence = sentence.strip()
        lemm_text.append(sentence)
    return lemm_text
lemm_sentences = lemmatize_text_from_grammar_map(text_grammar_map_ex)

# %% [raw]
# def lemmatize_line(text,morph):
#     lemm_split_text = []
#     words = text.split()
#     for word in words:
#         parsed_word = morph.parse(word)[0]
#         lemma = parsed_word.normal_form
#         lemm_split_text.append(lemma)
#     return ' '.join(lemm_split_text)
#
# def lemmatize_text_from_sent_list(sent_list):
#     lemm_text_lines = []
#     morph = pymorphy2.MorphAnalyzer()
#     for line in sent_list:
#         lemm_line = lemmatize_line(line, morph)
#         lemm_text_lines.append(lemm_line)
#     return lemm_text_lines
# lemm_sentences = lemmatize_text_from_sent_list(sentences_list)

# %%
lemm_sentences
# Out:
# ['в класс быть урок русский язык',
#  'преподаватель читать новый текст',
#  'студент внимательно слушать',
#  'извинять можно входить',
#  'я опаздывать сказать джон',
#  'что случаться джон',
#  'вчера вы опаздывать сегодня вы опаздывать',
#  'нельзя опаздывать на урок',
#  'вечер джон приходить домой',
#  'дома он долго думать вчера я опаздывать сегодня я тоже опаздывать',
#  'это очень плохой',
#  'не быть больше опаздывать на урок',
#  'завтра я вставать рано в час быстро сделать зарядка приготавливать завтрак позавтракать повторять домашний задание',
#  'завтра я не опаздывать',
#  'утро джон вставать в час',
#  'он сделать зарядка приготавливать завтрак позавтракать повторять домашний задание и пойти в институт',
#  'в час минута джон приходить в институт',
#  'что случаться молодой человек',
#  'куда вы идти',
#  'спрашивать дежурный',
#  'я идти на урок',
#  'сегодня я не опаздывать отвечать джон',
#  'идти домой молодой человек',
#  'сегодня нет урок',
#  'сегодня воскресение']

# %%
def get_weights_empty_list(clean_lemm_sentences_list, clean_orig_sentences_list):
    weights_list = []
    assert (len(clean_lemm_sentences_list) == len(clean_orig_sentences_list))
    for lemm_sentence, sentence in zip(clean_lemm_sentences_list,clean_lemm_sentences_list):
        #print(sentence)
        sentence_weights = []
        assert (len(lemm_sentence.split()) == len(sentence.split()))
        for lemm, word in zip (lemm_sentence.split(),sentence.split()) :
            if(lemm in russian_stopwords):
                weight = {"lemma" : lemm, "orig_word": word, "weight": 0, "stop_word":True}
            elif(lemm.isdigit()):
                weight = {"lemma" : lemm, "orig_word": word,"weight": 0, "digit":True}
            else:
                weight = {"lemma" : lemm, "orig_word": word,"weight": 0}
            sentence_weights.append(weight)
        weights_list.append(sentence_weights)
    return weights_list
text_weighs_1 = get_weights_empty_list(lemm_sentences, sentences_list)
text_weighs_1
# Out:
# [[{'lemma': 'в', 'orig_word': 'в', 'stop_word': True, 'weight': 0},
#   {'lemma': 'класс', 'orig_word': 'класс', 'weight': 0},
#   {'lemma': 'быть', 'orig_word': 'быть', 'stop_word': True, 'weight': 0},
#   {'lemma': 'урок', 'orig_word': 'урок', 'weight': 0},
#   {'lemma': 'русский', 'orig_word': 'русский', 'weight': 0},
#   {'lemma': 'язык', 'orig_word': 'язык', 'weight': 0}],
#  [{'lemma': 'преподаватель', 'orig_word': 'преподаватель', 'weight': 0},
#   {'lemma': 'читать', 'orig_word': 'читать', 'weight': 0},
#   {'lemma': 'новый', 'orig_word': 'новый', 'weight': 0},
#   {'lemma': 'текст', 'orig_word': 'текст', 'weight': 0}],
#  [{'lemma': 'студент', 'orig_word': 'студент', 'weight': 0},
#   {'lemma': 'внимательно', 'orig_word': 'внимательно', 'weight': 0},
#   {'lemma': 'слушать', 'orig_word': 'слушать', 'weight': 0}],
#  [{'lemma': 'извинять', 'orig_word': 'извинять', 'weight': 0},
#   {'lemma': 'можно', 'orig_word': 'можно', 'stop_word': True, 'weight': 0},
#   {'lemma': 'входить', 'orig_word': 'входить', 'weight': 0}],
#  [{'lemma': 'я', 'orig_word': 'я', 'stop_word': True, 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0},
#   {'lemma': 'сказать', 'orig_word': 'сказать', 'weight': 0},
#   {'lemma': 'джон', 'orig_word': 'джон', 'weight': 0}],
#  [{'lemma': 'что', 'orig_word': 'что', 'stop_word': True, 'weight': 0},
#   {'lemma': 'случаться', 'orig_word': 'случаться', 'weight': 0},
#   {'lemma': 'джон', 'orig_word': 'джон', 'weight': 0}],
#  [{'lemma': 'вчера', 'orig_word': 'вчера', 'weight': 0},
#   {'lemma': 'вы', 'orig_word': 'вы', 'stop_word': True, 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0},
#   {'lemma': 'сегодня', 'orig_word': 'сегодня', 'weight': 0},
#   {'lemma': 'вы', 'orig_word': 'вы', 'stop_word': True, 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0}],
#  [{'lemma': 'нельзя', 'orig_word': 'нельзя', 'stop_word': True, 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0},
#   {'lemma': 'на', 'orig_word': 'на', 'stop_word': True, 'weight': 0},
#   {'lemma': 'урок', 'orig_word': 'урок', 'weight': 0}],
#  [{'lemma': 'вечер', 'orig_word': 'вечер', 'weight': 0},
#   {'lemma': 'джон', 'orig_word': 'джон', 'weight': 0},
#   {'lemma': 'приходить', 'orig_word': 'приходить', 'weight': 0},
#   {'lemma': 'домой', 'orig_word': 'домой', 'weight': 0}],
#  [{'lemma': 'дома', 'orig_word': 'дома', 'weight': 0},
#   {'lemma': 'он', 'orig_word': 'он', 'stop_word': True, 'weight': 0},
#   {'lemma': 'долго', 'orig_word': 'долго', 'weight': 0},
#   {'lemma': 'думать', 'orig_word': 'думать', 'weight': 0},
#   {'lemma': 'вчера', 'orig_word': 'вчера', 'weight': 0},
#   {'lemma': 'я', 'orig_word': 'я', 'stop_word': True, 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0},
#   {'lemma': 'сегодня', 'orig_word': 'сегодня', 'weight': 0},
#   {'lemma': 'я', 'orig_word': 'я', 'stop_word': True, 'weight': 0},
#   {'lemma': 'тоже', 'orig_word': 'тоже', 'stop_word': True, 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0}],
#  [{'lemma': 'это', 'orig_word': 'это', 'weight': 0},
#   {'lemma': 'очень', 'orig_word': 'очень', 'weight': 0},
#   {'lemma': 'плохой', 'orig_word': 'плохой', 'weight': 0}],
#  [{'lemma': 'не', 'orig_word': 'не', 'weight': 0},
#   {'lemma': 'быть', 'orig_word': 'быть', 'stop_word': True, 'weight': 0},
#   {'lemma': 'больше', 'orig_word': 'больше', 'stop_word': True, 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0},
#   {'lemma': 'на', 'orig_word': 'на', 'stop_word': True, 'weight': 0},
#   {'lemma': 'урок', 'orig_word': 'урок', 'weight': 0}],
#  [{'lemma': 'завтра', 'orig_word': 'завтра', 'weight': 0},
#   {'lemma': 'я', 'orig_word': 'я', 'stop_word': True, 'weight': 0},
#   {'lemma': 'вставать', 'orig_word': 'вставать', 'weight': 0},
#   {'lemma': 'рано', 'orig_word': 'рано', 'weight': 0},
#   {'lemma': 'в', 'orig_word': 'в', 'stop_word': True, 'weight': 0},
#   {'lemma': 'час', 'orig_word': 'час', 'weight': 0},
#   {'lemma': 'быстро', 'orig_word': 'быстро', 'weight': 0},
#   {'lemma': 'сделать', 'orig_word': 'сделать', 'weight': 0},
#   {'lemma': 'зарядка', 'orig_word': 'зарядка', 'weight': 0},
#   {'lemma': 'приготавливать', 'orig_word': 'приготавливать', 'weight': 0},
#   {'lemma': 'завтрак', 'orig_word': 'завтрак', 'weight': 0},
#   {'lemma': 'позавтракать', 'orig_word': 'позавтракать', 'weight': 0},
#   {'lemma': 'повторять', 'orig_word': 'повторять', 'weight': 0},
#   {'lemma': 'домашний', 'orig_word': 'домашний', 'weight': 0},
#   {'lemma': 'задание', 'orig_word': 'задание', 'weight': 0}],
#  [{'lemma': 'завтра', 'orig_word': 'завтра', 'weight': 0},
#   {'lemma': 'я', 'orig_word': 'я', 'stop_word': True, 'weight': 0},
#   {'lemma': 'не', 'orig_word': 'не', 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0}],
#  [{'lemma': 'утро', 'orig_word': 'утро', 'weight': 0},
#   {'lemma': 'джон', 'orig_word': 'джон', 'weight': 0},
#   {'lemma': 'вставать', 'orig_word': 'вставать', 'weight': 0},
#   {'lemma': 'в', 'orig_word': 'в', 'stop_word': True, 'weight': 0},
#   {'lemma': 'час', 'orig_word': 'час', 'weight': 0}],
#  [{'lemma': 'он', 'orig_word': 'он', 'stop_word': True, 'weight': 0},
#   {'lemma': 'сделать', 'orig_word': 'сделать', 'weight': 0},
#   {'lemma': 'зарядка', 'orig_word': 'зарядка', 'weight': 0},
#   {'lemma': 'приготавливать', 'orig_word': 'приготавливать', 'weight': 0},
#   {'lemma': 'завтрак', 'orig_word': 'завтрак', 'weight': 0},
#   {'lemma': 'позавтракать', 'orig_word': 'позавтракать', 'weight': 0},
#   {'lemma': 'повторять', 'orig_word': 'повторять', 'weight': 0},
#   {'lemma': 'домашний', 'orig_word': 'домашний', 'weight': 0},
#   {'lemma': 'задание', 'orig_word': 'задание', 'weight': 0},
#   {'lemma': 'и', 'orig_word': 'и', 'stop_word': True, 'weight': 0},
#   {'lemma': 'пойти', 'orig_word': 'пойти', 'weight': 0},
#   {'lemma': 'в', 'orig_word': 'в', 'stop_word': True, 'weight': 0},
#   {'lemma': 'институт', 'orig_word': 'институт', 'weight': 0}],
#  [{'lemma': 'в', 'orig_word': 'в', 'stop_word': True, 'weight': 0},
#   {'lemma': 'час', 'orig_word': 'час', 'weight': 0},
#   {'lemma': 'минута', 'orig_word': 'минута', 'weight': 0},
#   {'lemma': 'джон', 'orig_word': 'джон', 'weight': 0},
#   {'lemma': 'приходить', 'orig_word': 'приходить', 'weight': 0},
#   {'lemma': 'в', 'orig_word': 'в', 'stop_word': True, 'weight': 0},
#   {'lemma': 'институт', 'orig_word': 'институт', 'weight': 0}],
#  [{'lemma': 'что', 'orig_word': 'что', 'stop_word': True, 'weight': 0},
#   {'lemma': 'случаться', 'orig_word': 'случаться', 'weight': 0},
#   {'lemma': 'молодой', 'orig_word': 'молодой', 'weight': 0},
#   {'lemma': 'человек', 'orig_word': 'человек', 'weight': 0}],
#  [{'lemma': 'куда', 'orig_word': 'куда', 'stop_word': True, 'weight': 0},
#   {'lemma': 'вы', 'orig_word': 'вы', 'stop_word': True, 'weight': 0},
#   {'lemma': 'идти', 'orig_word': 'идти', 'weight': 0}],
#  [{'lemma': 'спрашивать', 'orig_word': 'спрашивать', 'weight': 0},
#   {'lemma': 'дежурный', 'orig_word': 'дежурный', 'weight': 0}],
#  [{'lemma': 'я', 'orig_word': 'я', 'stop_word': True, 'weight': 0},
#   {'lemma': 'идти', 'orig_word': 'идти', 'weight': 0},
#   {'lemma': 'на', 'orig_word': 'на', 'stop_word': True, 'weight': 0},
#   {'lemma': 'урок', 'orig_word': 'урок', 'weight': 0}],
#  [{'lemma': 'сегодня', 'orig_word': 'сегодня', 'weight': 0},
#   {'lemma': 'я', 'orig_word': 'я', 'stop_word': True, 'weight': 0},
#   {'lemma': 'не', 'orig_word': 'не', 'weight': 0},
#   {'lemma': 'опаздывать', 'orig_word': 'опаздывать', 'weight': 0},
#   {'lemma': 'отвечать', 'orig_word': 'отвечать', 'weight': 0},
#   {'lemma': 'джон', 'orig_word': 'джон', 'weight': 0}],
#  [{'lemma': 'идти', 'orig_word': 'идти', 'weight': 0},
#   {'lemma': 'домой', 'orig_word': 'домой', 'weight': 0},
#   {'lemma': 'молодой', 'orig_word': 'молодой', 'weight': 0},
#   {'lemma': 'человек', 'orig_word': 'человек', 'weight': 0}],
#  [{'lemma': 'сегодня', 'orig_word': 'сегодня', 'weight': 0},
#   {'lemma': 'нет', 'orig_word': 'нет', 'stop_word': True, 'weight': 0},
#   {'lemma': 'урок', 'orig_word': 'урок', 'weight': 0}],
#  [{'lemma': 'сегодня', 'orig_word': 'сегодня', 'weight': 0},
#   {'lemma': 'воскресение', 'orig_word': 'воскресение', 'weight': 0}]]

# %%
len(text_weighs_1)
# Out:
# 25

# %%
def get_tf_idf_dict(lemm_text_list, save_to_csv = False):
    vect = TfidfVectorizer(stop_words = russian_stopwords)
    tfidf_matrix = vect.fit_transform(lemm_text_list)
    df = pd.DataFrame(tfidf_matrix.toarray(), columns = vect.get_feature_names())
    #print(df.head())
    if (save_to_csv): df.to_csv("./text_0_tfidf.xlsx", sep = '\t')
    tf_idf_dict = df.to_dict()
    return tf_idf_dict
tfidf_dict = get_tf_idf_dict(lemm_sentences, save_to_csv = True)

# %%
def assign_tf_idf(weights_list_input, tf_idf_dict):
    weights_list = copy.deepcopy(weights_list_input)
    for sentence_ind in range(len(weights_list)):
        for el_ind in range(len(weights_list[sentence_ind])):
            lemma = weights_list[sentence_ind][el_ind]["word"]
            
            if (lemma in tf_idf_dict):
                weights_list[sentence_ind][el_ind]["weight"] = tf_idf_dict[lemma][sentence_ind]
                #print(lemma, tf_idf_dict[lemma][sentence_ind])
            #else:
                #weights_list[sentence_ind][el_ind]["weight"] = 0.05
                #print(lemma, "not found")
                
    return weights_list
text_weighs_tfidf_2 = assign_tf_idf(text_weighs_1, tfidf_dict)

# %%
text_weighs_tfidf_2
# Out:
# [[{'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'weight': 0.5361619670142973, 'word': 'класс'},
#   {'stop_word': True, 'weight': 0, 'word': 'быть'},
#   {'weight': 0.37093265612787246, 'word': 'урок'},
#   {'weight': 0.5361619670142973, 'word': 'русский'},
#   {'weight': 0.5361619670142973, 'word': 'язык'}],
#  [{'weight': 0.5, 'word': 'преподаватель'},
#   {'weight': 0.5, 'word': 'читать'},
#   {'weight': 0.5, 'word': 'новый'},
#   {'weight': 0.5, 'word': 'текст'}],
#  [{'weight': 0.5773502691896257, 'word': 'студент'},
#   {'weight': 0.5773502691896257, 'word': 'внимательно'},
#   {'weight': 0.5773502691896257, 'word': 'слушать'}],
#  [{'weight': 0.7071067811865475, 'word': 'извинять'},
#   {'stop_word': True, 'weight': 0, 'word': 'можно'},
#   {'weight': 0.7071067811865475, 'word': 'входить'}],
#  [{'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'weight': 0.45625299726699864, 'word': 'опаздывать'},
#   {'weight': 0.7465701692916523, 'word': 'сказать'},
#   {'weight': 0.48421708438335126, 'word': 'джон'}],
#  [{'stop_word': True, 'weight': 0, 'word': 'что'},
#   {'weight': 0.8069854513107882, 'word': 'случаться'},
#   {'weight': 0.5905713177701093, 'word': 'джон'}],
#  [{'weight': 0.5336592850313727, 'word': 'вчера'},
#   {'stop_word': True, 'weight': 0, 'word': 'вы'},
#   {'weight': 0.7359805436065483, 'word': 'опаздывать'},
#   {'weight': 0.41658181301205893, 'word': 'сегодня'},
#   {'stop_word': True, 'weight': 0, 'word': 'вы'},
#   {'weight': 0.7359805436065483, 'word': 'опаздывать'}],
#  [{'stop_word': True, 'weight': 0, 'word': 'нельзя'},
#   {'weight': 0.662044442799776, 'word': 'опаздывать'},
#   {'stop_word': True, 'weight': 0, 'word': 'на'},
#   {'weight': 0.7494645793884686, 'word': 'урок'}],
#  [{'weight': 0.578160915178323, 'word': 'вечер'},
#   {'weight': 0.37498872064186545, 'word': 'джон'},
#   {'weight': 0.5124028764319833, 'word': 'приходить'},
#   {'weight': 0.5124028764319833, 'word': 'домой'}],
#  [{'weight': 0.416738274777688, 'word': 'дома'},
#   {'stop_word': True, 'weight': 0, 'word': 'он'},
#   {'weight': 0.416738274777688, 'word': 'долго'},
#   {'weight': 0.416738274777688, 'word': 'думать'},
#   {'weight': 0.36933989328823413, 'word': 'вчера'},
#   {'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'weight': 0.5093642761633557, 'word': 'опаздывать'},
#   {'weight': 0.2883118249402291, 'word': 'сегодня'},
#   {'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'stop_word': True, 'weight': 0, 'word': 'тоже'},
#   {'weight': 0.5093642761633557, 'word': 'опаздывать'}],
#  [{'weight': 0.5773502691896257, 'word': 'это'},
#   {'weight': 0.5773502691896257, 'word': 'очень'},
#   {'weight': 0.5773502691896257, 'word': 'плохой'}],
#  [{'weight': 0.6575124635425807, 'word': 'не'},
#   {'stop_word': True, 'weight': 0, 'word': 'быть'},
#   {'stop_word': True, 'weight': 0, 'word': 'больше'},
#   {'weight': 0.49881319311467176, 'word': 'опаздывать'},
#   {'stop_word': True, 'weight': 0, 'word': 'на'},
#   {'weight': 0.5646793414504481, 'word': 'урок'}],
#  [{'weight': 0.2734604088822302, 'word': 'завтра'},
#   {'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'weight': 0.2734604088822302, 'word': 'вставать'},
#   {'weight': 0.30855431836237057, 'word': 'рано'},
#   {'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'weight': 0.24856088384840483, 'word': 'час'},
#   {'weight': 0.30855431836237057, 'word': 'быстро'},
#   {'weight': 0.2734604088822302, 'word': 'сделать'},
#   {'weight': 0.2734604088822302, 'word': 'зарядка'},
#   {'weight': 0.2734604088822302, 'word': 'приготавливать'},
#   {'weight': 0.2734604088822302, 'word': 'завтрак'},
#   {'weight': 0.2734604088822302, 'word': 'позавтракать'},
#   {'weight': 0.2734604088822302, 'word': 'повторять'},
#   {'weight': 0.2734604088822302, 'word': 'домашний'},
#   {'weight': 0.2734604088822302, 'word': 'задание'}],
#  [{'weight': 0.6591401887187024, 'word': 'завтра'},
#   {'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'weight': 0.5991231731043144, 'word': 'не'},
#   {'weight': 0.454516924949216, 'word': 'опаздывать'}],
#  [{'weight': 0.5918230094768323, 'word': 'утро'},
#   {'weight': 0.38384980261366636, 'word': 'джон'},
#   {'weight': 0.5245110910014203, 'word': 'вставать'},
#   {'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'weight': 0.47675252480058705, 'word': 'час'}],
#  [{'stop_word': True, 'weight': 0, 'word': 'он'},
#   {'weight': 0.31199562897878214, 'word': 'сделать'},
#   {'weight': 0.31199562897878214, 'word': 'зарядка'},
#   {'weight': 0.31199562897878214, 'word': 'приготавливать'},
#   {'weight': 0.31199562897878214, 'word': 'завтрак'},
#   {'weight': 0.31199562897878214, 'word': 'позавтракать'},
#   {'weight': 0.31199562897878214, 'word': 'повторять'},
#   {'weight': 0.31199562897878214, 'word': 'домашний'},
#   {'weight': 0.31199562897878214, 'word': 'задание'},
#   {'stop_word': True, 'weight': 0, 'word': 'и'},
#   {'weight': 0.3520348668572578, 'word': 'пойти'},
#   {'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'weight': 0.31199562897878214, 'word': 'институт'}],
#  [{'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'weight': 0.42220060848498, 'word': 'час'},
#   {'weight': 0.52410427154223, 'word': 'минута'},
#   {'weight': 0.33992818454000945, 'word': 'джон'},
#   {'weight': 0.4644944499676149, 'word': 'приходить'},
#   {'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'weight': 0.4644944499676149, 'word': 'институт'}],
#  [{'stop_word': True, 'weight': 0, 'word': 'что'},
#   {'weight': 0.5773502691896257, 'word': 'случаться'},
#   {'weight': 0.5773502691896257, 'word': 'молодой'},
#   {'weight': 0.5773502691896257, 'word': 'человек'}],
#  [{'stop_word': True, 'weight': 0, 'word': 'куда'},
#   {'stop_word': True, 'weight': 0, 'word': 'вы'},
#   {'weight': 1.0, 'word': 'идти'}],
#  [{'weight': 0.7071067811865475, 'word': 'спрашивать'},
#   {'weight': 0.7071067811865475, 'word': 'дежурный'}],
#  [{'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'weight': 0.7586307126040724, 'word': 'идти'},
#   {'stop_word': True, 'weight': 0, 'word': 'на'},
#   {'weight': 0.6515208683486948, 'word': 'урок'}],
#  [{'weight': 0.4047437654505217, 'word': 'сегодня'},
#   {'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'weight': 0.47128352463063505, 'word': 'не'},
#   {'weight': 0.3575330549884247, 'word': 'опаздывать'},
#   {'weight': 0.5850339942728455, 'word': 'отвечать'},
#   {'weight': 0.3794465230786324, 'word': 'джон'}],
#  [{'weight': 0.4646815335637525, 'word': 'идти'},
#   {'weight': 0.5112308912043686, 'word': 'домой'},
#   {'weight': 0.5112308912043686, 'word': 'молодой'},
#   {'weight': 0.5112308912043686, 'word': 'человек'}],
#  [{'weight': 0.7071067811865476, 'word': 'сегодня'},
#   {'stop_word': True, 'weight': 0, 'word': 'нет'},
#   {'weight': 0.7071067811865476, 'word': 'урок'}],
#  [{'weight': 0.5689440996114069, 'word': 'сегодня'},
#   {'weight': 0.822376198292099, 'word': 'воскресение'}]]

# %%
def get_text_vocabulary_20_percent_size(lemm_text_sentences_list):
    vocab = []
    for sentence in lemm_text_sentences_list:
        for word in sentence.split():
            vocab.append(word)
    vocab_set = set(vocab)
    return int(round(len(vocab_set) * 0.2,0))
text_vocab_20_percent_len = get_text_vocabulary_20_percent_size(lemm_sentences)

# %%
text_vocab_20_percent_len
# Out:
# 14

# %%
def get_top_20_percent_words(lemm_text_sentences_list, top_n):
    """получаем топ 100 слов на основании tfidf"""
            #tfidf = TfidfVectorizer(ngram_range = {1,2})
    #vect = TfidfVectorizer(stop_words = russian_stopwords)
    #X = vect.fit_transform(lemm_text_sentences_list)
    vect = TfidfVectorizer(stop_words = russian_stopwords)
    X = vect.fit_transform(lemm_text_sentences_list)
    #print(len(X.sum(axis=0)[0]), X.sum(axis=0))
   # индексы топ 10 столбцов с максимальной суммой элементов (в столбцах)
    idx = np.ravel(X.sum(axis=0).argsort(axis=1))[::-1][:top_n]
    top_words = np.array(vect.get_feature_names())[idx].tolist()
    return top_words
top_20_percent_words = get_top_20_percent_words(lemm_sentences, text_vocab_20_percent_len)

# %%
def update_weights_with_top_words(weights_list_input, top_words):
    weights_list = copy.deepcopy(weights_list_input)
    for sentence_ind in range(len(weights_list)):
        for el_ind in range(len(weights_list[sentence_ind])):
            lemma = weights_list[sentence_ind][el_ind]["word"]
            
            if (lemma in top_words):
                weights_list[sentence_ind][el_ind]["top_20_word"] = True
                #print(lemma, tf_idf_dict[lemma][sentence_ind])

                
    return weights_list
top_words_weights_3 = update_weights_with_top_words(text_weighs_tfidf_2, top_20_percent_words)

# %%
top_words_weights_3[0]
# Out:
# [{'stop_word': True, 'weight': 0, 'word': 'в'},
#  {'weight': 0.5361619670142973, 'word': 'класс'},
#  {'stop_word': True, 'weight': 0, 'word': 'быть'},
#  {'top_20_word': True, 'weight': 0.37093265612787246, 'word': 'урок'},
#  {'weight': 0.5361619670142973, 'word': 'русский'},
#  {'weight': 0.5361619670142973, 'word': 'язык'}]

# %%
text_grammar_map_ex[0]
# Out:
# [{'analysis': [{'gr': 'PR=', 'lex': 'в', 'wt': 0.9999917878000001}],
#   'text': 'в'},
#  {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'класс', 'wt': 1}],
#   'text': 'классе'},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,муж,несов', 'lex': 'быть', 'wt': 1}],
#   'text': 'был'},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)',
#     'lex': 'урок',
#     'wt': 0.9992735223}],
#   'text': 'урок'},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#     'lex': 'русский',
#     'wt': 0.9496245492000001}],
#   'text': 'русского'},
#  {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'язык', 'wt': 0.9963354032}],
#   'text': 'языка'}]

# %%
def update_pos(weights_list, gr_map):
    
    sentences_weights_list_output = copy.deepcopy(weights_list)
    assert len(sentences_weights_list_output) == len(gr_map)#кол-во предложений
    for weights_sentence, gr_map_sentence in zip(sentences_weights_list_output, gr_map):
        assert len(weights_sentence) == len(gr_map_sentence )#кол-во слов
        for weight_word, gramm_map_word in zip(weights_sentence, gr_map_sentence):
            keys = list(gramm_map_word.keys())
            values = list(gramm_map_word.values())
            word  = gramm_map_word['text']
            #print(weight_word['word'])
            if ('analysis' not in keys):
                pass
            elif(gramm_map_word['analysis'] ==[]):
                pass
            else:
                grammar = gramm_map_word['analysis'][0]['gr']
                assert (weight_word['word'] == gramm_map_word['analysis'][0]['lex'])
                grammar_sep_by_comma = grammar.split(',')
                if (len(grammar_sep_by_comma) == 1):
                    weight_word['POS'] = "undefined"
                else:
                    pos = re.match('[A-Z\s]+', grammar_sep_by_comma[0])[0]
                    weight_word['POS'] = pos
                    
    return sentences_weights_list_output
pos_words_weights_4 = update_pos(top_words_weights_3, text_grammar_map_ex)
pos_words_weights_4
# Out:
# [[{'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'POS': 'S', 'weight': 0.5361619670142973, 'word': 'класс'},
#   {'POS': 'V', 'stop_word': True, 'weight': 0, 'word': 'быть'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.37093265612787246,
#    'word': 'урок'},
#   {'POS': 'A', 'weight': 0.5361619670142973, 'word': 'русский'},
#   {'POS': 'S', 'weight': 0.5361619670142973, 'word': 'язык'}],
#  [{'POS': 'S', 'weight': 0.5, 'word': 'преподаватель'},
#   {'POS': 'V', 'weight': 0.5, 'word': 'читать'},
#   {'POS': 'A', 'weight': 0.5, 'word': 'новый'},
#   {'POS': 'S', 'weight': 0.5, 'word': 'текст'}],
#  [{'POS': 'S', 'weight': 0.5773502691896257, 'word': 'студент'},
#   {'POS': 'undefined', 'weight': 0.5773502691896257, 'word': 'внимательно'},
#   {'POS': 'V', 'weight': 0.5773502691896257, 'word': 'слушать'}],
#  [{'POS': 'V', 'weight': 0.7071067811865475, 'word': 'извинять'},
#   {'POS': 'ADV', 'stop_word': True, 'weight': 0, 'word': 'можно'},
#   {'POS': 'V', 'weight': 0.7071067811865475, 'word': 'входить'}],
#  [{'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.45625299726699864,
#    'word': 'опаздывать'},
#   {'POS': 'V', 'weight': 0.7465701692916523, 'word': 'сказать'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.48421708438335126,
#    'word': 'джон'}],
#  [{'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'что'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.8069854513107882,
#    'word': 'случаться'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.5905713177701093,
#    'word': 'джон'}],
#  [{'POS': 'undefined', 'weight': 0.5336592850313727, 'word': 'вчера'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'вы'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.7359805436065483,
#    'word': 'опаздывать'},
#   {'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.41658181301205893,
#    'word': 'сегодня'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'вы'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.7359805436065483,
#    'word': 'опаздывать'}],
#  [{'POS': 'ADV', 'stop_word': True, 'weight': 0, 'word': 'нельзя'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.662044442799776,
#    'word': 'опаздывать'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'на'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.7494645793884686,
#    'word': 'урок'}],
#  [{'POS': 'S', 'weight': 0.578160915178323, 'word': 'вечер'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.37498872064186545,
#    'word': 'джон'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.5124028764319833,
#    'word': 'приходить'},
#   {'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.5124028764319833,
#    'word': 'домой'}],
#  [{'POS': 'undefined', 'weight': 0.416738274777688, 'word': 'дома'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'он'},
#   {'POS': 'undefined', 'weight': 0.416738274777688, 'word': 'долго'},
#   {'POS': 'V', 'weight': 0.416738274777688, 'word': 'думать'},
#   {'POS': 'undefined', 'weight': 0.36933989328823413, 'word': 'вчера'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.5093642761633557,
#    'word': 'опаздывать'},
#   {'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.2883118249402291,
#    'word': 'сегодня'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'тоже'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.5093642761633557,
#    'word': 'опаздывать'}],
#  [{'POS': 'SPRO', 'weight': 0.5773502691896257, 'word': 'это'},
#   {'POS': 'undefined', 'weight': 0.5773502691896257, 'word': 'очень'},
#   {'POS': 'A', 'weight': 0.5773502691896257, 'word': 'плохой'}],
#  [{'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.6575124635425807,
#    'word': 'не'},
#   {'POS': 'V', 'stop_word': True, 'weight': 0, 'word': 'быть'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'больше'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.49881319311467176,
#    'word': 'опаздывать'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'на'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.5646793414504481,
#    'word': 'урок'}],
#  [{'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.2734604088822302,
#    'word': 'завтра'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'POS': 'V', 'weight': 0.2734604088822302, 'word': 'вставать'},
#   {'POS': 'undefined', 'weight': 0.30855431836237057, 'word': 'рано'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.24856088384840483,
#    'word': 'час'},
#   {'POS': 'undefined', 'weight': 0.30855431836237057, 'word': 'быстро'},
#   {'POS': 'V', 'weight': 0.2734604088822302, 'word': 'сделать'},
#   {'POS': 'S', 'weight': 0.2734604088822302, 'word': 'зарядка'},
#   {'POS': 'V', 'weight': 0.2734604088822302, 'word': 'приготавливать'},
#   {'POS': 'S', 'weight': 0.2734604088822302, 'word': 'завтрак'},
#   {'POS': 'V', 'weight': 0.2734604088822302, 'word': 'позавтракать'},
#   {'POS': 'V', 'weight': 0.2734604088822302, 'word': 'повторять'},
#   {'POS': 'A', 'weight': 0.2734604088822302, 'word': 'домашний'},
#   {'POS': 'S', 'weight': 0.2734604088822302, 'word': 'задание'}],
#  [{'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.6591401887187024,
#    'word': 'завтра'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.5991231731043144,
#    'word': 'не'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.454516924949216,
#    'word': 'опаздывать'}],
#  [{'POS': 'S', 'weight': 0.5918230094768323, 'word': 'утро'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.38384980261366636,
#    'word': 'джон'},
#   {'POS': 'V', 'weight': 0.5245110910014203, 'word': 'вставать'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.47675252480058705,
#    'word': 'час'}],
#  [{'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'он'},
#   {'POS': 'V', 'weight': 0.31199562897878214, 'word': 'сделать'},
#   {'POS': 'S', 'weight': 0.31199562897878214, 'word': 'зарядка'},
#   {'POS': 'V', 'weight': 0.31199562897878214, 'word': 'приготавливать'},
#   {'POS': 'S', 'weight': 0.31199562897878214, 'word': 'завтрак'},
#   {'POS': 'V', 'weight': 0.31199562897878214, 'word': 'позавтракать'},
#   {'POS': 'V', 'weight': 0.31199562897878214, 'word': 'повторять'},
#   {'POS': 'A', 'weight': 0.31199562897878214, 'word': 'домашний'},
#   {'POS': 'S', 'weight': 0.31199562897878214, 'word': 'задание'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'и'},
#   {'POS': 'V', 'weight': 0.3520348668572578, 'word': 'пойти'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'POS': 'S', 'weight': 0.31199562897878214, 'word': 'институт'}],
#  [{'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'POS': 'S', 'top_20_word': True, 'weight': 0.42220060848498, 'word': 'час'},
#   {'POS': 'S', 'weight': 0.52410427154223, 'word': 'минута'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.33992818454000945,
#    'word': 'джон'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.4644944499676149,
#    'word': 'приходить'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'в'},
#   {'POS': 'S', 'weight': 0.4644944499676149, 'word': 'институт'}],
#  [{'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'что'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.5773502691896257,
#    'word': 'случаться'},
#   {'POS': 'A',
#    'top_20_word': True,
#    'weight': 0.5773502691896257,
#    'word': 'молодой'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.5773502691896257,
#    'word': 'человек'}],
#  [{'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'куда'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'вы'},
#   {'POS': 'V', 'top_20_word': True, 'weight': 1.0, 'word': 'идти'}],
#  [{'POS': 'V', 'weight': 0.7071067811865475, 'word': 'спрашивать'},
#   {'POS': 'S', 'weight': 0.7071067811865475, 'word': 'дежурный'}],
#  [{'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.7586307126040724,
#    'word': 'идти'},
#   {'POS': 'undefined', 'stop_word': True, 'weight': 0, 'word': 'на'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.6515208683486948,
#    'word': 'урок'}],
#  [{'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.4047437654505217,
#    'word': 'сегодня'},
#   {'POS': 'SPRO', 'stop_word': True, 'weight': 0, 'word': 'я'},
#   {'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.47128352463063505,
#    'word': 'не'},
#   {'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.3575330549884247,
#    'word': 'опаздывать'},
#   {'POS': 'V', 'weight': 0.5850339942728455, 'word': 'отвечать'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.3794465230786324,
#    'word': 'джон'}],
#  [{'POS': 'V',
#    'top_20_word': True,
#    'weight': 0.4646815335637525,
#    'word': 'идти'},
#   {'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.5112308912043686,
#    'word': 'домой'},
#   {'POS': 'A',
#    'top_20_word': True,
#    'weight': 0.5112308912043686,
#    'word': 'молодой'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.5112308912043686,
#    'word': 'человек'}],
#  [{'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.7071067811865476,
#    'word': 'сегодня'},
#   {'POS': 'ADV', 'stop_word': True, 'weight': 0, 'word': 'нет'},
#   {'POS': 'S',
#    'top_20_word': True,
#    'weight': 0.7071067811865476,
#    'word': 'урок'}],
#  [{'POS': 'undefined',
#    'top_20_word': True,
#    'weight': 0.5689440996114069,
#    'word': 'сегодня'},
#   {'POS': 'S', 'weight': 0.822376198292099, 'word': 'воскресение'}]]

# %% [raw]
# def detect_abstract(weights_list_input):
#     weights_list = copy.deepcopy(weights_list_input)
#     abs_suff={'аж', 'есть', 'ие', 'изм', 'изна', 'ина', 'ость', 'ота', 'ствo', 'ция',
#  'чина','щина','ёж','еж'}
#     morph = pymorphy2.MorphAnalyzer()
#     for sentence_ind in range(len(weights_list)):
#         for el_ind in range(len(weights_list[sentence_ind])):
#             lemma = weights_list[sentence_ind][el_ind]["word"]
#             pos = morph.parse(lemma)[0].tag.POS
#             if(pos == 'NOUN'):
#                 for suff in abs_suff:
#                     if (lemma.endswith(suff)):
#                         weights_list[sentence_ind][el_ind]["abstract_noun"] = True
#                         return weights_list
#     return weights_list
# pos_weights_4 = detect_abstract(top_words_weights_3)

# %%
df_sence = pd.read_csv("./for calculation/mult_sence.csv")
sence_dict = pd.Series(df_sence.count_rank.values,index=df_sence.word).to_dict()

def low(word):
    return word.lower()
df_freq = pd.read_csv("./for calculation/freq_lables.csv")
df_freq['Lemma'] = df_freq['Lemma'].apply(low)
freq_pos_dict = pd.Series(df_freq.PoS.values,index=df_freq.Lemma).to_dict()
freq_dict = pd.Series(df_freq.freq_lable.values,index=df_freq.Lemma).to_dict()

df_eng = pd.read_csv("./for calculation/eng_words.csv", sep = ' ')
eng_words = set(df_eng['orth'])

# %%
len(eng_words)
# Out:
# 665

# %%
def create_lex_vector(lexema, pos):
    #если слова нет в часотном словаре, значит оно скорее всего довольно редкое и признаем его относящ к категории 2
    #если слово не заимствовано то признаем сложным 1 
    sence_value, freq_value, eng_value, abstract= 0,2,1,0
    diff_analysis = {}
    
    if(lexema in sence_dict):
        #print(lexema, "found")
        sence_value = sence_dict[lexema]
        
        
    if(lexema in freq_dict):
        freq_value = freq_dict[lexema]
    else:
        diff_analysis["freq_value_note"] = "not in freq dict"
    
    if(lexema in eng_words):
        eng_value = 0
    abs_suff={'аж', 'есть', 'ие', 'изм', 'изна', 'ина', 'ость', 'ота', 'ствo', 'ция',
 'чина','щина','ёж','еж'}   
    if(pos == "S"):
        for suff in abs_suff:
            if (lexema.endswith(suff)):
                abstract = 1

    diff_analysis['raw_diff_values'] = [sence_value, freq_value, eng_value, abstract]
    diff_analysis_named = OrderedDict()
    diff_analysis_named['sence_value'] = sence_value
    diff_analysis_named['freq_value'] = freq_value
    diff_analysis_named['eng_value'] = eng_value
    diff_analysis_named['abstract'] = abstract
    #diff_analysis_named = { "freq_value":freq_value, "eng_value":eng_value, "abstract":abstract, "sence_value":sence_value}

    
    return diff_analysis, diff_analysis_named

# %%
def update_with_lex_vector(weights_list_input):
    weights_list = copy.deepcopy(weights_list_input)
    for sentence_ind in range(len(weights_list)):
        for el_ind in range(len(weights_list[sentence_ind])):
            lemma = weights_list[sentence_ind][el_ind]["word"]
            if('digit' in weights_list[sentence_ind][el_ind]):
                diff_analysis['raw_diff_values'] = [0,0,0,0]
                diff_analysis_named = {"sence_value":0, "freq_value":0, "eng_value":0, "abstract":0}
            else:
                diff_analysis,diff_analysis_named  = create_lex_vector(lemma,weights_list[sentence_ind][el_ind]["POS"])
            weights_list[sentence_ind][el_ind]["lex_vector"] = {"raw": diff_analysis, "named": diff_analysis_named}
            
    return weights_list
lex_vector_weights_5 = update_with_lex_vector(pos_words_weights_4)

# %%
lex_vector_weights_5[0]
# Out:
# [{'POS': 'undefined',
#   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                 ('freq_value', 0),
#                 ('eng_value', 1),
#                 ('abstract', 0)]),
#    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#   'stop_word': True,
#   'weight': 0,
#   'word': 'в'},
#  {'POS': 'S',
#   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                 ('freq_value', 0),
#                 ('eng_value', 1),
#                 ('abstract', 0)]),
#    'raw': {'raw_diff_values': [1, 0, 1, 0]}},
#   'weight': 0.5361619670142973,
#   'word': 'класс'},
#  {'POS': 'V',
#   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                 ('freq_value', 0),
#                 ('eng_value', 1),
#                 ('abstract', 0)]),
#    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#   'stop_word': True,
#   'weight': 0,
#   'word': 'быть'},
#  {'POS': 'S',
#   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                 ('freq_value', 1),
#                 ('eng_value', 1),
#                 ('abstract', 0)]),
#    'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#   'top_20_word': True,
#   'weight': 0.37093265612787246,
#   'word': 'урок'},
#  {'POS': 'A',
#   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                 ('freq_value', 1),
#                 ('eng_value', 1),
#                 ('abstract', 0)]),
#    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#   'weight': 0.5361619670142973,
#   'word': 'русский'},
#  {'POS': 'S',
#   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                 ('freq_value', 0),
#                 ('eng_value', 1),
#                 ('abstract', 0)]),
#    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#   'weight': 0.5361619670142973,
#   'word': 'язык'}]

# %%
m.analyze("не идут это")
# Out:
# [{'analysis': [{'gr': 'PART=', 'lex': 'не', 'wt': 1}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,нп=непрош,мн,изъяв,3-л',
#     'lex': 'идти',
#     'wt': 1}],
#   'text': 'идут'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=(вин|им)',
#     'lex': 'это',
#     'wt': 0.7809833731}],
#   'text': 'это'},
#  {'text': '\n'}]

# %%
def update_coreference_negation(weight_list):
    weight_list_output = copy.deepcopy(weight_list)
    coreference_list = ["который","которая","это","этот","эти","которое"]
    negation_list = ["не","ни","бы"]
    all_sentences_map = []
    for sentence in weight_list_output:
        sentence_map = {'words':[],"negation_items":[],"coreference_items":[]}
        for word_weight in sentence:
            #print(word_weight)
            if word_weight['word'] in negation_list:
                sentence_map['negation_items'].append(word_weight['word'])
                word_weight['negation'] = True
            elif word_weight['word'] in coreference_list:
                sentence_map['coreference_items'].append(word_weight['word'])
                word_weight['coreference'] = True
            sentence_map['words'].append(word_weight)
        all_sentences_map.append(sentence_map)
    return all_sentences_map

sts_map = update_coreference_negation(lex_vector_weights_5)
for sent in sts_map:
    print (sent)
    print()
# Out:
# {'words': [{'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'класс', 'weight': 0.5361619670142973, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'быть', 'weight': 0, 'stop_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'урок', 'weight': 0.37093265612787246, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'русский', 'weight': 0.5361619670142973, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'язык', 'weight': 0.5361619670142973, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'преподаватель', 'weight': 0.5, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'читать', 'weight': 0.5, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'новый', 'weight': 0.5, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'текст', 'weight': 0.5, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'студент', 'weight': 0.5773502691896257, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'внимательно', 'weight': 0.5773502691896257, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'слушать', 'weight': 0.5773502691896257, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'извинять', 'weight': 0.7071067811865475, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'можно', 'weight': 0, 'stop_word': True, 'POS': 'ADV', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'входить', 'weight': 0.7071067811865475, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'опаздывать', 'weight': 0.45625299726699864, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'сказать', 'weight': 0.7465701692916523, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'джон', 'weight': 0.48421708438335126, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'что', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [1, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'случаться', 'weight': 0.8069854513107882, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'джон', 'weight': 0.5905713177701093, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'вчера', 'weight': 0.5336592850313727, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'вы', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'опаздывать', 'weight': 0.7359805436065483, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'сегодня', 'weight': 0.41658181301205893, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'вы', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'опаздывать', 'weight': 0.7359805436065483, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'нельзя', 'weight': 0, 'stop_word': True, 'POS': 'ADV', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'опаздывать', 'weight': 0.662044442799776, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'на', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'урок', 'weight': 0.7494645793884686, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'вечер', 'weight': 0.578160915178323, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'джон', 'weight': 0.37498872064186545, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'приходить', 'weight': 0.5124028764319833, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'домой', 'weight': 0.5124028764319833, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'дома', 'weight': 0.416738274777688, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'он', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'долго', 'weight': 0.416738274777688, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'думать', 'weight': 0.416738274777688, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'вчера', 'weight': 0.36933989328823413, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'опаздывать', 'weight': 0.5093642761633557, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'сегодня', 'weight': 0.2883118249402291, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'тоже', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'опаздывать', 'weight': 0.5093642761633557, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'это', 'weight': 0.5773502691896257, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'coreference': True}, {'word': 'очень', 'weight': 0.5773502691896257, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'плохой', 'weight': 0.5773502691896257, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': ['это']}
#
# {'words': [{'word': 'не', 'weight': 0.6575124635425807, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'negation': True}, {'word': 'быть', 'weight': 0, 'stop_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'больше', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'опаздывать', 'weight': 0.49881319311467176, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'на', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'урок', 'weight': 0.5646793414504481, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': ['не'], 'coreference_items': []}
#
# {'words': [{'word': 'завтра', 'weight': 0.2734604088822302, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'вставать', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'рано', 'weight': 0.30855431836237057, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'час', 'weight': 0.24856088384840483, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'быстро', 'weight': 0.30855431836237057, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'сделать', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'зарядка', 'weight': 0.2734604088822302, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'приготавливать', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'завтрак', 'weight': 0.2734604088822302, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'позавтракать', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'повторять', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'домашний', 'weight': 0.2734604088822302, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'задание', 'weight': 0.2734604088822302, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 1]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 1)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'завтра', 'weight': 0.6591401887187024, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'не', 'weight': 0.5991231731043144, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'negation': True}, {'word': 'опаздывать', 'weight': 0.454516924949216, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': ['не'], 'coreference_items': []}
#
# {'words': [{'word': 'утро', 'weight': 0.5918230094768323, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'джон', 'weight': 0.38384980261366636, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'вставать', 'weight': 0.5245110910014203, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'час', 'weight': 0.47675252480058705, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'он', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'сделать', 'weight': 0.31199562897878214, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'зарядка', 'weight': 0.31199562897878214, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'приготавливать', 'weight': 0.31199562897878214, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'завтрак', 'weight': 0.31199562897878214, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'позавтракать', 'weight': 0.31199562897878214, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'повторять', 'weight': 0.31199562897878214, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'домашний', 'weight': 0.31199562897878214, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'задание', 'weight': 0.31199562897878214, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 1]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 1)])}}, {'word': 'и', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'пойти', 'weight': 0.3520348668572578, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'институт', 'weight': 0.31199562897878214, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'час', 'weight': 0.42220060848498, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'минута', 'weight': 0.52410427154223, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'джон', 'weight': 0.33992818454000945, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'приходить', 'weight': 0.4644944499676149, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'институт', 'weight': 0.4644944499676149, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'что', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [1, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'случаться', 'weight': 0.5773502691896257, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'молодой', 'weight': 0.5773502691896257, 'top_20_word': True, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'человек', 'weight': 0.5773502691896257, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'куда', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'вы', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'идти', 'weight': 1.0, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'спрашивать', 'weight': 0.7071067811865475, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'дежурный', 'weight': 0.7071067811865475, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'идти', 'weight': 0.7586307126040724, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'на', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'урок', 'weight': 0.6515208683486948, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'сегодня', 'weight': 0.4047437654505217, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'не', 'weight': 0.47128352463063505, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'negation': True}, {'word': 'опаздывать', 'weight': 0.3575330549884247, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'отвечать', 'weight': 0.5850339942728455, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'джон', 'weight': 0.3794465230786324, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': ['не'], 'coreference_items': []}
#
# {'words': [{'word': 'идти', 'weight': 0.4646815335637525, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'домой', 'weight': 0.5112308912043686, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'молодой', 'weight': 0.5112308912043686, 'top_20_word': True, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'человек', 'weight': 0.5112308912043686, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'сегодня', 'weight': 0.7071067811865476, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'нет', 'weight': 0, 'stop_word': True, 'POS': 'ADV', 'lex_vector': {'raw': {'raw_diff_values': [2, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'урок', 'weight': 0.7071067811865476, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}], 'negation_items': [], 'coreference_items': []}
#
# {'words': [{'word': 'сегодня', 'weight': 0.5689440996114069, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}, {'word': 'воскресение', 'weight': 0.822376198292099, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 1]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 1)])}}], 'negation_items': [], 'coreference_items': []}

# %%
m.analyze("мыть")
# Out:
# [{'analysis': [{'gr': 'V,несов,пе=инф', 'lex': 'мыть', 'wt': 1}],
#   'text': 'мыть'},
#  {'text': '\n'}]

# %%
m.analyze("мыться")
# Out:
# [{'analysis': [{'gr': 'V,несов,нп=инф', 'lex': 'мыться', 'wt': 1}],
#   'text': 'мыться'},
#  {'text': '\n'}]

# %%
m.analyze("делая")
# Out:
# [{'analysis': [{'gr': 'V,несов,пе=непрош,деепр', 'lex': 'делать', 'wt': 1}],
#   'text': 'делая'},
#  {'text': '\n'}]

# %%
m.analyze("делавший")
# Out:
# [{'analysis': [{'gr': 'V,несов,пе=(прош,вин,ед,прич,полн,муж,действ,неод|прош,им,ед,прич,полн,муж,действ)',
#     'lex': 'делать',
#     'wt': 1}],
#   'text': 'делавший'},
#  {'text': '\n'}]

# %%
len(text_grammar_map_ex[0]), len(sts_map[0]['words'] )
# Out:
# (6, 6)

# %%
len(text_grammar_map_ex), len(sts_map)
# Out:
# (25, 25)

# %%
def update_weight(s_weight, w_weight, pos):
    if ("special_pos" in w_weight):
        w_weight['special_pos'].append(pos)
    else:
        w_weight['special_pos'] = []
        w_weight['special_pos'].append(pos)
    s_weight['sent_special_pos'].append(w_weight['word'] + '_' + pos)

def update_special_pos(sentences_weights_list, gr_map):
    special_pos_list = ["инф", "прич", "деепр"]
    
    sentences_weights_list_output = copy.deepcopy(sentences_weights_list)
    assert len(sentences_weights_list_output) == len(gr_map)#кол-во предложений
    for weights_sentence, gr_map_sentence in zip(sentences_weights_list_output, gr_map):
        assert len(weights_sentence['words']) == len(gr_map_sentence )#кол-во слов
        weights_sentence['sent_special_pos'] = []
        for weight_word, gramm_map_word in zip(weights_sentence['words'], gr_map_sentence):
            keys = list(gramm_map_word.keys())
            values = list(gramm_map_word.values())
            word  = gramm_map_word['text']
            #print(weight_word['word'])
            if ('analysis' not in keys):
                pass
            elif(gramm_map_word['analysis'] ==[]):
                pass
            else:
                grammar = gramm_map_word['analysis'][0]['gr']
                assert (weight_word['word'] == gramm_map_word['analysis'][0]['lex'])
                for spec_pos in special_pos_list:
                    if (spec_pos in grammar):
                        update_weight(weights_sentence, weight_word,spec_pos)
                grammar_sep_by_comma = grammar.split(',')
                if (len(grammar_sep_by_comma) == 1):
                    pass
                else:
                    pos = re.match('[A-Z\s]+', grammar_sep_by_comma[0])[0]
                    if(pos == "V"):
                        if(gramm_map_word["text"].endswith("сь") or gramm_map_word["text"].endswith("ся")):
                            update_weight(weights_sentence, weight_word,"возвратный")
    return sentences_weights_list_output
sts_map_spec_2 = update_special_pos(sts_map, text_grammar_map_ex)

# %%
for sentence in sts_map_spec_2:
    print("sentence")
    print(sentence['negation_items'],sentence['coreference_items'],sentence['sent_special_pos'])
    for word in sentence['words']:
        print(word)
        print ( )
    print("==================================================")
# Out:
# sentence
# [] [] []
# {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'класс', 'weight': 0.5361619670142973, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'быть', 'weight': 0, 'stop_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'урок', 'weight': 0.37093265612787246, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'русский', 'weight': 0.5361619670142973, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'язык', 'weight': 0.5361619670142973, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'преподаватель', 'weight': 0.5, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'читать', 'weight': 0.5, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'новый', 'weight': 0.5, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'текст', 'weight': 0.5, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'студент', 'weight': 0.5773502691896257, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'внимательно', 'weight': 0.5773502691896257, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'слушать', 'weight': 0.5773502691896257, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] ['входить_инф']
# {'word': 'извинять', 'weight': 0.7071067811865475, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'можно', 'weight': 0, 'stop_word': True, 'POS': 'ADV', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'входить', 'weight': 0.7071067811865475, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'special_pos': ['инф']}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'опаздывать', 'weight': 0.45625299726699864, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'сказать', 'weight': 0.7465701692916523, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'джон', 'weight': 0.48421708438335126, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] ['случаться_возвратный']
# {'word': 'что', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [1, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'случаться', 'weight': 0.8069854513107882, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}, 'special_pos': ['возвратный']}
#
# {'word': 'джон', 'weight': 0.5905713177701093, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'вчера', 'weight': 0.5336592850313727, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'вы', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'опаздывать', 'weight': 0.7359805436065483, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'сегодня', 'weight': 0.41658181301205893, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'вы', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'опаздывать', 'weight': 0.7359805436065483, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] ['опаздывать_инф']
# {'word': 'нельзя', 'weight': 0, 'stop_word': True, 'POS': 'ADV', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'опаздывать', 'weight': 0.662044442799776, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}, 'special_pos': ['инф']}
#
# {'word': 'на', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'урок', 'weight': 0.7494645793884686, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'вечер', 'weight': 0.578160915178323, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'джон', 'weight': 0.37498872064186545, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'приходить', 'weight': 0.5124028764319833, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'домой', 'weight': 0.5124028764319833, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'дома', 'weight': 0.416738274777688, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'он', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'долго', 'weight': 0.416738274777688, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'думать', 'weight': 0.416738274777688, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'вчера', 'weight': 0.36933989328823413, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'опаздывать', 'weight': 0.5093642761633557, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'сегодня', 'weight': 0.2883118249402291, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'тоже', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'опаздывать', 'weight': 0.5093642761633557, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] ['это'] []
# {'word': 'это', 'weight': 0.5773502691896257, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'coreference': True}
#
# {'word': 'очень', 'weight': 0.5773502691896257, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'плохой', 'weight': 0.5773502691896257, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# ['не'] [] ['опаздывать_инф']
# {'word': 'не', 'weight': 0.6575124635425807, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'negation': True}
#
# {'word': 'быть', 'weight': 0, 'stop_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'больше', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'опаздывать', 'weight': 0.49881319311467176, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}, 'special_pos': ['инф']}
#
# {'word': 'на', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'урок', 'weight': 0.5646793414504481, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'завтра', 'weight': 0.2734604088822302, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'вставать', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'рано', 'weight': 0.30855431836237057, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'час', 'weight': 0.24856088384840483, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'быстро', 'weight': 0.30855431836237057, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'сделать', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'зарядка', 'weight': 0.2734604088822302, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'приготавливать', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'завтрак', 'weight': 0.2734604088822302, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'позавтракать', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'повторять', 'weight': 0.2734604088822302, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'домашний', 'weight': 0.2734604088822302, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'задание', 'weight': 0.2734604088822302, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 1]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 1)])}}
#
# ==================================================
# sentence
# ['не'] [] []
# {'word': 'завтра', 'weight': 0.6591401887187024, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'не', 'weight': 0.5991231731043144, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'negation': True}
#
# {'word': 'опаздывать', 'weight': 0.454516924949216, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'утро', 'weight': 0.5918230094768323, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'джон', 'weight': 0.38384980261366636, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'вставать', 'weight': 0.5245110910014203, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'час', 'weight': 0.47675252480058705, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'он', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'сделать', 'weight': 0.31199562897878214, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'зарядка', 'weight': 0.31199562897878214, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'приготавливать', 'weight': 0.31199562897878214, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'завтрак', 'weight': 0.31199562897878214, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'позавтракать', 'weight': 0.31199562897878214, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'повторять', 'weight': 0.31199562897878214, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'домашний', 'weight': 0.31199562897878214, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'задание', 'weight': 0.31199562897878214, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 1]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 1)])}}
#
# {'word': 'и', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'пойти', 'weight': 0.3520348668572578, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'институт', 'weight': 0.31199562897878214, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'час', 'weight': 0.42220060848498, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'минута', 'weight': 0.52410427154223, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'джон', 'weight': 0.33992818454000945, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'приходить', 'weight': 0.4644944499676149, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'в', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'институт', 'weight': 0.4644944499676149, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] ['случаться_возвратный']
# {'word': 'что', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [1, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'случаться', 'weight': 0.5773502691896257, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}, 'special_pos': ['возвратный']}
#
# {'word': 'молодой', 'weight': 0.5773502691896257, 'top_20_word': True, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'человек', 'weight': 0.5773502691896257, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'куда', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'вы', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'идти', 'weight': 1.0, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'спрашивать', 'weight': 0.7071067811865475, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'дежурный', 'weight': 0.7071067811865475, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'идти', 'weight': 0.7586307126040724, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'на', 'weight': 0, 'stop_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'урок', 'weight': 0.6515208683486948, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# ['не'] [] []
# {'word': 'сегодня', 'weight': 0.4047437654505217, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'я', 'weight': 0, 'stop_word': True, 'POS': 'SPRO', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'не', 'weight': 0.47128352463063505, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}, 'negation': True}
#
# {'word': 'опаздывать', 'weight': 0.3575330549884247, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'отвечать', 'weight': 0.5850339942728455, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [1, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 1), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'джон', 'weight': 0.3794465230786324, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'идти', 'weight': 0.4646815335637525, 'top_20_word': True, 'POS': 'V', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'домой', 'weight': 0.5112308912043686, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'молодой', 'weight': 0.5112308912043686, 'top_20_word': True, 'POS': 'A', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'человек', 'weight': 0.5112308912043686, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'сегодня', 'weight': 0.7071067811865476, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'нет', 'weight': 0, 'stop_word': True, 'POS': 'ADV', 'lex_vector': {'raw': {'raw_diff_values': [2, 2, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 2), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'урок', 'weight': 0.7071067811865476, 'top_20_word': True, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [2, 1, 1, 0]}, 'named': OrderedDict([('sence_value', 2), ('freq_value', 1), ('eng_value', 1), ('abstract', 0)])}}
#
# ==================================================
# sentence
# [] [] []
# {'word': 'сегодня', 'weight': 0.5689440996114069, 'top_20_word': True, 'POS': 'undefined', 'lex_vector': {'raw': {'raw_diff_values': [0, 0, 1, 0]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 0), ('eng_value', 1), ('abstract', 0)])}}
#
# {'word': 'воскресение', 'weight': 0.822376198292099, 'POS': 'S', 'lex_vector': {'raw': {'raw_diff_values': [0, 2, 1, 1]}, 'named': OrderedDict([('sence_value', 0), ('freq_value', 2), ('eng_value', 1), ('abstract', 1)])}}
#
# ==================================================

# %%
text_grammar_map_ex[0]
# Out:
# [{'analysis': [{'gr': 'PR=', 'lex': 'в', 'wt': 0.9999917878}], 'text': 'в'},
#  {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'класс', 'wt': 1}],
#   'text': 'классе'},
#  {'analysis': [{'gr': 'V,нп=прош,ед,изъяв,муж,несов', 'lex': 'быть', 'wt': 1}],
#   'text': 'был'},
#  {'analysis': [{'gr': 'S,муж,неод=(вин,ед|им,ед)',
#     'lex': 'урок',
#     'wt': 0.9992735223}],
#   'text': 'урок'},
#  {'analysis': [{'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)',
#     'lex': 'русский',
#     'wt': 0.9496245492}],
#   'text': 'русского'},
#  {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'язык', 'wt': 0.9963354032}],
#   'text': 'языка'}]

# %%
len(sts_map[0]["words"])
# Out:
# 6

# %%
sts_map_spec_2[0]
# Out:
# {'coreference_items': [],
#  'negation_items': [],
#  'sent_special_pos': [],
#  'words': [{'POS': 'undefined',
#    'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                  ('freq_value', 0),
#                  ('eng_value', 1),
#                  ('abstract', 0)]),
#     'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#    'stop_word': True,
#    'weight': 0,
#    'word': 'в'},
#   {'POS': 'S',
#    'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                  ('freq_value', 0),
#                  ('eng_value', 1),
#                  ('abstract', 0)]),
#     'raw': {'raw_diff_values': [1, 0, 1, 0]}},
#    'weight': 0.5361619670142973,
#    'word': 'класс'},
#   {'POS': 'V',
#    'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                  ('freq_value', 0),
#                  ('eng_value', 1),
#                  ('abstract', 0)]),
#     'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#    'stop_word': True,
#    'weight': 0,
#    'word': 'быть'},
#   {'POS': 'S',
#    'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                  ('freq_value', 1),
#                  ('eng_value', 1),
#                  ('abstract', 0)]),
#     'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#    'top_20_word': True,
#    'weight': 0.37093265612787246,
#    'word': 'урок'},
#   {'POS': 'A',
#    'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                  ('freq_value', 1),
#                  ('eng_value', 1),
#                  ('abstract', 0)]),
#     'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#    'weight': 0.5361619670142973,
#    'word': 'русский'},
#   {'POS': 'S',
#    'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                  ('freq_value', 0),
#                  ('eng_value', 1),
#                  ('abstract', 0)]),
#     'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#    'weight': 0.5361619670142973,
#    'word': 'язык'}]}

# %% [markdown]
# # ФИЧИ ТЕКСТОВЫЕ - финальное состояние единицы текста

# %%
на уровен предложения

sent_special_pos СЛОВО_инф", "СЛОВО_прич", "СЛОВО_деепр СЛОВО_возвратный")
отдельно к глаголам
все вместе к глаголам

negation_items: само слово
    все вместе ко всем НЕ СТОП словам
coreference_items: само слово
    все вместе ко всем НЕ СТОП словам

# %%
def caclulate_overall_text_features(sentences_map, processed_text_sentences, lemm_text_sentences, raw_aligned_text):
    text_map = {}
    non_stop_word_count = 0
    verbs_count = 0
    inf, prich, deeprich, vozvr = 0,0,0,0
    all_spec_pos = 0
    negation_count, coreference_count = 0,0
    
    
    for sentence in sentences_map:
        for spec_pos in sentence['sent_special_pos']:
            if("_инф" in spec_pos):
                
                inf += 1
                all_spec_pos += 1
            elif("_прич" in spec_pos):
                
                prich += 1
                all_spec_pos += 1
            elif("_деепр" in spec_pos):
                
                deeprich += 1
                all_spec_pos += 1
            elif("_возвратный" in spec_pos):
                
                vozvr += 1
        negation_count += len(sentence['negation_items'])      
        coreference_count += len(sentence['coreference_items']) 
        for word in sentence['words']:
            if (word["POS"] == "V"):
                verbs_count += 1
            if("stop_word" not in word):
                non_stop_word_count += 1
                
        
    text_map = OrderedDict()
    text_map['lix'] = calculate_lix_from_list_of_sentences(processed_text_sentences)
    text_map['ttr'] = calculate_type_token_ratio(lemm_text_sentences)
    text_map['inf_verb'] = inf/verbs_count
    text_map['prich_verb'] = prich/verbs_count
    text_map['deeprich_verb'] = deeprich/verbs_count
    text_map['vozvr_verb'] = vozvr/verbs_count
    text_map['spec_pos_verb'] = all_spec_pos/ verbs_count
    
    text_map['negation_per_n_stop_words'] = negation_count/non_stop_word_count
    text_map ['coreference_per_n_stop_words'] = coreference_count/non_stop_word_count
    
    text_map['sentences&words_analysis'] = sentences_map
    
    text_map['raw_aligned_text'] = raw_aligned_text
    text_map['cleaned_sentences'] = processed_text_sentences
    text_map['lemm_sentences'] = lemm_text_sentences
    
    return  text_map
caclulate_overall_text_features(sts_map_spec_2, sentences_list,lemm_sentences, list_sentences_lines)
# Out:
# OrderedDict([('lix', 40.66),
#              ('ttr', 0.52),
#              ('inf_verb', 0.08108108108108109),
#              ('prich_verb', 0.0),
#              ('deeprich_verb', 0.0),
#              ('vozvr_verb', 0.05405405405405406),
#              ('spec_pos_verb', 0.08108108108108109),
#              ('negation_per_n_stop_words', 0.030927835051546393),
#              ('coreference_per_n_stop_words', 0.010309278350515464),
#              ('sentences&words_analysis',
#               [{'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'в'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [1, 0, 1, 0]}},
#                   'weight': 0.5361619670142973,
#                   'word': 'класс'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'быть'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.37093265612787246,
#                   'word': 'урок'},
#                  {'POS': 'A',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.5361619670142973,
#                   'word': 'русский'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.5361619670142973,
#                   'word': 'язык'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.5,
#                   'word': 'преподаватель'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.5,
#                   'word': 'читать'},
#                  {'POS': 'A',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.5,
#                   'word': 'новый'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.5,
#                   'word': 'текст'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.5773502691896257,
#                   'word': 'студент'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.5773502691896257,
#                   'word': 'внимательно'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.5773502691896257,
#                   'word': 'слушать'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': ['входить_инф'],
#                 'words': [{'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'weight': 0.7071067811865475,
#                   'word': 'извинять'},
#                  {'POS': 'ADV',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'можно'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'special_pos': ['инф'],
#                   'weight': 0.7071067811865475,
#                   'word': 'входить'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'я'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.45625299726699864,
#                   'word': 'опаздывать'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.7465701692916523,
#                   'word': 'сказать'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.48421708438335126,
#                   'word': 'джон'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': ['случаться_возвратный'],
#                 'words': [{'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [1, 2, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'что'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'special_pos': ['возвратный'],
#                   'top_20_word': True,
#                   'weight': 0.8069854513107882,
#                   'word': 'случаться'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5905713177701093,
#                   'word': 'джон'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.5336592850313727,
#                   'word': 'вчера'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'вы'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.7359805436065483,
#                   'word': 'опаздывать'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.41658181301205893,
#                   'word': 'сегодня'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'вы'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.7359805436065483,
#                   'word': 'опаздывать'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': ['опаздывать_инф'],
#                 'words': [{'POS': 'ADV',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'нельзя'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'special_pos': ['инф'],
#                   'top_20_word': True,
#                   'weight': 0.662044442799776,
#                   'word': 'опаздывать'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 2, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'на'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.7494645793884686,
#                   'word': 'урок'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [1, 0, 1, 0]}},
#                   'weight': 0.578160915178323,
#                   'word': 'вечер'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.37498872064186545,
#                   'word': 'джон'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5124028764319833,
#                   'word': 'приходить'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5124028764319833,
#                   'word': 'домой'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.416738274777688,
#                   'word': 'дома'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [1, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'он'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.416738274777688,
#                   'word': 'долго'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.416738274777688,
#                   'word': 'думать'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.36933989328823413,
#                   'word': 'вчера'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'я'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5093642761633557,
#                   'word': 'опаздывать'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.2883118249402291,
#                   'word': 'сегодня'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'я'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'тоже'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5093642761633557,
#                   'word': 'опаздывать'}]},
#                {'coreference_items': ['это'],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'SPRO',
#                   'coreference': True,
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.5773502691896257,
#                   'word': 'это'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.5773502691896257,
#                   'word': 'очень'},
#                  {'POS': 'A',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.5773502691896257,
#                   'word': 'плохой'}]},
#                {'coreference_items': [],
#                 'negation_items': ['не'],
#                 'sent_special_pos': ['опаздывать_инф'],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'negation': True,
#                   'top_20_word': True,
#                   'weight': 0.6575124635425807,
#                   'word': 'не'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'быть'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'больше'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'special_pos': ['инф'],
#                   'top_20_word': True,
#                   'weight': 0.49881319311467176,
#                   'word': 'опаздывать'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 2, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'на'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5646793414504481,
#                   'word': 'урок'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.2734604088822302,
#                   'word': 'завтра'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'я'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'вставать'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.30855431836237057,
#                   'word': 'рано'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'в'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.24856088384840483,
#                   'word': 'час'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.30855431836237057,
#                   'word': 'быстро'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'сделать'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'зарядка'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'приготавливать'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'завтрак'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'позавтракать'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'повторять'},
#                  {'POS': 'A',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'домашний'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 1)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 1]}},
#                   'weight': 0.2734604088822302,
#                   'word': 'задание'}]},
#                {'coreference_items': [],
#                 'negation_items': ['не'],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.6591401887187024,
#                   'word': 'завтра'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'я'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'negation': True,
#                   'top_20_word': True,
#                   'weight': 0.5991231731043144,
#                   'word': 'не'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.454516924949216,
#                   'word': 'опаздывать'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.5918230094768323,
#                   'word': 'утро'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.38384980261366636,
#                   'word': 'джон'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.5245110910014203,
#                   'word': 'вставать'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'в'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.47675252480058705,
#                   'word': 'час'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [1, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'он'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'сделать'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'зарядка'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'приготавливать'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'завтрак'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'позавтракать'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'повторять'},
#                  {'POS': 'A',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'домашний'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 1)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 1]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'задание'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [1, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'и'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.3520348668572578,
#                   'word': 'пойти'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'в'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.31199562897878214,
#                   'word': 'институт'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'в'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.42220060848498,
#                   'word': 'час'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.52410427154223,
#                   'word': 'минута'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.33992818454000945,
#                   'word': 'джон'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.4644944499676149,
#                   'word': 'приходить'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'в'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'weight': 0.4644944499676149,
#                   'word': 'институт'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': ['случаться_возвратный'],
#                 'words': [{'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [1, 2, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'что'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 1, 1, 0]}},
#                   'special_pos': ['возвратный'],
#                   'top_20_word': True,
#                   'weight': 0.5773502691896257,
#                   'word': 'случаться'},
#                  {'POS': 'A',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5773502691896257,
#                   'word': 'молодой'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5773502691896257,
#                   'word': 'человек'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'куда'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'вы'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 1.0,
#                   'word': 'идти'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'weight': 0.7071067811865475,
#                   'word': 'спрашивать'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'weight': 0.7071067811865475,
#                   'word': 'дежурный'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'я'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.7586307126040724,
#                   'word': 'идти'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 2, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'на'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.6515208683486948,
#                   'word': 'урок'}]},
#                {'coreference_items': [],
#                 'negation_items': ['не'],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.4047437654505217,
#                   'word': 'сегодня'},
#                  {'POS': 'SPRO',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'я'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'negation': True,
#                   'top_20_word': True,
#                   'weight': 0.47128352463063505,
#                   'word': 'не'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.3575330549884247,
#                   'word': 'опаздывать'},
#                  {'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 1),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [1, 0, 1, 0]}},
#                   'weight': 0.5850339942728455,
#                   'word': 'отвечать'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.3794465230786324,
#                   'word': 'джон'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'V',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.4646815335637525,
#                   'word': 'идти'},
#                  {'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5112308912043686,
#                   'word': 'домой'},
#                  {'POS': 'A',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5112308912043686,
#                   'word': 'молодой'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5112308912043686,
#                   'word': 'человек'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.7071067811865476,
#                   'word': 'сегодня'},
#                  {'POS': 'ADV',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 2, 1, 0]}},
#                   'stop_word': True,
#                   'weight': 0,
#                   'word': 'нет'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 2),
#                                 ('freq_value', 1),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [2, 1, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.7071067811865476,
#                   'word': 'урок'}]},
#                {'coreference_items': [],
#                 'negation_items': [],
#                 'sent_special_pos': [],
#                 'words': [{'POS': 'undefined',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 0),
#                                 ('eng_value', 1),
#                                 ('abstract', 0)]),
#                    'raw': {'raw_diff_values': [0, 0, 1, 0]}},
#                   'top_20_word': True,
#                   'weight': 0.5689440996114069,
#                   'word': 'сегодня'},
#                  {'POS': 'S',
#                   'lex_vector': {'named': OrderedDict([('sence_value', 0),
#                                 ('freq_value', 2),
#                                 ('eng_value', 1),
#                                 ('abstract', 1)]),
#                    'raw': {'raw_diff_values': [0, 2, 1, 1]}},
#                   'weight': 0.822376198292099,
#                   'word': 'воскресение'}]}]),
#              ('raw_aligned_text',
#               ['В классе был урок русского языка. Преподаватель читал новый текст.',
#                'Студенты внимательно слушали.',
#                '– Извините, можно войти? Я опоздал, – сказал Джон.',
#                ' – Что случилось, Джон? Вчера вы опоздали, сегодня вы опоздали. Нельзя опаздывать на урок.',
#                ' Вечером Джон пришел домой. Дома он долго думал: «Вчера я опоздал, сегодня я тоже опоздал. Это очень плохо. Не буду больше опаздывать на урок. Завтра я встану рано, в 8 часов, быстро сделаю зарядку, приготовлю завтрак, позавтракаю, повторю домашнее задание. Завтра я не опоздаю!»',
#                ' Утром Джон встал в 8 часов. Он сделал зарядку, приготовил завтрак, позавтракал, повторил домашнее задание и пошел в институт.',
#                'В 9 часов 30 минут Джон пришел в институт.',
#                '– Что случилось, молодой человек? Куда вы идете? – спросил дежурный.',
#                '– Я иду на урок. Сегодня я не опоздал, – ответил Джон.',
#                '– Идите домой, молодой человек! Сегодня нет урока. Сегодня воскресенье.']),
#              ('cleaned_sentences',
#               ['в классе был урок русского языка',
#                'преподаватель читал новый текст',
#                'студенты внимательно слушали',
#                'извините можно войти',
#                'я опоздал сказал джон',
#                'что случилось джон',
#                'вчера вы опоздали сегодня вы опоздали',
#                'нельзя опаздывать на урок',
#                'вечером джон пришел домой',
#                'дома он долго думал вчера я опоздал сегодня я тоже опоздал',
#                'это очень плохо',
#                'не буду больше опаздывать на урок',
#                'завтра я встану рано в 8 часов быстро сделаю зарядку приготовлю завтрак позавтракаю повторю домашнее задание',
#                'завтра я не опоздаю',
#                'утром джон встал в 8 часов',
#                'он сделал зарядку приготовил завтрак позавтракал повторил домашнее задание и пошел в институт',
#                'в 9 часов 30 минут джон пришел в институт',
#                'что случилось молодой человек',
#                'куда вы идете',
#                'спросил дежурный',
#                'я иду на урок',
#                'сегодня я не опоздал ответил джон',
#                'идите домой молодой человек',
#                'сегодня нет урока',
#                'сегодня воскресенье']),
#              ('lemm_sentences',
#               ['в класс быть урок русский язык',
#                'преподаватель читать новый текст',
#                'студент внимательно слушать',
#                'извинять можно входить',
#                'я опаздывать сказать джон',
#                'что случаться джон',
#                'вчера вы опаздывать сегодня вы опаздывать',
#                'нельзя опаздывать на урок',
#                'вечер джон приходить домой',
#                'дома он долго думать вчера я опаздывать сегодня я тоже опаздывать',
#                'это очень плохой',
#                'не быть больше опаздывать на урок',
#                'завтра я вставать рано в час быстро сделать зарядка приготавливать завтрак позавтракать повторять домашний задание',
#                'завтра я не опаздывать',
#                'утро джон вставать в час',
#                'он сделать зарядка приготавливать завтрак позавтракать повторять домашний задание и пойти в институт',
#                'в час минута джон приходить в институт',
#                'что случаться молодой человек',
#                'куда вы идти',
#                'спрашивать дежурный',
#                'я идти на урок',
#                'сегодня я не опаздывать отвечать джон',
#                'идти домой молодой человек',
#                'сегодня нет урок',
#                'сегодня воскресение'])])

# %%
def calc_common_features(text_map_input,processed_text_sentences, lemm_text_sentences ):
    lix = lemm_text_sentences()

# %%
ЗДЕСЬ ЖЕ РАССЧИТАТЬ ЛЕКСИЧЕСКИЙ ВЕКТОР ЕТКСТА (ОПУСКАТЬ СТОП СЛОВА)

# %%
def calculate_lix_from_list_of_sentences(processed_text_sentences):
        sentences_count = len(processed_text_sentences)
        words_count = sum([len(line.split(' ')) for line in processed_text_sentences])
        long_words_count = 0 #more than 6
        for line in processed_text_sentences:
            for word in line.split():
                if len(word) > 6:
                    long_words_count += 1
        lix = words_count/ sentences_count + (long_words_count * 100) / words_count
        
        return round(lix,2)
text_lix = calculate_lix_from_list_of_sentences(sentences_list)
text_lix
# Out:
# 40.66

# %%
def calculate_type_token_ratio(lemm_text_sentences):
      all_words = []
      for sentence in lemm_text_sentences:
          words = sentence.split()
          for word in words:
              all_words.append(word)

      unqie_words = set(all_words)
      types = len(unqie_words)
      tokens = len (all_words)

      return round(types/tokens,2)
text_ttr = calculate_type_token_ratio(lemm_sentences)
text_ttr
# Out:
# 0.52

# %% [markdown]
# # ИДЕЯ - ТЕСТРОВАТЬ ЛЕКСИКУ В ТЕКСТЕ. ПРОЙТИСЬ ПО ВСЕМ ТЕКСТАМ И НАРЫТЬ ТАКИЕ ТРИ ТЕКСТА КОТОРЫЕ КЛЮЧАТ В СЕБЯ ВСЕ НЕОБХОДИМЫЕ СЛОВА
#
# ЗДЕСЬ МОЖЕТ ПОНАДОБИТЬСЯ ТОП 20% слов
