# %%
import re

import pandas as pd

from pymystem3 import Mystem

# %% [markdown]
# -ость-/-есть- (свежесть, трусость),
#
# трусость
# трусости
# трусостью
#
# свежесть
# свежести
# свежестью

# %%
-ств(о)-/-еств(о)- (ничтожество, хвастовство),

ничтожество
ничтожества
ничтожеству
ничтожестве

хвастовство

# %%
match = re.search(r'\d\d\D\d\d', r'Телефон 123-12-12') 
print(match[0] if match else 'Not found')
# Out:
# 23-12

# %%
word = 'трусость'
def find_abstract_suff(word,pos):
    if (pos != 's'):
        return
    
    chek_list = [r'ость$',r'ости$',r'остью$',r'есть$',r'ести$',r'естью$',r'ество$',r'ества$',r'еству$',r'естве$']
    match = None
    for check_el in chek_list:
        match = re.search(check_el, word) 
        if(match):
            print("found", match[0], "in word", word)
            return
    #print("not found")
find_ost_est(word,'s')
# Out:
# found ость in word трусость

# %%
df = pd.read_csv("freq_dict.csv", sep='\t')

# %%
df.head()
# Out:
#    Rank Lemma   PoS  Freq(ipm)    R   D    Doc
# 0     1     и  conj    35801.8  100  99  37704
# 1     2     в    pr    31374.2  100  98  37865
# 2     3    не  part    18028.0  100  97  33999
# 3     4    на    pr    15867.3  100  98  36748
# 4     5     я  spro    12684.4  100  95  17116

# %%
lemm = df['Lemma'] 
pos = df['PoS'] 
for current_lemm, current_pos in zip(lemm, pos):
    find_ost_est(current_lemm,current_pos)
# Out:
# found ость in word возможность
# found ество in word качество
# found ество in word общество
# found ость in word деятельность
# found ество in word количество
# found ость in word гость
# found ость in word радость
# found ость in word безопасность
# found ость in word необходимость
# found ость in word личность
# found ость in word ответственность
# found ество in word множество
# found ость in word особенность
# found ость in word частность
# found ость in word скорость
# found ость in word поверхность
# found ость in word способность
# found ость in word стоимость
# found ество in word существо
# found ость in word зависимость
# found ость in word собственность
# found ество in word имущество
# found ость in word должность
# found есть in word честь
# found ость in word ценность
# found ость in word обязанность
# found ость in word промышленность
# found ество in word творчество
# found ость in word реальность
# found ество in word сотрудничество
# found ость in word потребность
# found ество in word вещество
# found ество in word человечество
# found ость in word опасность
# found ость in word новость
# found ость in word сущность
# found ость in word эффективность
# found есть in word совесть
# found ость in word кость
# found ость in word активность
# found ость in word мощность
# found ость in word действительность
# found ость in word готовность
# found ество in word преимущество
# found ость in word трудность
# found ость in word уверенность
# found ость in word подробность
# found ость in word молодость
# found ость in word сложность
# found ость in word справедливость
# found ество in word одиночество
# found есть in word повесть
# found ость in word глупость
# found ость in word точность
# found ость in word гордость
# found ество in word сообщество
# found ость in word юность
# found есть in word тяжесть
# found ость in word численность
# found ость in word благодарность
# found ость in word слабость
# found ость in word последовательность
# found ость in word жидкость
# found ость in word вероятность
# found ость in word неприятность
# found ость in word старость
# found ость in word крепость
# found ество in word торжество
# found ость in word специальность
# found ость in word независимость
# found ость in word усталость
# found ость in word местность
# found ость in word общественность
# found ость in word совокупность
# found ость in word принадлежность
# found ость in word близость
# found ество in word отечество
# found ость in word национальность
# found ость in word стабильность
# found ость in word популярность
# found ость in word внешность
# found ость in word мудрость
# found ость in word жалость
# found ость in word нежность
# found ость in word вечность
# found ость in word неожиданность
# found ость in word недвижимость
# found ость in word устойчивость
# found есть in word весть
# found ость in word легкость
# found ость in word ярость
# found ость in word милость
# found ость in word верность
# found ость in word задолженность
# found ость in word важность
# found ество in word электричество
# found ество in word мужество
# found ость in word производительность
# found ость in word закономерность
# found ость in word плотность
# found ость in word плоскость
# found ость in word надежность
# found ость in word видимость
# found есть in word прелесть
# found ость in word невозможность
# found ость in word редкость
# found ость in word бедность
# found ость in word договоренность
# found ость in word отчетность
# found ость in word случайность
# found ость in word значимость
# found ость in word злость
# found ость in word прочность
# found ость in word ясность
# found ость in word преступность
# found ость in word занятость
# found ество in word рождество
# found ество in word величество
# found ость in word продолжительность
# found ость in word жестокость
# found ость in word интенсивность
# found ость in word беременность
# found ость in word окрестность
# found ость in word известность
# found ость in word ревность
# found ость in word смелость
# found ость in word общность
# found ость in word давность
# found ость in word емкость
# found ость in word современность
# found ость in word растерянность
# found ость in word достоверность
# found ость in word полость
# found ость in word неопределенность
# found ость in word самостоятельность
# found ость in word тонкость
# found ость in word законность
# found ость in word дальность
# found ость in word гадость
# found ость in word целостность
# found ость in word склонность
# found ость in word преданность
# found ость in word бесконечность
# found ость in word направленность
# found есть in word месть
# found ость in word древность
# found ость in word себестоимость
# found ость in word нравственность
# found ость in word разновидность
# found ество in word отчество
# found ость in word напряженность
# found ость in word чувствительность
# found ество in word товарищество
# found ость in word хитрость
# found ость in word правильность
# found ость in word осторожность
# found ость in word индивидуальность
# found ость in word крайность
# found ость in word знаменитость
# found ость in word конкурентоспособность
# found ость in word отдельность
# found ость in word несправедливость
# found ость in word солидарность
# found ество in word содружество
# found ость in word искренность
# found ость in word решимость
# found ость in word заинтересованность
# found ость in word целесообразность
# found ость in word странность
# found ество in word божество
# found ость in word серьезность
# found ость in word надобность
# found ость in word жизнедеятельность
# found ость in word ведомость
# found ость in word сохранность
# found есть in word свежесть
# found ость in word вежливость
# found ость in word противоположность
# found ость in word жадность
# found ость in word растительность
# found ость in word открытость
# found ость in word неловкость
# found ость in word драгоценность
# found ость in word бдительность
# found ость in word самодеятельность
# found ость in word подлость
# found ость in word конечность
# found ость in word идентичность
# found ость in word гласность
# found ость in word честность
# found ость in word доходность
# found ость in word скромность
# found ость in word привлекательность
# found ость in word доверенность
# found ость in word государственность
# found ость in word привязанность
# found ость in word протяженность
# found ость in word условность
# found ость in word откровенность
# found ость in word длительность
# found ость in word актуальность
# found ость in word строгость
# found ость in word сладость
# found ость in word малость
# found ость in word зрелость
# found ость in word твердость
# found ость in word духовность
# found есть in word тесть
# found ость in word причастность
# found ость in word пошлость
# found ость in word сырость
# found ость in word прозрачность
# found ость in word грубость
# found ость in word смертность
# found ость in word рентабельность
# found ость in word работоспособность
# found ость in word озабоченность
# found ость in word несостоятельность
# found ость in word жесткость
# found ость in word влажность
# found ость in word стойкость
# found ество in word пророчество
# found ость in word неизбежность
# found ество in word невежество
# found ость in word объективность
# found ость in word святость
# found ость in word наглость
# found ость in word наивность
# found ость in word словесность
# found ость in word неспособность
# found ость in word гибкость
# found ость in word храбрость
# found ость in word неисправность
# found ество in word могущество
# found ество in word новшество
# found ость in word внутренность
# found ость in word достопримечательность
# found ость in word урожайность
# found ость in word трусость
# found ость in word продуктивность
# found ость in word порядочность
# found ость in word нелепость
# found ость in word неизвестность
# found ость in word настойчивость
# found ость in word мерзость
# found ость in word беспомощность
# found ость in word яркость
# found ость in word формальность
# found ость in word неуверенность
# found ость in word неприкосновенность
# found ость in word бодрость
# found ость in word премудрость
# found ость in word мягкость
# found ость in word доступность
# found ость in word преемственность
# found ость in word неточность
# found ость in word разность
# found ость in word подлинность
# found ество in word замужество
# found ость in word заболеваемость
# found ество in word соперничество
# found ость in word определенность
# found ость in word дерзость
# found ество in word изящество
# found ость in word вязкость
# found ость in word убежденность
# found ость in word секретность
# found ость in word сдержанность
# found ость in word рождаемость
# found ость in word относительность
# found ость in word недостаточность
# found есть in word живучесть
# found ость in word влюбленность
# found ость in word приверженность
# found ость in word подвижность
# found ость in word ограниченность
# found ество in word ничтожество
# found ость in word лояльность
# found ость in word щедрость
# found ость in word трость
# found ость in word терпимость
# found ость in word покорность
# found ость in word народность
# found ость in word изменчивость
# found ество in word художество
# found есть in word доблесть
# found ость in word античность
# found ость in word погрешность
# found ость in word задумчивость
# found ество in word естество
# found ость in word валентность
# found ость in word убедительность
# found ость in word признательность
# found ество in word мошенничество
# found ость in word ловкость
# found ость in word робость
# found ость in word полезность
# found ость in word нестабильность
# found ость in word взаимность
# found ость in word нерешительность
# found ость in word госбезопасность
# found ость in word человечность
# found ость in word уникальность
# found ость in word тональность
# found ость in word резкость
# found ость in word неполноценность
# found ость in word неподвижность
# found ость in word любезность
# found ость in word истинность
# found ость in word наследственность
# found ость in word вольность
# found ость in word четкость
# found ость in word предосторожность
# found ость in word очевидность
# found ость in word окружность
# found ость in word неосторожность
# found ость in word инвалидность
# found ость in word брезгливость
# found ость in word агрессивность
# found ость in word решительность
# found ость in word оригинальность
# found ость in word нетерпимость
# found ество in word лесничество
# found ество in word казачество
# found ость in word деликатность
# found ость in word цельность
# found ость in word управляемость
# found ость in word подозрительность
# found ость in word естественность
# found ость in word тревожность
# found ести in word почести
# found ость in word одаренность
# found ость in word непосредственность
# found ость in word грузоподъемность
# found ость in word гениальность
# found ость in word благотворительность
# found ость in word безнадежность
# found ость in word размерность
# found ость in word письменность
# found ость in word обеспеченность
# found ость in word наклонность
# found ество in word монашество
# found ость in word безысходность
# found ость in word банальность
# found ость in word пакость
# found ость in word невиновность
# found ость in word тупость
# found ость in word трезвость
# found ость in word подсудность
# found ость in word повседневность
# found ость in word неоднородность
# found ость in word невинность
# found ество in word княжество
# found ество in word имя-отчество
# found ость in word данность
# found ость in word годность
# found ость in word упругость
# found ость in word самоуверенность
# found ость in word самобытность
# found ость in word проницаемость
# found ость in word невесомость
# found ость in word интеллигентность
# found ество in word излишество
# found ость in word защищенность
# found ость in word выносливость
# found ость in word чуткость
# found ость in word туманность
# found ость in word специфичность
# found ость in word сосредоточенность
# found ость in word периодичность
# found ество in word отрочество
# found ость in word оплошность
# found ость in word обоснованность
# found ость in word неустойчивость
# found ость in word мобильность
# found ость in word значительность
# found ость in word выразительность
# found ость in word враждебность
# found ость in word шалость
# found ость in word толерантность
# found ость in word оперативность
# found ость in word изобретательность
# found ость in word дикость
# found ество in word младенчество
# found есть in word известь
# found есть in word жесть
# found ость in word грамотность
# found ество in word высочество
# found ость in word бездарность
# found ость in word трудоемкость
# found ество in word празднество
# found ость in word правдивость
# found ость in word обреченность
# found ость in word образованность
# found ость in word неясность
# found ость in word настороженность
# found ость in word наглядность
# found ость in word ликвидность
# found есть in word лесть
# found ость in word компетентность
# found ость in word живность
# found ость in word бессмысленность
# found ость in word беспечность
# found ость in word торжественность
# found ество in word святейшество
# found ость in word рациональность
# found ество in word паломничество
# found ость in word неудовлетворенность
# found ость in word недопустимость
# found ость in word небрежность
# found ость in word множественность
# found ость in word исключительность
# found ость in word женственность
# found ость in word доброжелательность
# found ость in word совместимость
# found ость in word сексуальность
# found ость in word очередность
# found ость in word осведомленность
# found ость in word обязательность
# found ость in word непрерывность
# found ость in word недействительность
# found ость in word жизнеспособность
# found ость in word живость
# found ость in word доверчивость
# found есть in word горесть
# found ость in word бытность
# found ость in word безответственность
# found ость in word эластичность
# found ество in word чиновничество
# found ость in word универсальность
# found ость in word тщательность
# found ость in word неровность
# found ость in word наружность
# found ость in word внезапность
# found ость in word успешность
# found ость in word сухость
# found ость in word поспешность
# found ость in word пассивность
# found ость in word несовместимость
# found ость in word краткость
# found ость in word замкнутость
# found ость in word двойственность
# found ость in word адекватность
# found ость in word требовательность
# found ость in word судимость
# found ость in word религиозность
# found ость in word результативность
# found ость in word рассеянность
# found ость in word проводимость
# found ость in word принципиальность
# found ество in word пиршество
# found ость in word обыденность
# found ость in word наблюдательность
# found ость in word двусмысленность
# found ество in word язычество
# found ость in word элегантность
# found ость in word суровость
# found ость in word стройность
# found ость in word повинность
# found ость in word отсталость
# found ость in word однородность
# found ость in word неузнаваемость
# found ость in word ментальность
# found ость in word горячность
# found ость in word бестактность
# found ость in word безнаказанность
# found ость in word эмоциональность
# found ость in word халатность
# found ество in word тождество
# found ость in word таинственность
# found ость in word снисходительность
# found ость in word пряность
# found ость in word противоречивость
# found ость in word проницательность
# found ество in word посредничество
# found ество in word подмножество
# found ость in word корректность
# found ость in word исправность
# found ость in word долговечность
# found ость in word девственность
# found ость in word возвышенность
# found ость in word виновность
# found ость in word близорукость
# found ость in word бледность
# found ость in word аккуратность
# found ость in word целость
# found ость in word сытость
# found ость in word сообразительность
# found ость in word серость
# found ость in word регулярность
# found ость in word платежеспособность
# found ость in word нервозность
# found ость in word непредсказуемость
# found ость in word медлительность
# found ость in word легитимность
# found ость in word конфиденциальность
# found ость in word конкретность
# found ество in word зодчество
# found ость in word добросовестность
# found ость in word громкость
# found ость in word вместимость
# found ость in word веселость
# found ость in word холодность
# found ество in word убожество
# found ость in word согласованность
# found ость in word правомерность
# found ость in word посредственность
# found ость in word перспективность
# found ость in word окупаемость
# found ость in word обороноспособность
# found ость in word необычность
# found ость in word находчивость
# found ость in word насыщенность
# found ость in word наличность
# found ость in word вялость
# found ество in word взяточничество
# found ость in word боеготовность
# found ость in word функциональность
# found ость in word успеваемость
# found ость in word тягость
# found ость in word солидность
# found ость in word сентиментальность
# found ость in word подведомственность
# found ость in word ненадобность
# found ость in word некомпетентность
# found ость in word неизменность
# found ость in word деловитость
# found ость in word дееспособность
# found ость in word боеспособность
# found ость in word чувственность
# found ость in word уязвимость
# found ость in word упорядоченность
# found ость in word узость
# found ество in word студенчество
# found ость in word стремительность
# found ость in word состязательность
# found ость in word проходимость
# found ость in word отчужденность
# found ость in word одержимость
# found ость in word необратимость
# found ость in word любознательность
# found ость in word кротость
# found ество in word католичество
# found ость in word изысканность
# found ость in word застенчивость
# found ость in word забывчивость
# found ость in word гуманность
# found ость in word беззащитность
# found ость in word хрупкость
# found ество in word ханжество
# found есть in word текучесть
# found ость in word сплоченность
# found ость in word сознательность
# found ость in word распространенность
# found ость in word пластичность
# found ость in word организованность
# found ость in word неэффективность
# found ость in word неопытность
# found ость in word маневренность
# found ость in word конституционность
# found ость in word кислотность
# found ость in word дурость
# found ость in word достаточность
# found ость in word выпуклость
# found ость in word вседозволенность
# found ость in word вредность
# found ость in word восприимчивость
# found ость in word благосклонность
# found ество in word юношество
# found ость in word целеустремленность
# found ость in word трудоспособность
# found ость in word токсичность
# found ость in word субъективность
# found ость in word соборность
# found ость in word скрытность
# found ость in word разумность
# found ость in word публичность
# found ость in word прозорливость
# found ость in word пригодность
# found ость in word прибыльность
# found ость in word предрасположенность
# found ость in word политкорректность
# found ость in word оснащенность
# found ость in word облачность
# found ость in word низость
# found ость in word неповторимость
# found ость in word действенность
# found ость in word греховность
# found ость in word выраженность
# found ество in word владычество
# found ость in word безграмотность
# found ость in word ученость
# found ость in word удаленность
# found ость in word увлеченность
# found есть in word схожесть
# found ество in word старчество
# found ость in word сонливость
# found ость in word самоотверженность
# found ость in word превратность
# found ость in word отрешенность
# found ость in word освещенность
# found ость in word обеспокоенность
# found ость in word негодность
# found ество in word всемогущество
# found ость in word волость
# found ость in word взаимозависимость
# found ость in word экономичность
# found ость in word шероховатость
# found ость in word устремленность
# found ость in word трещиноватость
# found ость in word скованность
# found ость in word своевременность
# found ость in word распущенность
# found ость in word раскованность
# found ость in word приятность
# found ость in word предметность
# found ость in word праведность
# found ость in word подчиненность
# found ость in word подготовленность
# found ость in word партийность
# found ость in word отзывчивость
# found ость in word оседлость
# found ость in word неравномерность
# found ость in word неотвратимость
# found ость in word незыблемость
# found ость in word намагниченность
# found ость in word музыкальность
# found ость in word закрытость
# found ество in word бизнес-сообщество
# found ество in word чудачество
# found ость in word ущербность
# found ость in word театральность
# found ость in word скудость
# found ость in word раздражительность
# found ость in word промежность
# found ость in word провинность
# found ость in word предвзятость
# found ость in word практичность
# found ость in word посещаемость
# found ость in word плавность
# found ость in word отчетливость
# found ость in word образность
# found ость in word нереальность
# found ость in word непримиримость
# found ость in word ненужность
# found ость in word невозмутимость
# found ость in word неблагодарность
# found ость in word косность
# found ость in word жертвенность
# found ость in word выживаемость
# found ость in word безнравственность
# found ость in word анонимность
# found ость in word алчность
# found ость in word абсурдность
# found ость in word удовлетворенность
# found ость in word страстность
# found ость in word собранность
# found ость in word скупость
# found ость in word разобщенность
# found ость in word пышность
# found ость in word приветливость
# found ость in word предприимчивость
# found ость in word пористость
# found ость in word основательность
# found ость in word округлость
# found ость in word неустроенность
# found ость in word непоследовательность
# found ость in word мужественность
# found ость in word масштабность
# found ость in word массовость
# found ость in word комфортность
# found ость in word информированность
# found ость in word завершенность
# found ость in word душевность
# found ость in word досягаемость
# found ость in word дисциплинированность
# found ость in word декоративность
# found ость in word востребованность
# found ость in word вирулентность
# found ость in word беспощадность
# found ость in word фамильярность
# found ость in word умеренность
# found ость in word телесность
# found ество in word супружество
# found ость in word самодостаточность
# found ость in word радиоактивность
# found ость in word причинность
# found ость in word применимость
# found ость in word предсказуемость
# found ость in word праздность
# found ость in word оконечность
# found ость in word непринужденность
# found ость in word немилость
# found ость in word неграмотность
# found ость in word неверность
# found ость in word неадекватность
# found ость in word лихость
# found ость in word крупность
# found ость in word коррумпированность
# found ость in word информативность
# found ость in word интенциональность
# found ость in word иммуногенность
# found ость in word избыточность
# found ество in word заступничество
# found ество in word законотворчество
# found ость in word загруженность
# found ость in word загадочность
# found ость in word заботливость
# found ость in word жимолость
# found ость in word допустимость
# found ество in word девичество
# found ость in word гражданственность
# found ость in word госсобственность
# found ость in word гнусность
# found ость in word вовлеченность
# found ость in word вариабельность
# found ость in word аварийность
# found ость in word эквивалентность
# found ость in word торопливость
# found ость in word состоятельность
# found ость in word сопротивляемость
# found ость in word селективность
# found ость in word светлость
# found ость in word сбалансированность
# found ость in word резистентность
# found ость in word растворимость
# found ость in word расслабленность
# found ость in word притягательность
# found ость in word приобщенность
# found ость in word престижность
# found ость in word предусмотрительность
# found ость in word правоспособность
# found ость in word подавленность
# found ость in word парадоксальность
# found ость in word оптимальность
# found ость in word ничтожность
# found ость in word неправильность
# found ость in word незащищенность
# found ость in word надменность
# found ость in word категоричность
# found ость in word законченность
# found ость in word единственность
# found ость in word диспозитивность
# found ость in word внимательность
# found ость in word бесполезность
# found ость in word безмятежность
# found ость in word безвестность
# found ость in word энергоемкость
# found ость in word черствость
# found ость in word художественность
# found ество in word ткачество
# found ость in word стыдливость
# found ость in word слышимость
# found ость in word реактивность
# found ость in word пунктуальность
# found ость in word прямолинейность
# found ество in word подвижничество
# found ость in word повторяемость
# found ость in word оторванность
# found ость in word осмотрительность
# found ость in word огромность
# found ость in word общительность
# found ость in word непристойность
# found ость in word непреклонность
# found ость in word неоднозначность
# found ость in word недоступность
# found ость in word неготовность
# found ость in word научность
# found ость in word монотонность
# found ость in word мнительность
# found ость in word леность
# found ость in word интимность
# found ость in word инертность
# found ость in word изощренность
# found ость in word избранность
# found ость in word зоркость
# found ость in word доверительность
# found ость in word герметичность
# found ость in word встречаемость
# found ость in word виртуозность
# found ость in word будущность
# found ость in word болезненность
# found ость in word благость
# found ость in word автономность
# found ость in word учтивость
# found ество in word ученичество
# found ость in word убогость
# found ость in word соразмерность
# found ость in word сопричастность
# found ость in word сопоставимость
# found ость in word собираемость
# found ость in word сердечность
# found ость in word самость
# found ость in word самонадеянность
# found ость in word русскость
# found ость in word резвость
# found ость in word раскрываемость
# found ость in word раздвоенность
# found ость in word развязность
# found ость in word продажность
# found ость in word приоритетность
# found ость in word почтительность
# found есть in word похожесть
# found ость in word пикантность
# found ость in word первичность
# found ость in word отстраненность
# found ость in word отдаленность
# found ость in word опытность
# found ость in word нормальность
# found ость in word нетрудоспособность
# found ость in word несуразность
# found ость in word несогласованность
# found ость in word неразвитость
# found ость in word неподготовленность
# found ость in word необязательность
# found ость in word незаконность
# found ость in word незавершенность
# found ость in word наполненность
# found ество in word мученичество
# found ость in word мрачность
# found ость in word меткость
# found ость in word красивость
# found ость in word контрастность
# found ость in word компактность
# found ость in word избирательность
# found ество in word землячество
# found ество in word жульничество
# found ость in word жирность
# found ость in word жизнерадостность
# found ость in word жизненность
# found ость in word дотошность
# found ость in word взрослость
# found ость in word беспристрастность
# found ость in word беспринципность
# found ость in word бесперспективность
# found ость in word беззаботность
# found ость in word бездеятельность
# found ость in word экстравагантность
# found ость in word цикличность
# found ость in word целенаправленность
# found ость in word теплопроводность
# found ость in word срочность
# found ость in word спелость
# found ость in word социальность
# found ость in word слаженность
# found ость in word системность
# found ость in word сезонность
# found ость in word связность
# found есть in word сверхтекучесть
# found ость in word сверхпроводимость
# found ость in word респектабельность
# found ость in word рассудительность
# found ество in word пособничество
# found ость in word порочность
# found ость in word полярность
# found ость in word ошибочность
# found ость in word осмысленность
# found ость in word оппозиционность
# found ость in word озлобленность
# found ость in word однозначность
# found ость in word обусловленность
# found ость in word никчемность
# found ость in word неуязвимость
# found ость in word непротиворечивость
# found ость in word непонятность
# found ость in word непогрешимость
# found ость in word неискренность
# found ость in word модальность
# found ость in word ложность
# found ость in word ласковость
# found ество in word купечество
# found ость in word креативность
# found ость in word комплексность
# found ость in word колкость
# found ость in word исполнительность
# found ость in word искусственность
# found ость in word изворотливость
# found ость in word динамичность
# found ость in word детскость
# found ество in word госимущество
# found ость in word ветхость
# found ость in word бренность
# found ость in word бесцеремонность
# found ость in word беспризорность
# found ость in word безупречность
# found ость in word бездуховность
# found ость in word безвыходность
# found ость in word щепетильность
# found ость in word чрезвычайность
# found ость in word утонченность
# found ость in word утомляемость
# found ость in word узнаваемость
# found ость in word трагичность
# found ость in word талантливость
# found ость in word суетливость
# found ость in word старательность
# found ость in word свирепость
# found ость in word светимость
# found ость in word самоценность
# found ость in word приподнятость
# found ость in word примитивность
# found ость in word полноценность
# found ество in word патриаршество
# found ость in word оргпреступность
# found ость in word опустошенность
# found ость in word одухотворенность
# found ость in word обстоятельность
# found ость in word обособленность
# found ость in word оборачиваемость
# found ость in word нужность
# found ость in word нецелесообразность
# found ость in word нефтегазоносность
# found ость in word неторопливость
# found ость in word нескромность
# found ость in word нервность
# found ость in word непричастность
# found есть in word непохожесть
# found ость in word непереносимость
# found ость in word неосведомленность
# found ость in word незрелость
# found ость in word недоговоренность
# found ость in word невнимательность
# found ость in word невменяемость
# found ость in word невероятность
# found ость in word нацеленность
# found ость in word напористость
# found ость in word мстительность
# found ость in word многопартийность
# found ость in word лживость
# found ость in word летальность
# found ость in word кредитоспособность
# found ость in word кратность
# found ость in word копченость
# found ость in word калорийность
# found ость in word историчность
# found ость in word инфекционность
# found ость in word инициативность
# found ость in word импульсивность
# found ость in word запальчивость
# found ость in word заброшенность
# found ость in word живописность
# found ость in word добровольность
# found ость in word дискретность
# found ость in word грандиозность
# found ость in word гетерогенность
# found ость in word гадливость
# found ость in word вульгарность
# found ость in word всеобщность
# found ость in word воспитанность
# found ости in word вкусности
# found ость in word весомость
# found ость in word благонадежность
# found ость in word бесшабашность
# found ость in word бесхозяйственность
# found ость in word бездомность
# found ость in word безалаберность
# found ость in word амбивалентность
# found ость in word этничность
# found ость in word этажность
# found ость in word элитарность
# found ость in word чистоплотность
# found ость in word церковность
# found ость in word характерность
# found ость in word фантастичность
# found ость in word уравновешенность
# found ость in word униженность
# found ость in word удачливость
# found ость in word тождественность
# found ость in word товарность
# found ость in word тактичность
# found ость in word суетность
# found ость in word стеснительность
# found ость in word стерильность
# found ость in word сочность
# found ость in word сочетаемость
# found ость in word соотнесенность
# found ость in word содержательность
# found ость in word скученность
# found ость in word самоокупаемость
# found ость in word революционность
# found ость in word расчетливость
# found ость in word расхлябанность
# found ость in word развитость
# found ость in word произвольность
# found ость in word продуманность
# found ость in word провинциальность
# found ость in word припухлость
# found ость in word предопределенность
# found ость in word поэтичность
# found ость in word постепенность
# found ость in word понятность
# found ость in word переменность
# found ость in word патогенность
# found ество in word отступничество
# found ость in word опрятность
# found ость in word окаменелость
# found ость in word одинаковость
# found ество in word огородничество
# found ость in word обратимость
# found ость in word низменность
# found ость in word неуместность
# found ость in word несообразность
# found ость in word неряшливость
# found ость in word нерасторопность
# found ость in word неприкаянность
# found ость in word непригодность
# found ость in word непостижимость
# found ость in word неординарность
# found ость in word ненадежность
# found ость in word недосказанность
# found ость in word недобросовестность
# found ость in word начитанность
# found ость in word многозначительность
# found ество in word миротворчество
# found ость in word мелочность
# found ость in word материальность
# found ество in word мальчишество
# found ость in word лаконичность
# found ость in word критичность
# found ество in word крепостничество
# found ость in word конфликтность
# found ость in word коммуникабельность
# found ость in word изученность
# found ость in word изношенность
# found ество in word избранничество
# found ество in word иждивенчество
# found ость in word идейность
# found ость in word зрелищность
# found ость in word злобность
# found ость in word дополнительность
# found ость in word демократичность
# found ость in word гладкость
# found ость in word возбудимость
# found ость in word властность
# found ость in word веротерпимость
# found ество in word бродяжничество
# found ость in word болтливость
# found ость in word божественность
# found ость in word бесчеловечность
# found ость in word бесплодность
# found ость in word бескомпромиссность
# found ость in word бережливость
# found ость in word безвредность
# found ество in word антивещество
# found ость in word ангажированность
# found ость in word аморальность
# found ость in word язвительность
# found ость in word электропроводность
# found ость in word чуждость
# found ость in word цивилизованность
# found ость in word цепкость
# found ость in word уступчивость
# found ость in word усидчивость
# found ость in word угодливость
# found ость in word убыточность
# found ость in word тщетность
# found ость in word технологичность
# found ость in word теплоемкость
# found ость in word сходимость
# found ость in word субъектность
# found ость in word строптивость
# found ость in word спонтанность
# found ость in word слитность
# found ость in word скрупулезность
# found ость in word скорострельность
# found ость in word сжимаемость
# found ость in word семейственность
# found ость in word связанность
# found ость in word светскость
# found ость in word родственность
# found ость in word ритмичность
# found ость in word реалистичность
# found ость in word расторопность
# found ость in word разнородность
# found ость in word размытость
# found ость in word раздробленность
# found ость in word равноудаленность
# found ость in word равномерность
# found ость in word пылкость
# found ость in word пропорциональность
# found ество in word приспособленчество
# found ость in word приспособленность
# found ость in word праздничность
# found ость in word потертость
# found ость in word помпезность
# found ость in word пожароустойчивость
# found ость in word поворачиваемость
# found ость in word поверхностность
# found ость in word плодовитость
# found есть in word плавучесть
# found ость in word перегруженность
# found ость in word первозданность
# found ество in word отшельничество
# found ость in word отчаянность
# found ость in word ость
# found ость in word осознанность
# found ость in word органичность
# found ость in word односторонность
# found ость in word объемность
# found ость in word обрядность
# found ость in word обездоленность
# found ость in word нечестность
# found есть in word неуклюжесть
# found ость in word несдержанность
# found ость in word нерешенность
# found ость in word неразборчивость
# found ость in word неотразимость
# found ость in word необоснованность
# found ость in word нелояльность
# found ость in word незначительность
# found ость in word незаинтересованность
# found ость in word неестественность
# found ость in word недоказанность
# found ость in word недоверчивость
# found ость in word недееспособность
# found ость in word невидимость
# found ость in word натуральность
# found ость in word настырность
# found ость in word настроенность
# found ость in word насмешливость
# found ость in word назойливость
# found ество in word наемничество
# found ость in word мягкотелость
# found ость in word морозостойкость
# found ость in word монументальность
# found ость in word многочисленность
# found ость in word многозначность
# found ость in word многогранность
# found ость in word мечтательность
# found ость in word малочисленность
# found ость in word логичность
# found ость in word лесистость
# found ость in word красочность
# found ость in word комплектность
# found ость in word иррациональность
# found ость in word инфантильность
# found ость in word износостойкость
# found ость in word зыбкость
# found ость in word зимостойкость
# found ость in word звучность
# found ость in word зараженность
# found ость in word запущенность
# found ество in word западничество
# found ость in word заносчивость
# found ость in word заметность
# found ость in word замедленность
# found ость in word заданность
# found ость in word загрязненность
# found ость in word загазованность
# found ость in word жизнестойкость
# found ость in word добротность
# found ость in word дисперсность
# found ость in word гармоничность
# found ость in word галантность
# found ость in word выборность
# found ость in word вшивость
# found ость in word вторичность
# found ость in word впечатлительность
# found ость in word восторженность
# found ость in word включенность
# found ость in word вариативность
# found ость in word богооставленность
# found ость in word благожелательность
# found ость in word бестолковость
# found ость in word беспредельность
# found ость in word безусловность
# found ость in word безжалостность
# found ость in word артистичность
# found ость in word амбициозность
# found ость in word эксцентричность
# found ость in word экологичность
# found ость in word шаткость
# found ость in word цветность
# found ость in word хаотичность
# found ость in word укорененность
# found ость in word укомплектованность
# found ость in word угрюмость
# found ость in word трансцендентность
# found ость in word транспарентность
# found ость in word тенденциозность
# found ость in word теленовость
# found ость in word существенность
# found ество in word стукачество
# found ость in word статичность
# found ество in word сотворчество
# found ость in word соленость
# found ость in word созерцательность
# found ость in word совестливость
# found ость in word скудность
# found ость in word синхронность
# found ество in word сестричество
# found ество in word ребячество
# found ость in word реактогенность
# found ость in word расточительность
# found ость in word расплывчатость
# found ость in word ранимость
# found ость in word разнузданность
# found ость in word разговорчивость
# found ость in word разборчивость
# found ость in word пустынность
# found ость in word приспособляемость
# found ость in word приблизительность
# found ость in word предупредительность
# found ость in word представленность
# found ость in word предпочтительность
# found ость in word потливость
# found ость in word помехозащищенность
# found ость in word податливость
# found ость in word погруженность
# found ость in word платность
# found ость in word педантичность
# found ость in word пассионарность
# found ость in word пагубность
# found ость in word особость
# found ость in word ориентированность
# found ость in word окончательность
# found ость in word одновременность
# found ость in word огнестойкость
# found ость in word обученность
# found ость in word обидчивость
# found ость in word нечистоплотность
# found ость in word нечеткость
# found ость in word неуступчивость
# found ость in word неуравновешенность
# found ость in word неумелость
# found ость in word неразрешимость
# found ость in word непрозрачность
# found ость in word неприступность
# found ость in word неприемлемость
# found ость in word непотопляемость
# found ость in word неповоротливость
# found ость in word непобедимость
# found ость in word необъективность
# found ость in word необразованность
# found ость in word ненормальность
# found ость in word нелинейность
# found ость in word нейтральность
# found ость in word незаменимость
# found ость in word недостоверность
# found ость in word недоброжелательность
# found ость in word недальновидность
# found ость in word невостребованность
# found ость in word невоспитанность
# found ость in word мутность
# found ость in word молчаливость
# found ость in word многомерность
# found ость in word мнимость
# found ество in word мифотворчество
# found ость in word маскулинность
# found ость in word линейность
# found ество in word кулачество
# found ость in word крутость
# found ость in word кровожадность
# found ость in word консервативность
# found ость in word испорченность
# found ость in word интеллектуальность
# found ость in word инерционность
# found ость in word иллюзорность
# found ость in word изолированность
# found ость in word игривость
# found ость in word зональность
# found ость in word знатность
# found ость in word защитность
# found ество in word затворничество
# found ость in word запутанность
# found ость in word законопослушность
# found ость in word желательность
# found ость in word дряхлость
# found ость in word догадливость
# found ость in word детерминированность
# found ость in word детальность
# found ость in word державность
# found ость in word делимость
# found ость in word дальновидность
# found ость in word грациозность
# found ость in word выгодность
# found есть in word всхожесть
# found ость in word вспыльчивость
# found ость in word всеядность
# found ость in word временность
# found ость in word воспроизводимость
# found ость in word воинственность
# found ость in word вменяемость
# found ость in word взволнованность
# found ость in word взаимозаменяемость
# found ость in word буржуазность
# found ество in word богочеловечество
# found ость in word бесформенность
# found ость in word безнадзорность
# found ость in word безликость
# found ость in word беглость
# found ость in word аполитичность
# found ость in word адаптивность
# found ость in word авторитетность
# found ость in word авиапромышленность
# found ость in word ядовитость
# found ость in word эффектность
# found ость in word эфемерность
# found ость in word энергичность
# found ость in word эксклюзивность
# found ость in word чрезмерность
# found ость in word фригидность
# found ость in word услужливость
# found ость in word унылость
# found ость in word умиротворенность
# found ество in word угодничество
# found ость in word уважительность
# found ость in word турбулентность
# found ость in word транспортабельность
# found ость in word традиционность
# found ость in word тотальность
# found ость in word тварность
# found ость in word суверенность
# found ость in word структурированность
# found ость in word стихийность
# found ество in word старообрядчество
# found ость in word спортивность
# found ость in word сомнительность
# found ость in word скоротечность
# found ость in word скандальность
# found ость in word систематичность
# found ость in word сингулярность
# found ость in word симметричность
# found ость in word сенсационность
# found ество in word роскошество
# found ость in word ровность
# found ость in word рискованность
# found ость in word репрезентативность
# found ость in word релевантность
# found ость in word рассудочность
# found ость in word расположенность
# found ость in word раскрепощенность
# found ость in word разделенность
# found ость in word разбросанность
# found ость in word пытливость
# found ость in word профнепригодность
# found ость in word пронзительность
# found ость in word пристрастность
# found ость in word пристальность
# found ость in word приживаемость
# found ость in word приемлемость
# found ость in word приближенность
# found ость in word представительность
# found ость in word правосубъектность
# found ость in word правомочность
# found ество in word попрошайничество
# found ость in word покладистость
# found ость in word плодотворность
# found ость in word переносимость
# found ость in word парность
# found ость in word официальность
# found ость in word отточенность
# found ость in word отечность
# found ость in word отверженность
# found ость in word ожесточенность
# found ость in word обширность
# found ость in word обобщенность
# found ость in word обнаженность
# found ость in word обводненность
# found ество in word нормотворчество
# found ость in word неутомимость
# found ость in word неуспеваемость
# found ость in word неуправляемость
# found ость in word неумолимость
# found ость in word нестандартность
# found ость in word несомненность
# found ость in word неслучайность
# found ость in word нерушимость
# found ость in word неразрывность
# found ость in word нерадивость
# found ость in word непроницаемость
# found ость in word неприхотливость
# found ость in word неприглядность
# found ость in word непреложность
# found ость in word непонятливость
# found ость in word неподкупность
# found ость in word неосмотрительность
# found ость in word необъятность
# found ость in word нелогичность
# found ость in word некорректность
# found ость in word нейровирулентность
# found ость in word незаурядность
# found ость in word недосягаемость
# found ость in word недолговечность
# found ость in word невнятность
# found ость in word нарочитость
# found ость in word наполняемость
# found ость in word навязчивость
# found ость in word набожность
# found ость in word монолитность
# found ость in word многовариантность
# found ость in word мимолетность
# found ость in word метафоричность
# found ость in word массивность
# found ость in word манерность
# found ость in word ломкость
# found ость in word литературность
# found ость in word легальность
# found ость in word кучность
# found ость in word корпоративность
# found ость in word конвертируемость
# found ость in word камерность
# found ость in word исчерпанность
# found ость in word инвариантность
# found ость in word идеальность
# found ость in word заурядность
# found ость in word затхлость
# found ость in word заразительность
# found ость in word занимательность
# found ость in word зажатость
# found ость in word задушевность
# found ость in word жалкость
# found ость in word документальность
# found ость in word добропорядочность
# found ость in word дальнозоркость
# found ость in word громоздкость
# found ость in word гомосексуальность
# found ость in word гомогенность
# found ость in word вогнутость
# found ость in word внятность
# found ость in word внушаемость
# found ость in word влиятельность
# found ость in word виртуальность
# found ость in word виноватость
# found ость in word взвешенность
# found ость in word благоприятность
# found ость in word благоглупость
# found ость in word бессовестность
# found ость in word бесконтрольность
# found ость in word безотказность
# found ость in word безмерность
# found ость in word безграничность
# found ость in word безапелляционность
# found ость in word антигенность
# found ость in word авторитарность
# found ость in word абсолютность

# %% [raw]
# только ед. Тоже, что ничтожность в 1 знач.; убогое состояние. «Есть люди, которые, при всем своем ничтожестве, много о себе думают.» А.Островский. «Вы вывели вашего мужа из ничтожества, приобрели себе обеспечение на старость лет.» Чернышевский.

# %%
line = "только ед. Тоже, что ничтожность в 1 знач.; убогое состояние. «Есть люди, которые, при всем своем ничтожестве, много о себе думают.» А.Островский. «Вы вывели вашего мужа из ничтожества, приобрели себе обеспечение на старость лет.»"

# %%
m = Mystem()

# %%
mystemmed_line = m.analyze(line)
for st_line in mystemmed_line:
    print (st_line,'\n')
# Out:
# {'analysis': [{'lex': 'только', 'wt': 0.9073895266, 'gr': 'PART='}], 'text': 'только'}
#
# {'text': ' '}
#
# {'analysis': [], 'text': 'ед'}
#
# {'text': '. '}
#
# {'analysis': [{'lex': 'тоже', 'wt': 0.9944987474, 'gr': 'PART='}], 'text': 'Тоже'}
#
# {'text': ', '}
#
# {'analysis': [{'lex': 'что', 'wt': 0.688532576, 'gr': 'CONJ='}], 'text': 'что'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'ничтожность', 'wt': 1, 'gr': 'S,жен,неод=(вин,ед|им,ед)'}], 'text': 'ничтожность'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'}
#
# {'text': ' '}
#
# {'text': '1'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'знач', 'wt': 0.5254962442, 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'знач'}
#
# {'text': '.'}
#
# {'text': '; '}
#
# {'analysis': [{'lex': 'убогий', 'wt': 1, 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}], 'text': 'убогое'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'состояние', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}], 'text': 'состояние'}
#
# {'text': '. '}
#
# {'text': '«'}
#
# {'analysis': [{'lex': 'быть', 'wt': 0.9493594277, 'gr': 'V,нп=(непрош,ед,изъяв,3-л,несов|непрош,мн,изъяв,3-л,несов|наст,мн,изъяв,1-л,несов|наст,ед,изъяв,1-л,несов|наст,мн,изъяв,2-л,несов|наст,ед,изъяв,2-л,несов|наст,мн,изъяв,3-л,несов|наст,ед,изъяв,3-л,несов)'}], 'text': 'Есть'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'человек', 'wt': 1, 'gr': 'S,муж,од=им,мн'}], 'text': 'люди'}
#
# {'text': ', '}
#
# {'analysis': [{'lex': 'который', 'wt': 1, 'gr': 'APRO=(им,мн|вин,мн,неод)'}], 'text': 'которые'}
#
# {'text': ', '}
#
# {'analysis': [{'lex': 'при', 'wt': 0.9999956493, 'gr': 'PR='}], 'text': 'при'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'весь', 'wt': 0.5549692986, 'gr': 'APRO=(дат,мн|пр,ед,муж|пр,ед,сред|твор,ед,муж|твор,ед,сред)'}], 'text': 'всем'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'свой', 'wt': 0.9988393999, 'gr': 'APRO=(пр,ед,муж|пр,ед,сред)'}], 'text': 'своем'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'ничтожество', 'wt': 1, 'gr': 'S,сред=(пр,ед,од|пр,ед,неод)'}], 'text': 'ничтожестве'}
#
# {'text': ', '}
#
# {'analysis': [{'lex': 'много', 'wt': 0.9866397499, 'gr': 'ADV,прдк='}], 'text': 'много'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'о', 'wt': 0.9737875835, 'gr': 'PR='}], 'text': 'о'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'себя', 'wt': 0.9438010556, 'gr': 'SPRO=(пр|дат)'}], 'text': 'себе'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'думать', 'wt': 0.9967991681, 'gr': 'V,несов,нп=непрош,мн,изъяв,3-л'}], 'text': 'думают'}
#
# {'text': '.» '}
#
# {'analysis': [{'lex': 'а', 'wt': 0.9822148501, 'gr': 'CONJ='}], 'text': 'А'}
#
# {'text': '.'}
#
# {'analysis': [{'lex': 'островский', 'wt': 0.9921152976, 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'Островский'}
#
# {'text': '. '}
#
# {'text': '«'}
#
# {'analysis': [{'lex': 'вы', 'wt': 1, 'gr': 'SPRO,мн,2-л=им'}], 'text': 'Вы'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'выводить', 'wt': 0.4626723728, 'gr': 'V=прош,мн,изъяв,сов'}], 'text': 'вывели'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'ваш', 'wt': 1, 'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)'}], 'text': 'вашего'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'муж', 'wt': 0.6376694972, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'мужа'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'из', 'wt': 0.9999999775, 'gr': 'PR='}], 'text': 'из'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'ничтожество', 'wt': 1, 'gr': 'S,сред=(вин,мн,неод|вин,мн,од|род,ед,од|род,ед,неод|им,мн,од|им,мн,неод)'}], 'text': 'ничтожества'}
#
# {'text': ', '}
#
# {'analysis': [{'lex': 'приобретать', 'wt': 1, 'gr': 'V=прош,мн,изъяв,сов'}], 'text': 'приобрели'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'себя', 'wt': 0.9438010556, 'gr': 'SPRO=(пр|дат)'}], 'text': 'себе'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'обеспечение', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}], 'text': 'обеспечение'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'на', 'wt': 0.9989522965, 'gr': 'PR='}], 'text': 'на'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'старость', 'wt': 1, 'gr': 'S,жен,неод=(вин,ед|им,ед)'}], 'text': 'старость'}
#
# {'text': ' '}
#
# {'analysis': [{'lex': 'год', 'wt': 0.9954891636, 'gr': 'S,муж,неод=род,мн'}], 'text': 'лет'}
#
# {'text': '.'}
#
# {'text': '»\n'}

# %%
word = 'трусость'
def find_abstract_suff(word):
    chek_list = [r'ость$',r'ости$',r'остью$',r'есть$',r'ести$',r'естью$',r'ество$',r'ества$',r'еству$',r'естве$']
    match = None
    for check_el in chek_list:
        match = re.search(check_el, word) 
        if(match):
            print("found", match[0], "in word", word)
            return
    #print("not found")
find_ost_est(word,'s')
# Out:
# found ость in word трусость

# %%
def check_line_for_abstract(line):
    m = Mystem()
    mystemmed_line = m.analyze(line)
    for i in mystemmed_line:
            keys = list(i.keys())
            values = list(i.values())
            word  = i['text']
            if ('analysis' not in keys):
                pass
            elif(i['analysis'] ==[]):
                pass
            else:
                grammar = i['analysis'][0]['gr']
                grammar_sep_by_comma = grammar.split(',')
                if (len(grammar_sep_by_comma) == 1):
                    pass
                else:
                    pos = re.match('[A-Z\s]+', grammar_sep_by_comma[0])[0]
                    if(pos == "S"):
                        #print("subj found", word)
                        find_abstract_suff(word)
check_line_for_abstract(line)
# Out:
# found ость in word ничтожность
# found естве in word ничтожестве
# found ества in word ничтожества
# found ость in word старость

# %%
df_suff = pd.read_csv("suff.csv", sep='    ')
df_suff.head()
# Out:
#                              pdz\ted\tmn
# 0           И.    све́жесть    све́жести
# 1          Р.    све́жести    све́жестей
# 2          Д.    све́жести    све́жестям
# 3  В.    неод.    све́жесть    све́жести
# 4                          одуш.
