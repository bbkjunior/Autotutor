# %%
import json
from get_answers_return_recommendation import recommendation_algo

# %%
with open("answers_to_texts_questions.json", "r") as f:
    ans_dict = json.load(f)

# %% [markdown]
# with open("./text_maps/text_1.json", "r", encoding = "utf-8") as f:
#     ans_dict = json.load(f)

# %%
recommendation_algo(ans_dict)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 224/224 [02:54<00:00,  1.28it/s]
# {'recommended_text_1': {'raw_text': 'Вице-премьер правительства РФ Илья Клебанов полагает, что средства, необходимые на проведение международной операции по подъему атомохода "Курск", будут собраны в срок и в полном объеме. Об этом он заявил в пятницу РИА "Новости" по окончании встречи с представителями Фонда "Курск". По словам Клебанова, стоимость международной части операции составит не более 70 миллионов долларов. На нынешней встрече вице-премьер обсудил с представителями фонда ход подготовки предстоящей операции. Технический проект по подъему подлодки будет утвержден до конца января.',
#   'text_ind': 13},
# ...
